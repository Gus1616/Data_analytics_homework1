# %% [markdown]
# # HomeWork 1- 17350796

# %% [markdown]
# It includes Date of Sale, Price and Address of all residential properties purchased in Ireland since the 1st January 2010,
# as declared to the Revenue Commissioners for stamp duty purposes
# csv file = ppr-17350796.csv

# %% [markdown]
# ## Part 1: Preparing the data from CSV

# %%
import pandas as pd

from pandas.plotting import table
# import dataframe_image as dfi

import numpy as np
from numpy import array

import matplotlib.pyplot as plt

# %matplotlib inline

from matplotlib.backends.backend_pdf import PdfPages


from scipy import stats

# %% [markdown]
# Reading in the data and displaying the first 5 rows:

# %%
df = pd.read_csv('ppr-17350796.csv', keep_default_na=True, sep=',\s+', delimiter=',', skipinitialspace=True)

# %% [markdown]
# ## First 5 rows

# %%
df.head(5)
# Out:
#   Date of Sale (dd/mm/yyyy)                               Address Postal Code  \
# 0                06/05/2016    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8
# 1                22/12/2014  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8
# 2                22/05/2020    17 MERRION PARK, BLACKROCK, DUBLIN         NaN
# 3                27/11/2014      KNOCKROE, RATHMOYLE, CO.KILKENNY         NaN
# 4                22/11/2018    15 SHANNON PARK, LIFFORD RD, ENNIS         NaN
#
#      County    Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin  €630,000.00                    No            No
# 1    Dublin  €281,000.00                    No            No
# 2    Dublin  €560,000.00                    No            No
# 3  Kilkenny   €46,000.00                    No            No
# 4     Clare  €204,000.00                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
# 2  Second-Hand Dwelling house /Apartment                       NaN
# 3  Second-Hand Dwelling house /Apartment                       NaN
# 4  Second-Hand Dwelling house /Apartment                       NaN

# %% [markdown]
# ## Last 5 rows

# %% [markdown]
# Displaying the last 5 rows

# %%
df.tail(5)
# Out:
#      Date of Sale (dd/mm/yyyy)                                    Address  \
# 9995                15/12/2017           KNOCKASARTNETT, KILLARNEY, KERRY
# 9996                18/12/2012    17 the court, cypress downs, templeogue
# 9997                14/12/2016  THE LOG CABIN, FORGE COTTAGE, CULLENSTOWN
# 9998                19/06/2017               CARRIG RD, PARKMORE, ROSCREA
# 9999                02/11/2017         26 KILSHANE RD, FINGLAS, DUBLIN 11
#
#      Postal Code     County    Price (€) Not Full Market Price VAT Exclusive  \
# 9995         NaN      Kerry  €200,000.00                    No            No
# 9996         NaN     Dublin  €605,000.00                    No            No
# 9997         NaN    Wexford   €46,666.67                    No            No
# 9998         NaN  Tipperary  €176,000.00                    No            No
# 9999   Dublin 11     Dublin   €86,738.06                   Yes            No
#
#                     Description of Property Property Size Description
# 9995  Second-Hand Dwelling house /Apartment                       NaN
# 9996  Second-Hand Dwelling house /Apartment                       NaN
# 9997  Second-Hand Dwelling house /Apartment                       NaN
# 9998  Second-Hand Dwelling house /Apartment                       NaN
# 9999  Second-Hand Dwelling house /Apartment                       NaN

# %% [markdown]
# #### Shape of data frame

# %% [markdown]
# Display number of rows and columns- 10000 = Rows, 9 = columns

# %%
# number of rows and columns
df.shape
# Out:
# (10000, 9)

# %% [markdown]
# The data is currently all read as type object. The data needs to be change to the appropriate data type for it to be accurately analysed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date of Sale (dd/mm/yyyy)  10000 non-null  object
#  1   Address                    10000 non-null  object
#  2   Postal Code                1860 non-null   object
#  3   County                     10000 non-null  object
#  4   Price (€)                  10000 non-null  object
#  5   Not Full Market Price      10000 non-null  object
#  6   VAT Exclusive              10000 non-null  object
#  7   Description of Property    10000 non-null  object
#  8   Property Size Description  1029 non-null   object
# dtypes: object(9)
# memory usage: 703.2+ KB

# %% [markdown]
# Looking at the column names for errrors

# %%
df.columns
# Out:
# Index(['Date of Sale (dd/mm/yyyy)', 'Address', 'Postal Code', 'County',
#        'Price (€)', 'Not Full Market Price', 'VAT Exclusive',
#        'Description of Property', 'Property Size Description'],
#       dtype='object')

# %%
# Converting price to float, you need to remove all symbols from strings for the command to work. 



df['Price (€)'] = df['Price (€)'].str.replace(',', '')


df['Price (€)'] = df['Price (€)'].str.replace('€', '')

df['Price (€)'] = df['Price (€)'].astype(float)

df[['Price (€)']]
# Out:
#       Price (€)
# 0     630000.00
# 1     281000.00
# 2     560000.00
# 3      46000.00
# 4     204000.00
# ...         ...
# 9995  200000.00
# 9996  605000.00
# 9997   46666.67
# 9998  176000.00
# 9999   86738.06
#
# [10000 rows x 1 columns]

# %% [markdown]
# These object features have been changed to categorical as they each describe unique values

# %%
# There are a set number of unique counties
df['County'] = df['County'].astype('category')

# There are a set number of unique descriptions

df['Description of Property'] = df['Description of Property'].astype('category')

df['Address'] = df['Address'].astype('category')


# Postal code has a set number of unique categories
df['Postal Code'] = df['Postal Code'].astype('category')

# There are a set number of property size descriptions
df['Property Size Description'] = df['Property Size Description'].astype('category')

# this is just yes or no data there for categorical 
df['VAT Exclusive'] = df['VAT Exclusive'].astype('category')

# this is just yes or no data so it is cateogrical 
df['Not Full Market Price'] = df['Not Full Market Price'].astype('category')






df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)      object
# Address                      category
# Postal Code                  category
# County                       category
# Price (€)                     float64
# Not Full Market Price        category
# VAT Exclusive                category
# Description of Property      category
# Property Size Description    category
# dtype: object

# %%
# converting dates to date data type
df['Date of Sale (dd/mm/yyyy)'] = pd.to_datetime(df['Date of Sale (dd/mm/yyyy)'])

df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)    datetime64[ns]
# Address                            category
# Postal Code                        category
# County                             category
# Price (€)                           float64
# Not Full Market Price              category
# VAT Exclusive                      category
# Description of Property            category
# Property Size Description          category
# dtype: object

# %%
df['Year'] = pd.DatetimeIndex(df['Date of Sale (dd/mm/yyyy)']).year
df['Month'] = pd.DatetimeIndex(df['Date of Sale (dd/mm/yyyy)']).month

df.head(10)
# Out:
#   Date of Sale (dd/mm/yyyy)                                        Address  \
# 0                2016-06-05             21 CURZON ST, PORTOBELLO, DUBLIN 8
# 1                2014-12-22           44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8
# 2                2020-05-22             17 MERRION PARK, BLACKROCK, DUBLIN
# 3                2014-11-27               KNOCKROE, RATHMOYLE, CO.KILKENNY
# 4                2018-11-22             15 SHANNON PARK, LIFFORD RD, ENNIS
# 5                2016-01-31  27 MOUNT DRUMMOND SQ, HAROLDS CROSS, DUBLIN 6
# 6                2021-11-30         10 HOLLOW WAY, OAKVIEW VILLAGE, TRALEE
# 7                2016-02-05                            Ballygibbon, Nenagh
# 8                2018-12-03              RANDLESTOWN, BALLYCOGLEY, WEXFORD
# 9                2015-11-17               3 RIVER STREET, CLARA, CO OFFALY
#
#   Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin 8     Dublin   630000.0                    No            No
# 1    Dublin 8     Dublin   281000.0                    No            No
# 2         NaN     Dublin   560000.0                    No            No
# 3         NaN   Kilkenny    46000.0                    No            No
# 4         NaN      Clare   204000.0                    No            No
# 5    Dublin 6     Dublin   375000.0                    No            No
# 6         NaN      Kerry   182000.0                    No            No
# 7         NaN  Tipperary   264317.0                    No           Yes
# 8         NaN    Wexford    70000.0                    No            No
# 9         NaN     Offaly    34500.0                    No            No
#
#                  Description of Property   Property Size Description  Year  \
# 0  Second-Hand Dwelling house /Apartment                         NaN  2016
# 1  Second-Hand Dwelling house /Apartment                         NaN  2014
# 2  Second-Hand Dwelling house /Apartment                         NaN  2020
# 3  Second-Hand Dwelling house /Apartment                         NaN  2014
# 4  Second-Hand Dwelling house /Apartment                         NaN  2018
# 5  Second-Hand Dwelling house /Apartment                         NaN  2016
# 6  Second-Hand Dwelling house /Apartment                         NaN  2021
# 7          New Dwelling house /Apartment  greater than 125 sq metres  2016
# 8  Second-Hand Dwelling house /Apartment                         NaN  2018
# 9  Second-Hand Dwelling house /Apartment                         NaN  2015
#
#    Month
# 0      6
# 1     12
# 2      5
# 3     11
# 4     11
# 5      1
# 6     11
# 7      2
# 8     12
# 9     11

# %%
df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)    datetime64[ns]
# Address                            category
# Postal Code                        category
# County                             category
# Price (€)                           float64
# Not Full Market Price              category
# VAT Exclusive                      category
# Description of Property            category
# Property Size Description          category
# Year                                  int64
# Month                                 int64
# dtype: object

# %% [markdown]
# Looking for duplicate rows and columns

# %%
# There is 20 non unique addresses 
df.nunique()
# Out:
# Date of Sale (dd/mm/yyyy)    2759
# Address                      9980
# Postal Code                    22
# County                         26
# Price (€)                    2285
# Not Full Market Price           2
# VAT Exclusive                   2
# Description of Property         3
# Property Size Description       4
# Year                           13
# Month                          12
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date of Sale (dd/mm/yyyy)       0
# Address                         0
# Postal Code                  8140
# County                          0
# Price (€)                       0
# Not Full Market Price           0
# VAT Exclusive                   0
# Description of Property         0
# Property Size Description    8971
# Year                            0
# Month                           0
# dtype: int64

# %%
df['Not Full Market Price'].value_counts(dropna=False)
# Out:
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64

# %% [markdown]
# ## Postal Codes Review

# %% [markdown]
# The county Dublin appears 3193 times, this is the highest proportion.

# %%
df.loc[df['County'].isin(['Dublin'])]
# Out:
#      Date of Sale (dd/mm/yyyy)  \
# 0                   2016-06-05
# 1                   2014-12-22
# 2                   2020-05-22
# 5                   2016-01-31
# 10                  2015-06-15
# ...                        ...
# 9975                2013-04-11
# 9988                2020-10-03
# 9993                2019-05-12
# 9996                2012-12-18
# 9999                2017-02-11
#
#                                                Address Postal Code  County  \
# 0                   21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8  Dublin
# 1                 44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8  Dublin
# 2                   17 MERRION PARK, BLACKROCK, DUBLIN         NaN  Dublin
# 5        27 MOUNT DRUMMOND SQ, HAROLDS CROSS, DUBLIN 6    Dublin 6  Dublin
# 10    Apt 350 Block 8B, Tallaght Cross West, Dublin 24   Dublin 24  Dublin
# ...                                                ...         ...     ...
# 9975        29 Carndonagh Drive, Donaghmede, Dublin 13   Dublin 13  Dublin
# 9988        44 GERALDSTOWN WOODS, SANTRY AVE, DUBLIN 9    Dublin 9  Dublin
# 9993            6 Edenbrook Green, Edenbrook, Citywest         NaN  Dublin
# 9996           17 the court, cypress downs, templeogue         NaN  Dublin
# 9999                26 KILSHANE RD, FINGLAS, DUBLIN 11   Dublin 11  Dublin
#
#       Price (€) Not Full Market Price VAT Exclusive  \
# 0     630000.00                    No            No
# 1     281000.00                    No            No
# 2     560000.00                    No            No
# 5     375000.00                    No            No
# 10     99433.75                    No           Yes
# ...         ...                   ...           ...
# 9975  190000.00                    No            No
# 9988  170000.00                    No            No
# 9993  348017.61                    No           Yes
# 9996  605000.00                    No            No
# 9999   86738.06                   Yes            No
#
#                     Description of Property  \
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 5     Second-Hand Dwelling house /Apartment
# 10            New Dwelling house /Apartment
# ...                                     ...
# 9975  Second-Hand Dwelling house /Apartment
# 9988  Second-Hand Dwelling house /Apartment
# 9993          New Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9999  Second-Hand Dwelling house /Apartment
#
#                               Property Size Description  Year  Month
# 0                                                   NaN  2016      6
# 1                                                   NaN  2014     12
# 2                                                   NaN  2020      5
# 5                                                   NaN  2016      1
# 10    greater than or equal to 38 sq metres and less...  2015      6
# ...                                                 ...   ...    ...
# 9975                                                NaN  2013      4
# 9988                                                NaN  2020     10
# 9993                                                NaN  2019      5
# 9996                                                NaN  2012     12
# 9999                                                NaN  2017      2
#
# [3193 rows x 11 columns]

# %%
df["Postal Code"].describe().T
# Out:
# count          1860
# unique           22
# top       Dublin 15
# freq            232
# Name: Postal Code, dtype: object

# %% [markdown]
# 58% percent have a set post code, while this is low. I have opted to keep the data as it still could provide relevent statisical inferences

# %% [markdown]
# There is some logical integrity issues with the data. Some post codes do not match the post codes in their addresses. NaN needs to be converted to not relevent.

# %%
category_columns = df.select_dtypes(['category']).columns
df[category_columns].head()
# Out:
#                                 Address Postal Code    County  \
# 0    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8    Dublin
# 1  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8    Dublin
# 2    17 MERRION PARK, BLACKROCK, DUBLIN         NaN    Dublin
# 3      KNOCKROE, RATHMOYLE, CO.KILKENNY         NaN  Kilkenny
# 4    15 SHANNON PARK, LIFFORD RD, ENNIS         NaN     Clare
#
#   Not Full Market Price VAT Exclusive                Description of Property  \
# 0                    No            No  Second-Hand Dwelling house /Apartment
# 1                    No            No  Second-Hand Dwelling house /Apartment
# 2                    No            No  Second-Hand Dwelling house /Apartment
# 3                    No            No  Second-Hand Dwelling house /Apartment
# 4                    No            No  Second-Hand Dwelling house /Apartment
#
#   Property Size Description
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %% [markdown]
# I have decided to change the NaN values of 'Postal Code' to 'No Post Code'

# %% [markdown]
# ### Looking at all the unique categories and their values:

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(dropna=False))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
#
# Postal Code
# NaN          8140
# Dublin 15     232
# Dublin 18     143
# Dublin 9      119
# Dublin 8      115
# Dublin 24     114
# Dublin 4      109
# Dublin 12     104
# Dublin 16      96
# Dublin 11      93
# Dublin 7       88
# Dublin 13      85
# Dublin 14      84
# Dublin 3       82
# Dublin 5       78
# Dublin 1       77
# Dublin 6       66
# Dublin 22      54
# Dublin 2       34
# Dublin 20      25
# Dublin 17      24
# Dublin 10      20
# Dublin 6w      18
# Name: Postal Code, dtype: int64
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8363
# New Dwelling house /Apartment            1636
# Teach/Árasán Cónaithe Atháimhe              1
# Name: Description of Property, dtype: int64
#
# Property Size Description
# NaN                                                                  8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64

# %% [markdown]
# ## Description of Property Iregularity

# %% [markdown]
# 'Description of Property' shows 3 unique properties. "Teach/Árasán Cónaithe Atháimhe" is the Irish translation of "Second-Hand Dwelling house /Apartment". While it is important that Irish people practice their native language for the purpose of data analytics it makes sense to change this to the english category for consistency.

# %%
# getting index of where the illogical data is 
df.index[df['Description of Property'] == 'Teach/Árasán Cónaithe Atháimhe'].tolist()
# Out:
# [5686]

# %%
# replacing with english translation
df.at[5686,'Description of Property']='Second-Hand Dwelling house /Apartment'

# %%
df['Description of Property'].value_counts(dropna=False)
# Out:
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Teach/Árasán Cónaithe Atháimhe              0
# Name: Description of Property, dtype: int64

# %%
df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                 1860     22
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description   1029      4
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                            freq
# Address                       2
# Postal Code                 232
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description   723

# %% [markdown]
# # Describing Numeric Types

# %%
numeric_columns = df.select_dtypes(['float64','int']).columns
numeric_columns
# Out:
# Index(['Price (€)'], dtype='object')

# %%
df.describe(datetime_is_numeric=True).T
# Out:
#                              count                        mean  \
# Date of Sale (dd/mm/yyyy)    10000  2017-01-19 02:06:08.640000
# Price (€)                  10000.0               260260.702676
# Year                       10000.0                   2016.5192
# Month                      10000.0                      6.8947
#
#                                            min                  25%  \
# Date of Sale (dd/mm/yyyy)  2010-01-02 00:00:00  2014-11-07 00:00:00
# Price (€)                               5500.0             120000.0
# Year                                    2010.0               2014.0
# Month                                      1.0                  4.0
#
#                                            50%                  75%  \
# Date of Sale (dd/mm/yyyy)  2017-06-02 12:00:00  2019-08-04 00:00:00
# Price (€)                             200000.0            308370.08
# Year                                    2017.0               2019.0
# Month                                      7.0                 10.0
#
#                                            max            std
# Date of Sale (dd/mm/yyyy)  2022-12-01 00:00:00            NaN
# Price (€)                           17151248.0  390170.322939
# Year                                    2022.0       3.108729
# Month                                     12.0       3.477186

# %%
# numeric_DataDescription_Table = df.describe(datetime_is_numeric=True).T

# # plot = plt.subplot(111, frame_on=False)

# # #     #remove axis
# # # plot.xaxis.set_visible(False) 
# # # plot.yaxis.set_visible(False) 

# # #create the table plot and position it in the upper left corner
# # table(plot, numeric_DataDescription_Table,loc='upper right')

# #save the plot as a png file
# plt.savefig('numericDataDescribed.png')

# %% [markdown]
# #### Summary stats for numeric data Price (€)
# From look at the price data, the standard deviation is very large, with a large range of values. Range = 17145748

# %%
df[numeric_columns].describe().T
# Out:
#              count           mean            std     min       25%       50%  \
# Price (€)  10000.0  260260.702676  390170.322939  5500.0  120000.0  200000.0
#
#                  75%         max
# Price (€)  308370.08  17151248.0

# %% [markdown]
# ### Median value of price

# %%
df['Price (€)'].median()
# Out:
# 200000.0

# %%
numeric_columns_card = df[numeric_columns].nunique()
# store the values in a dataframe
df_numeric_card = pd.DataFrame(numeric_columns_card, columns=['card'])
df_numeric_card
# Out:
#            card
# Price (€)  2285

# %%
df['Address'].describe()
# Out:
# count                                                 10000
# unique                                                 9980
# top       APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# freq                                                      2
# Name: Address, dtype: object

# %%
df.to_csv('updated-ppr-17350796.csv', index=False)

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(dropna=False))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
#
# Postal Code
# NaN          8140
# Dublin 15     232
# Dublin 18     143
# Dublin 9      119
# Dublin 8      115
# Dublin 24     114
# Dublin 4      109
# Dublin 12     104
# Dublin 16      96
# Dublin 11      93
# Dublin 7       88
# Dublin 13      85
# Dublin 14      84
# Dublin 3       82
# Dublin 5       78
# Dublin 1       77
# Dublin 6       66
# Dublin 22      54
# Dublin 2       34
# Dublin 20      25
# Dublin 17      24
# Dublin 10      20
# Dublin 6w      18
# Name: Postal Code, dtype: int64
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Teach/Árasán Cónaithe Atháimhe              0
# Name: Description of Property, dtype: int64
#
# Property Size Description
# NaN                                                                  8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(normalize=True, dropna=False))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    0.0002
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       0.0002
# GURETTI, HOWTH SUMMIT, NEW RD                            0.0002
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      0.0002
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        0.0002
#                                                           ...
# 29 Crockaun Way, Brownstown, Curragh                     0.0001
# 29 DROIMNEACH, BWEENG, CORK                              0.0001
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    0.0001
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          0.0001
# unit 3 Parkside Glen, parkside, malahide road            0.0001
# Name: Address, Length: 9980, dtype: float64
#
# Postal Code
# NaN          0.8140
# Dublin 15    0.0232
# Dublin 18    0.0143
# Dublin 9     0.0119
# Dublin 8     0.0115
# Dublin 24    0.0114
# Dublin 4     0.0109
# Dublin 12    0.0104
# Dublin 16    0.0096
# Dublin 11    0.0093
# Dublin 7     0.0088
# Dublin 13    0.0085
# Dublin 14    0.0084
# Dublin 3     0.0082
# Dublin 5     0.0078
# Dublin 1     0.0077
# Dublin 6     0.0066
# Dublin 22    0.0054
# Dublin 2     0.0034
# Dublin 20    0.0025
# Dublin 17    0.0024
# Dublin 10    0.0020
# Dublin 6w    0.0018
# Name: Postal Code, dtype: float64
#
# County
# Dublin       0.3193
# Cork         0.1099
# Galway       0.0502
# Kildare      0.0483
# Meath        0.0399
# Wexford      0.0363
# Limerick     0.0348
# Wicklow      0.0317
# Louth        0.0288
# Kerry        0.0285
# Tipperary    0.0283
# Donegal      0.0274
# Mayo         0.0259
# Waterford    0.0245
# Clare        0.0240
# Westmeath    0.0174
# Laois        0.0163
# Cavan        0.0153
# Sligo        0.0148
# Roscommon    0.0143
# Kilkenny     0.0133
# Carlow       0.0124
# Offaly       0.0119
# Leitrim      0.0099
# Longford     0.0090
# Monaghan     0.0076
# Name: County, dtype: float64
#
# Not Full Market Price
# No     0.9552
# Yes    0.0448
# Name: Not Full Market Price, dtype: float64
#
# VAT Exclusive
# No     0.8399
# Yes    0.1601
# Name: VAT Exclusive, dtype: float64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    0.8364
# New Dwelling house /Apartment            0.1636
# Teach/Árasán Cónaithe Atháimhe           0.0000
# Name: Description of Property, dtype: float64
#
# Property Size Description
# NaN                                                                  0.8971
# greater than or equal to 38 sq metres and less than 125 sq metres    0.0723
# greater than 125 sq metres                                           0.0135
# greater than or equal to 125 sq metres                               0.0094
# less than 38 sq metres                                               0.0077
# Name: Property Size Description, dtype: float64

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(normalize=True, dropna=True))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    0.0002
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       0.0002
# GURETTI, HOWTH SUMMIT, NEW RD                            0.0002
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      0.0002
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        0.0002
#                                                           ...
# 29 Crockaun Way, Brownstown, Curragh                     0.0001
# 29 DROIMNEACH, BWEENG, CORK                              0.0001
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    0.0001
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          0.0001
# unit 3 Parkside Glen, parkside, malahide road            0.0001
# Name: Address, Length: 9980, dtype: float64
#
# Postal Code
# Dublin 15    0.124731
# Dublin 18    0.076882
# Dublin 9     0.063978
# Dublin 8     0.061828
# Dublin 24    0.061290
# Dublin 4     0.058602
# Dublin 12    0.055914
# Dublin 16    0.051613
# Dublin 11    0.050000
# Dublin 7     0.047312
# Dublin 13    0.045699
# Dublin 14    0.045161
# Dublin 3     0.044086
# Dublin 5     0.041935
# Dublin 1     0.041398
# Dublin 6     0.035484
# Dublin 22    0.029032
# Dublin 2     0.018280
# Dublin 20    0.013441
# Dublin 17    0.012903
# Dublin 10    0.010753
# Dublin 6w    0.009677
# Name: Postal Code, dtype: float64
#
# County
# Dublin       0.3193
# Cork         0.1099
# Galway       0.0502
# Kildare      0.0483
# Meath        0.0399
# Wexford      0.0363
# Limerick     0.0348
# Wicklow      0.0317
# Louth        0.0288
# Kerry        0.0285
# Tipperary    0.0283
# Donegal      0.0274
# Mayo         0.0259
# Waterford    0.0245
# Clare        0.0240
# Westmeath    0.0174
# Laois        0.0163
# Cavan        0.0153
# Sligo        0.0148
# Roscommon    0.0143
# Kilkenny     0.0133
# Carlow       0.0124
# Offaly       0.0119
# Leitrim      0.0099
# Longford     0.0090
# Monaghan     0.0076
# Name: County, dtype: float64
#
# Not Full Market Price
# No     0.9552
# Yes    0.0448
# Name: Not Full Market Price, dtype: float64
#
# VAT Exclusive
# No     0.8399
# Yes    0.1601
# Name: VAT Exclusive, dtype: float64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    0.8364
# New Dwelling house /Apartment            0.1636
# Teach/Árasán Cónaithe Atháimhe           0.0000
# Name: Description of Property, dtype: float64
#
# Property Size Description
# greater than or equal to 38 sq metres and less than 125 sq metres    0.702624
# greater than 125 sq metres                                           0.131195
# greater than or equal to 125 sq metres                               0.091351
# less than 38 sq metres                                               0.074830
# Name: Property Size Description, dtype: float64

# %% [markdown]
# ### Looking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
dfT = df.T
print("Number of duplicate (excluding first) columns in the table is: ", dfT.duplicated().sum())
print("Number of duplicate (including first) columns in the table is: ",  dfT[dfT.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) columns in the table is:  0
# Number of duplicate (including first) columns in the table is:  0

# %% [markdown]
# ## Describing categorical data

# %%
df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                 1860     22
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description   1029      4
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                            freq
# Address                       2
# Postal Code                 232
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description   723

# %%
df_category_mode = pd.DataFrame(index = df[category_columns].describe().T.index, columns=['mode', 'freq_mode','%mode', '2ndmode', 'freq_2ndmode','%2ndmode'])
df_category_mode
# Out:
#                           mode freq_mode %mode 2ndmode freq_2ndmode %2ndmode
# Address                    NaN       NaN   NaN     NaN          NaN      NaN
# Postal Code                NaN       NaN   NaN     NaN          NaN      NaN
# County                     NaN       NaN   NaN     NaN          NaN      NaN
# Not Full Market Price      NaN       NaN   NaN     NaN          NaN      NaN
# VAT Exclusive              NaN       NaN   NaN     NaN          NaN      NaN
# Description of Property    NaN       NaN   NaN     NaN          NaN      NaN
# Property Size Description  NaN       NaN   NaN     NaN          NaN      NaN

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts())
    print(df[column].value_counts().keys())
    
    df_category_mode.loc[column]['mode'] = df[column].value_counts().keys()[0]
    df_category_mode.loc[column]['freq_mode'] = df[column].value_counts()[df_category_mode.loc[column]['mode']]
    df_category_mode.loc[column]['%mode'] = df[column].value_counts(normalize=True)[df_category_mode.loc[column]['mode']]
 

    if df[column].value_counts().size > 1:
        df_category_mode.loc[column]['2ndmode'] = df[column].value_counts().keys()[1]
        df_category_mode.loc[column]['freq_2ndmode'] = df[column].value_counts()[df_category_mode.loc[column]['2ndmode']]
        df_category_mode.loc[column]['%2ndmode'] = df[column].value_counts(normalize=True)[df_category_mode.loc[column]['2ndmode']]
    else: df_category_mode.loc[column] = '-'
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
# CategoricalIndex(['APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE',
#                   '8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY',
#                   'GURETTI, HOWTH SUMMIT, NEW RD',
#                   '3 BARTRA ROCK, HARBOUR ROAD, DALKEY',
#                   'BALLYHAUNIS RD, CLAREMORRIS, MAYO',
#                   'RUSHLAKE, WOODLAWN, BALLINASLOE',
#                   'Glackmore, Aught Road, Muff',
#                   '16 BENBULBIN RD, DRIMNAGH, DUBLIN 12',
#                   '67 MALAHIDE MARINA VILLAGE, MALAHIDE, DUBLIN',
#                   'HILLQUARTER, COOSAN, ATHLONE',
#                   ...
#                   '29 COIS LOCHA, SALEEN, BALLINROBE RD',
#                   '29 Carlinn Avenue, Mullaharlin Road, Dundalk',
#                   '29 Carndonagh Drive, Donaghmede, Dublin 13',
#                   '29 Castlebrook Green, Castlebrook Manor, Castletroy',
#                   '29 Citywest Village Avenue, Citywest Village, Citywest',
#                   '29 Crockaun Way, Brownstown, Curragh',
#                   '29 DROIMNEACH, BWEENG, CORK',
#                   '29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7',
#                   '29 DUBLIN ST, DUNDALK, CO LOUTH',
#                   'unit 3 Parkside Glen, parkside, malahide road'],
#                  categories=[''Ardan', Aghowle, Ashford', ''Eala', Castlejane, Glanmire', ''Ermland', Johnstown Road, Enfield', ''Ewell', 18 Mount Anville Road, Dundrum', ''Knocknagow', Blackrock Road', ''SANCTA MARIA', BRIGHTON ROAD, FOXROCK', ''SHARON', NORTH CIRCULAR ROAD', '04 MOYGLARE RIDGE, MARIAVILLA, MAYNOOTH', ...], ordered=False, dtype='category', length=9980)
#
# Postal Code
# Dublin 15    232
# Dublin 18    143
# Dublin 9     119
# Dublin 8     115
# Dublin 24    114
# Dublin 4     109
# Dublin 12    104
# Dublin 16     96
# Dublin 11     93
# Dublin 7      88
# Dublin 13     85
# Dublin 14     84
# Dublin 3      82
# Dublin 5      78
# Dublin 1      77
# Dublin 6      66
# Dublin 22     54
# Dublin 2      34
# Dublin 20     25
# Dublin 17     24
# Dublin 10     20
# Dublin 6w     18
# Name: Postal Code, dtype: int64
# CategoricalIndex(['Dublin 15', 'Dublin 18', 'Dublin 9', 'Dublin 8',
#                   'Dublin 24', 'Dublin 4', 'Dublin 12', 'Dublin 16',
#                   'Dublin 11', 'Dublin 7', 'Dublin 13', 'Dublin 14',
#                   'Dublin 3', 'Dublin 5', 'Dublin 1', 'Dublin 6', 'Dublin 22',
#                   'Dublin 2', 'Dublin 20', 'Dublin 17', 'Dublin 10',
#                   'Dublin 6w'],
#                  categories=['Dublin 1', 'Dublin 10', 'Dublin 11', 'Dublin 12', 'Dublin 13', 'Dublin 14', 'Dublin 15', 'Dublin 16', ...], ordered=False, dtype='category')
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
# CategoricalIndex(['Dublin', 'Cork', 'Galway', 'Kildare', 'Meath', 'Wexford',
#                   'Limerick', 'Wicklow', 'Louth', 'Kerry', 'Tipperary',
#                   'Donegal', 'Mayo', 'Waterford', 'Clare', 'Westmeath',
#                   'Laois', 'Cavan', 'Sligo', 'Roscommon', 'Kilkenny', 'Carlow',
#                   'Offaly', 'Leitrim', 'Longford', 'Monaghan'],
#                  categories=['Carlow', 'Cavan', 'Clare', 'Cork', 'Donegal', 'Dublin', 'Galway', 'Kerry', ...], ordered=False, dtype='category')
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
# CategoricalIndex(['No', 'Yes'], categories=['No', 'Yes'], ordered=False, dtype='category')
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
# CategoricalIndex(['No', 'Yes'], categories=['No', 'Yes'], ordered=False, dtype='category')
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Teach/Árasán Cónaithe Atháimhe              0
# Name: Description of Property, dtype: int64
# CategoricalIndex(['Second-Hand Dwelling house /Apartment',
#                   'New Dwelling house /Apartment',
#                   'Teach/Árasán Cónaithe Atháimhe'],
#                  categories=['New Dwelling house /Apartment', 'Second-Hand Dwelling house /Apartment', 'Teach/Árasán Cónaithe Atháimhe'], ordered=False, dtype='category')
#
# Property Size Description
# greater than or equal to 38 sq metres and less than 125 sq metres    723
# greater than 125 sq metres                                           135
# greater than or equal to 125 sq metres                                94
# less than 38 sq metres                                                77
# Name: Property Size Description, dtype: int64
# CategoricalIndex(['greater than or equal to 38 sq metres and less than 125 sq metres',
#                   'greater than 125 sq metres',
#                   'greater than or equal to 125 sq metres',
#                   'less than 38 sq metres'],
#                  categories=['greater than 125 sq metres', 'greater than or equal to 125 sq metres', 'greater than or equal to 38 sq metres and less than 125 sq metres', 'less than 38 sq metres'], ordered=False, dtype='category')

# %%
df_category_mode
# Out:
#                                                                         mode  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                           freq_mode     %mode  \
# Address                           2    0.0002
# Postal Code                     232  0.124731
# County                         3193    0.3193
# Not Full Market Price          9552    0.9552
# VAT Exclusive                  8399    0.8399
# Description of Property        8364    0.8364
# Property Size Description       723  0.702624
#
#                                                                      2ndmode  \
# Address                    8A COACHMAN APARTMENTS, DOMINICK STREET, CO GA...
# Postal Code                                                        Dublin 18
# County                                                                  Cork
# Not Full Market Price                                                    Yes
# VAT Exclusive                                                            Yes
# Description of Property                        New Dwelling house /Apartment
# Property Size Description                         greater than 125 sq metres
#
#                           freq_2ndmode  %2ndmode
# Address                              2    0.0002
# Postal Code                        143  0.076882
# County                            1099    0.1099
# Not Full Market Price              448    0.0448
# VAT Exclusive                     1601    0.1601
# Description of Property           1636    0.1636
# Property Size Description          135  0.131195

# %%
# Prepare %missing column
category_columns_perc_missing  = 100 * (df[category_columns].isnull().sum()/df.shape[0])
#category_columns_perc_missing

# Store the values in a dataframe
df_category_perc_missing = pd.DataFrame(category_columns_perc_missing, columns=['%missing'])
df_category_perc_missing
# Out:
#                            %missing
# Address                        0.00
# Postal Code                   81.40
# County                         0.00
# Not Full Market Price          0.00
# VAT Exclusive                  0.00
# Description of Property        0.00
# Property Size Description     89.71

# %%
# Put the columns together to prepare the final table 
df_category_columns_data_quality_report_table = pd.concat([df[category_columns].describe().T, df_category_mode, df_category_perc_missing], axis=1)

df_category_columns_data_quality_report_table
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                 1860     22
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description   1029      4
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                            freq  \
# Address                       2
# Postal Code                 232
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description   723
#
#                                                                         mode  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                           freq_mode     %mode  \
# Address                           2    0.0002
# Postal Code                     232  0.124731
# County                         3193    0.3193
# Not Full Market Price          9552    0.9552
# VAT Exclusive                  8399    0.8399
# Description of Property        8364    0.8364
# Property Size Description       723  0.702624
#
#                                                                      2ndmode  \
# Address                    8A COACHMAN APARTMENTS, DOMINICK STREET, CO GA...
# Postal Code                                                        Dublin 18
# County                                                                  Cork
# Not Full Market Price                                                    Yes
# VAT Exclusive                                                            Yes
# Description of Property                        New Dwelling house /Apartment
# Property Size Description                         greater than 125 sq metres
#
#                           freq_2ndmode  %2ndmode  %missing
# Address                              2    0.0002      0.00
# Postal Code                        143  0.076882     81.40
# County                            1099    0.1099      0.00
# Not Full Market Price              448    0.0448      0.00
# VAT Exclusive                     1601    0.1601      0.00
# Description of Property           1636    0.1636      0.00
# Property Size Description          135  0.131195     89.71

# %% [markdown]
# # Visualisation- Data Quality Report

# %% [markdown]
# ### Price feature

# %%
df[numeric_columns].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Price (€)'}>]], dtype=object)

# %%
df[numeric_columns].plot(kind='hist', subplots=True, figsize=(30,30), layout=(4,4), sharex=False, sharey=False)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ### It is clear from the looking at these histograms of price that there is a large range of values, that is heavily right skewed

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
plt.savefig('Homework1-DataQualityReport-NumericFeatures-histograms_all_1-1.pdf')

# %% [markdown]
# Box Plot of Price

# %% [markdown]
# From the box plot you can see there is a significant number of outliers

# %%
df[numeric_columns].plot(kind='box', subplots=True, figsize=(30,30), layout=(3,3), sharex=False, sharey=False)
plt.savefig('HomeWork-DataQualityReport-NumericFeatures-boxplots_all_1-1.pdf')

# %%
df.boxplot(column =['Price (€)'], grid = False, figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Date of Sale feature

# %%
df['Date of Sale (dd/mm/yyyy)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Month'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Charts for All Catergotical Features

# %%
# Plot bar charts for all categorical features and save them in a single PDF file
pp = PdfPages('Homework1-DataQualityReport-CategoricalFeatures_barcharts_1-1.pdf')

# We can set the parameters for .value_counts() to not drop the na. This allows us to see missing data in our 
# # categorical features.
for column in category_columns:
    f = df[column].value_counts(dropna=False).plot(kind='bar', title=column, figsize=(5,5))
    pp.savefig(f.get_figure())
    plt.show()

pp.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-efabba2d2f3d> in <module>
#       7     f = df[column].value_counts(dropna=False).plot(kind='bar', title=column, figsize=(5,5))
#       8     pp.savefig(f.get_figure())
# ----> 9     plt.show()
#      10
#      11 pp.close()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4151             if self.xaxis.get_visible():
#    4152                 try:
# -> 4153                     bb_xaxis = self.xaxis.get_tightbbox(
#    4154                         renderer, for_layout_only=for_layout_only)
#    4155                 except TypeError:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1112
#    1113         # go back to just this axis's tick labels
# -> 1114         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1115                     ticks_to_draw, renderer)
#    1116
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     285
#     286         # Full vertical extent of font, including ascenders and descenders:
# --> 287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
#     289             ismath="TeX" if self.get_usetex() else False)
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     271         """
#     272         fname = findfont(prop)
# --> 273         font = get_font(fname)
#     274
#     275         font.clear()
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1412     # Resolving the path avoids embedding the font twice in pdf/ps output if a
#    1413     # single font is selected using two different relative paths.
# -> 1414     filename = os.path.realpath(filename)
#    1415     if hinting_factor is None:
#    1416         hinting_factor = rcParams['text.hinting_factor']
#
# ~\anaconda3\lib\ntpath.py in realpath(path)
#     662             # Ensure that the non-prefixed path resolves to the same path
#     663             try:
# --> 664                 if _getfinalpathname(spath) == path:
#     665                     path = spath
#     666             except OSError as ex:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 2: data quality plan for the cleaned CSV file

# %% [markdown]
# ### List of data quality issues and proposed solutions

# %% [markdown]
# Date of Sale (dd/mm/yyyy): This data was converted to datetime. I will extract the months and the years in order to compare them to other features.
#
# Postal Code:Large proportion missing. Opted to keep as could provide further geographical information about Dublin
#
# Price: Large variance in data makes it difficult for interpretation. There is potential to remove outliers
#
# Description of Property: Irish descriptions were tranlated so there were only two unique values for consistency.
#
# Property Size Description: This feature has a large amount of missing data.
#
# Vat Exclusive: Less than 17% of the sales do not include the VAT in the sale price. I have chose not sepated this data and keep it as one.

# %% [markdown]
# ### Addressing 'Property Size Desciption' feature:

# %%
df["Property Size Description"].describe().T
# Out:
# count                                                  1029
# unique                                                    4
# top       greater than or equal to 38 sq metres and less...
# freq                                                    723
# Name: Property Size Description, dtype: object

# %%
df['Property Size Description'].unique()
# Out:
# [NaN, 'greater than 125 sq metres', 'greater than or equal to 38 sq metres and les..., 'greater than or equal to 125 sq metres', 'less than 38 sq metres']
# Categories (4, object): ['greater than 125 sq metres', 'greater than or equal to 38 sq metres and les..., 'greater than or equal to 125 sq metres', 'less than 38 sq metres']

# %%
df['Property Size Description'].value_counts()
# Out:
# greater than or equal to 38 sq metres and less than 125 sq metres    723
# greater than 125 sq metres                                           135
# greater than or equal to 125 sq metres                                94
# less than 38 sq metres                                                77
# Name: Property Size Description, dtype: int64

# %%
df['Property Size Description'].isnull().sum()
# Out:
# 8971

# %%
df.groupby('Description of Property')['Property Size Description'].count()
# Out:
# Description of Property
# New Dwelling house /Apartment            1029
# Second-Hand Dwelling house /Apartment       0
# Teach/Árasán Cónaithe Atháimhe              0
# Name: Property Size Description, dtype: int64

# %% [markdown]
# As you can see 90% of the data is missing. However, as is shown 62% of New Dwelling house/Apartments have a Property Size Description attrtibuted to them. Thus, it may be valuable information to help look at the target feature Price later on.

# %%
df.loc[(df['Description of Property'] == 'New Dwelling house /Apartment') & 
                         (df['Property Size Description'].isna())]
# Out:
#      Date of Sale (dd/mm/yyyy)                                       Address  \
# 15                  2021-03-06        4 INISHFALLEN, ROOKERY ROAD, KILLARNEY
# 32                  2020-09-12     4 Forgelands, Old Forge Road, Enniscorthy
# 49                  2021-08-17          4 An Gairdin Cuil, Cosmona, Loughrea
# 52                  2021-11-29             18 Strand View, Strand Road, Bray
# 63                  2019-11-27                   14 Meadowgate, Marlton Road
# ...                        ...                                           ...
# 9942                2019-03-05    96 Cnoc Tiarnach, Grange End, Dunshaughlin
# 9959                2019-11-14                          Pulla, Gorteen, Ring
# 9966                2021-09-30  Apartment 14, First Floor - Block B, Belvoir
# 9983                2021-06-30                            Knockmore, Drinagh
# 9993                2019-05-12        6 Edenbrook Green, Edenbrook, Citywest
#
#      Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 15           NaN      Kerry  340000.00                    No           Yes
# 32           NaN    Wexford  190390.31                    No           Yes
# 49           NaN     Galway  265000.00                    No           Yes
# 52           NaN    Wicklow  431718.00                    No           Yes
# 63           NaN    Wicklow  297797.36                    No           Yes
# ...          ...        ...        ...                   ...           ...
# 9942         NaN      Meath  295154.00                    No           Yes
# 9959         NaN  Waterford  150000.00                    No           Yes
# 9966         NaN     Dublin  476678.00                    No            No
# 9983         NaN       Cork  233000.00                    No           Yes
# 9993         NaN     Dublin  348017.61                    No           Yes
#
#             Description of Property Property Size Description  Year  Month
# 15    New Dwelling house /Apartment                       NaN  2021      3
# 32    New Dwelling house /Apartment                       NaN  2020      9
# 49    New Dwelling house /Apartment                       NaN  2021      8
# 52    New Dwelling house /Apartment                       NaN  2021     11
# 63    New Dwelling house /Apartment                       NaN  2019     11
# ...                             ...                       ...   ...    ...
# 9942  New Dwelling house /Apartment                       NaN  2019      3
# 9959  New Dwelling house /Apartment                       NaN  2019     11
# 9966  New Dwelling house /Apartment                       NaN  2021      9
# 9983  New Dwelling house /Apartment                       NaN  2021      6
# 9993  New Dwelling house /Apartment                       NaN  2019      5
#
# [607 rows x 11 columns]

# %%
df.groupby('Description of Property').count()
# Out:
#                                        Date of Sale (dd/mm/yyyy)  Address  \
# Description of Property
# New Dwelling house /Apartment                               1636     1636
# Second-Hand Dwelling house /Apartment                       8364     8364
# Teach/Árasán Cónaithe Atháimhe                                 0        0
#
#                                        Postal Code  County  Price (€)  \
# Description of Property
# New Dwelling house /Apartment                  211    1636       1636
# Second-Hand Dwelling house /Apartment         1649    8364       8364
# Teach/Árasán Cónaithe Atháimhe                   0       0          0
#
#                                        Not Full Market Price  VAT Exclusive  \
# Description of Property
# New Dwelling house /Apartment                           1636           1636
# Second-Hand Dwelling house /Apartment                   8364           8364
# Teach/Árasán Cónaithe Atháimhe                             0              0
#
#                                        Property Size Description  Year  Month
# Description of Property
# New Dwelling house /Apartment                               1029  1636   1636
# Second-Hand Dwelling house /Apartment                          0  8364   8364
# Teach/Árasán Cónaithe Atháimhe                                 0     0      0

# %% [markdown]
# ### Addressing the 'VAT exclusive' data

# %%
df.loc[df['Description of Property'] == 'New Dwelling house /Apartment']
# Out:
#      Date of Sale (dd/mm/yyyy)  \
# 7                   2016-02-05
# 10                  2015-06-15
# 15                  2021-03-06
# 20                  2017-07-04
# 24                  2010-07-09
# ...                        ...
# 9967                2018-03-08
# 9979                2010-03-11
# 9983                2021-06-30
# 9991                2018-11-19
# 9993                2019-05-12
#
#                                                Address Postal Code     County  \
# 7                                  Ballygibbon, Nenagh         NaN  Tipperary
# 10    Apt 350 Block 8B, Tallaght Cross West, Dublin 24   Dublin 24     Dublin
# 15              4 INISHFALLEN, ROOKERY ROAD, KILLARNEY         NaN      Kerry
# 20                                 Knockanna, Tinahely         NaN    Wicklow
# 24    30 Broadfield Drive, Broadfield Manor, Rathcoole         NaN     Dublin
# ...                                                ...         ...        ...
# 9967                    152 BEECHDALE, DUNBOYNE, MEATH         NaN      Meath
# 9979                        3 Holywell Grove, Kilcoole         NaN    Wicklow
# 9983                                Knockmore, Drinagh         NaN       Cork
# 9991                14 Roseberry Hill, Quinagh, CARLOW         NaN     Carlow
# 9993            6 Edenbrook Green, Edenbrook, Citywest         NaN     Dublin
#
#       Price (€) Not Full Market Price VAT Exclusive  \
# 7     264317.00                    No           Yes
# 10     99433.75                    No           Yes
# 15    340000.00                    No           Yes
# 20    105000.00                    No           Yes
# 24    281938.00                    No           Yes
# ...         ...                   ...           ...
# 9967  330000.00                    No           Yes
# 9979  233480.17                    No           Yes
# 9983  233000.00                    No           Yes
# 9991  173173.00                    No           Yes
# 9993  348017.61                    No           Yes
#
#             Description of Property  \
# 7     New Dwelling house /Apartment
# 10    New Dwelling house /Apartment
# 15    New Dwelling house /Apartment
# 20    New Dwelling house /Apartment
# 24    New Dwelling house /Apartment
# ...                             ...
# 9967  New Dwelling house /Apartment
# 9979  New Dwelling house /Apartment
# 9983  New Dwelling house /Apartment
# 9991  New Dwelling house /Apartment
# 9993  New Dwelling house /Apartment
#
#                               Property Size Description  Year  Month
# 7                            greater than 125 sq metres  2016      2
# 10    greater than or equal to 38 sq metres and less...  2015      6
# 15                                                  NaN  2021      3
# 20               greater than or equal to 125 sq metres  2017      7
# 24    greater than or equal to 38 sq metres and less...  2010      7
# ...                                                 ...   ...    ...
# 9967  greater than or equal to 38 sq metres and less...  2018      3
# 9979  greater than or equal to 38 sq metres and less...  2010      3
# 9983                                                NaN  2021      6
# 9991  greater than or equal to 38 sq metres and less...  2018     11
# 9993                                                NaN  2019      5
#
# [1636 rows x 11 columns]

# %%
print("number of 'Yes VAT exclusives: '",(df['VAT Exclusive'] == 'Yes').sum())
print("number of New Dwelling house/Apartment '",(df['Description of Property'] == 'New Dwelling house /Apartment').sum())
# Out:
# number of 'Yes VAT exclusives: ' 1601
# number of New Dwelling house/Apartment ' 1636

# %%
df.loc[(df['Description of Property'] == 'New Dwelling house /Apartment') & (df['VAT Exclusive'] == 'No')]
# Out:
#      Date of Sale (dd/mm/yyyy)  \
# 199                 2017-08-05
# 479                 2016-08-23
# 738                 2014-08-09
# 822                 2016-12-23
# 1004                2011-06-10
# 1382                2012-08-22
# 1389                2013-04-07
# 1704                2010-01-27
# 2458                2018-11-14
# 2744                2015-06-11
# 3540                2013-06-28
# 4121                2012-04-01
# 4653                2010-07-29
# 5459                2012-10-12
# 5949                2016-07-29
# 5956                2017-01-08
# 6064                2017-07-13
# 6099                2015-07-31
# 6145                2015-02-27
# 6206                2019-11-01
# 6807                2014-05-12
# 6991                2019-10-24
# 7138                2016-06-16
# 7300                2017-08-05
# 7912                2015-02-04
# 8292                2010-01-03
# 8557                2018-11-01
# 8731                2010-12-11
# 8749                2018-11-12
# 9263                2018-09-02
# 9367                2015-09-06
# 9777                2013-09-27
# 9811                2018-01-06
# 9855                2021-02-11
# 9966                2021-09-30
#
#                                                 Address Postal Code  \
# 199                  Unit 271 Roseberry Hill, Newbridge         NaN
# 479                           33 Shannon Quays, Rooskey         NaN
# 738                     Woodbine Heights, Spanish Point         NaN
# 822   4 The Parade, Riverchapel Wood, Riverchapel  C...         NaN
# 1004            57 Glen Tain, Carnamuggagh, Letterkenny         NaN
# 1382  8 Cois Abhann, Excise Street/Lyster Street, At...         NaN
# 1389                               Far Finisklin, Sligo         NaN
# 1704                           no 8 emmet place, nenagh         NaN
# 2458             2 THE GRAINSTORE, BAGENALSTOWN, CARLOW         NaN
# 2744                    50 Abhainn glas, Edgeworthstown         NaN
# 3540                  48 Gleann Bhan, Ballybane, Galway         NaN
# 4121                         10 Lissoran, Ballinspittle         NaN
# 4653                             105 Lios Ard, Tulla Rd         NaN
# 5459                                  WOODVIEW, DOUGLAS         NaN
# 5949  8 Retirement Village, Windmill  Churchtown, Ma...         NaN
# 5956    APARTMENT 2, GALWAY BAY SEA VIEW APTS, SALTHILL         NaN
# 6064              55 Carraig Ean, edenderry, Co. Offaly         NaN
# 6099                  1 The Terrace, Robswall, Malahide         NaN
# 6145                    Apartment 16 Seascape, Clontarf         NaN
# 6206                     LAVAGH, BALLYHEELAN, KILNALECK         NaN
# 6807    4 Castlemurray Apt, St John's Point, Dunkineely         NaN
# 6991                             Station Road, Glenties         NaN
# 7138          Cottage and Garden, Glanbane, Trughanacmy         NaN
# 7300                 Unit 270 Roseberry Hill, Newbridge         NaN
# 7912          160 Brightwater, Konocknagore, Crosshaven         NaN
# 8292                    168 The Quadrants, Ballincollig         NaN
# 8557                       12 Seagull Park, Clogherhead         NaN
# 8731                               Balllycummin, Easkey         NaN
# 8749                   52 FIONNUISCE, DOUGHISKA, GALWAY         NaN
# 9263  6 St. Edmunds Green, St. Edmunds, St. Lomans Road   Dublin 20
# 9367                     Apt 12 Millrace Drive, Saggart         NaN
# 9777                   BON-HOMIE, BOHERBOY, CAHIRCIVEEN         NaN
# 9811       76 MARLINSTOWN PARK, MULLINGAR, CO WESTMEATH         NaN
# 9855                7 BEECHWOOD AVENUE, RAPHOE, LIFFORD         NaN
# 9966       Apartment 14, First Floor - Block B, Belvoir         NaN
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 199     Kildare  235000.00                    No            No
# 479     Leitrim  132159.00                    No            No
# 738       Clare   48242.00                    No            No
# 822     Wexford  130000.00                    No            No
# 1004    Donegal   90000.00                   Yes            No
# 1382  Westmeath  125000.00                    No            No
# 1389      Sligo   48000.00                   Yes            No
# 1704  Tipperary  140000.00                    No            No
# 2458     Carlow  107825.00                    No            No
# 2744   Longford   35000.00                    No            No
# 3540     Galway   57750.00                    No            No
# 4121       Cork   99000.00                   Yes            No
# 4653      Clare  170500.00                    No            No
# 5459       Cork  210000.00                    No            No
# 5949       Cork   89000.00                    No            No
# 5956     Galway   86242.00                    No            No
# 6064     Offaly   20000.00                    No            No
# 6099     Dublin  475000.00                    No            No
# 6145     Dublin  619500.00                    No            No
# 6206      Cavan  370000.00                    No            No
# 6807    Donegal  114276.42                    No            No
# 6991    Donegal   97500.00                    No            No
# 7138      Kerry   80000.00                    No            No
# 7300    Kildare  235000.00                    No            No
# 7912       Cork  250000.00                    No            No
# 8292       Cork  170000.00                    No            No
# 8557      Louth   70000.00                    No            No
# 8731      Sligo  172000.00                   Yes            No
# 8749     Galway   88350.00                    No            No
# 9263     Dublin  415000.00                    No            No
# 9367     Dublin  205000.00                    No            No
# 9777      Kerry   80648.00                    No            No
# 9811  Westmeath  210800.00                    No            No
# 9855    Donegal   60690.00                   Yes            No
# 9966     Dublin  476678.00                    No            No
#
#             Description of Property  \
# 199   New Dwelling house /Apartment
# 479   New Dwelling house /Apartment
# 738   New Dwelling house /Apartment
# 822   New Dwelling house /Apartment
# 1004  New Dwelling house /Apartment
# 1382  New Dwelling house /Apartment
# 1389  New Dwelling house /Apartment
# 1704  New Dwelling house /Apartment
# 2458  New Dwelling house /Apartment
# 2744  New Dwelling house /Apartment
# 3540  New Dwelling house /Apartment
# 4121  New Dwelling house /Apartment
# 4653  New Dwelling house /Apartment
# 5459  New Dwelling house /Apartment
# 5949  New Dwelling house /Apartment
# 5956  New Dwelling house /Apartment
# 6064  New Dwelling house /Apartment
# 6099  New Dwelling house /Apartment
# 6145  New Dwelling house /Apartment
# 6206  New Dwelling house /Apartment
# 6807  New Dwelling house /Apartment
# 6991  New Dwelling house /Apartment
# 7138  New Dwelling house /Apartment
# 7300  New Dwelling house /Apartment
# 7912  New Dwelling house /Apartment
# 8292  New Dwelling house /Apartment
# 8557  New Dwelling house /Apartment
# 8731  New Dwelling house /Apartment
# 8749  New Dwelling house /Apartment
# 9263  New Dwelling house /Apartment
# 9367  New Dwelling house /Apartment
# 9777  New Dwelling house /Apartment
# 9811  New Dwelling house /Apartment
# 9855  New Dwelling house /Apartment
# 9966  New Dwelling house /Apartment
#
#                               Property Size Description  Year  Month
# 199   greater than or equal to 38 sq metres and less...  2017      8
# 479   greater than or equal to 38 sq metres and less...  2016      8
# 738   greater than or equal to 38 sq metres and less...  2014      8
# 822   greater than or equal to 38 sq metres and less...  2016     12
# 1004                             less than 38 sq metres  2011      6
# 1382  greater than or equal to 38 sq metres and less...  2012      8
# 1389  greater than or equal to 38 sq metres and less...  2013      4
# 1704  greater than or equal to 38 sq metres and less...  2010      1
# 2458  greater than or equal to 38 sq metres and less...  2018     11
# 2744  greater than or equal to 38 sq metres and less...  2015      6
# 3540                             less than 38 sq metres  2013      6
# 4121                             less than 38 sq metres  2012      4
# 4653  greater than or equal to 38 sq metres and less...  2010      7
# 5459                         greater than 125 sq metres  2012     10
# 5949  greater than or equal to 38 sq metres and less...  2016      7
# 5956  greater than or equal to 38 sq metres and less...  2017      1
# 6064                             less than 38 sq metres  2017      7
# 6099  greater than or equal to 38 sq metres and less...  2015      7
# 6145  greater than or equal to 38 sq metres and less...  2015      2
# 6206                                                NaN  2019     11
# 6807  greater than or equal to 38 sq metres and less...  2014      5
# 6991                                                NaN  2019     10
# 7138  greater than or equal to 38 sq metres and less...  2016      6
# 7300  greater than or equal to 38 sq metres and less...  2017      8
# 7912  greater than or equal to 38 sq metres and less...  2015      2
# 8292  greater than or equal to 38 sq metres and less...  2010      1
# 8557                             less than 38 sq metres  2018     11
# 8731                         greater than 125 sq metres  2010     12
# 8749                                                NaN  2018     11
# 9263  greater than or equal to 38 sq metres and less...  2018      9
# 9367  greater than or equal to 38 sq metres and less...  2015      9
# 9777  greater than or equal to 38 sq metres and less...  2013      9
# 9811  greater than or equal to 38 sq metres and less...  2018      1
# 9855                                                NaN  2021      2
# 9966                                                NaN  2021      9

# %% [markdown]
# Only 35 "New Dwelling house/Apartment" are marked as 'No' for Vat Exclusive. The other 1601 are marked as 'Yes'. This is in line with the information for the revenue regarding VAT payments on new property. New properties that meet certain conditions must pay VAT at a rate of 13.5%- https://www.revenue.ie/en/property/stamp-duty/consideration/vat-exclusive-consideration.aspx#:~:text=If%20you%20buy%20or%20lease,on%20the%20VAT%2Dexclusive%20amount.
# This does not apply to second hand property which we can see in the data:

# %%
print("number of 'No' VAT exclusives: '",(df['VAT Exclusive'] == 'No').sum())
# Out:
# number of 'No' VAT exclusives: ' 8399

# %% [markdown]
# For this there is no reason to extract or remove any of the Vat Exclusive data as there are differences only for a very small amount of data and the difference may only be 13.5%

# %% [markdown]
# ### Looking at the outliers of the price data

# %% [markdown]
# As you can see there is a large range of values for the target feature of price.

# %%
print(df['Price (€)'].mean(), "mean of price data")
print(df['Price (€)'].std(), "standard deviation of price data")
# Out:
# 260260.70267600025 mean of price data
# 390170.3229389402 standard deviation of price data

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#         Price (€)
# 4518  17151248.00
# 7913  16308370.05
# 7698   9515419.00
# 915    7600000.00
# 6404   7405286.34
# 3167   6720000.00
# 3999   6680000.00
# 5961   6200000.00
# 9789   6000000.00
# 2645   5250000.00

# %%
df.sort_values(by='Price (€)', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#       Price (€)
# 2094     5500.0
# 8321     5500.0
# 4708     6000.0
# 2661     6348.0
# 2772     6608.0
# 2950     7250.0
# 2582     7300.0
# 2846     7500.0
# 5542     7500.0
# 2749     7500.0

# %%
df.loc[df['Price (€)'] <= 10000]
# Out:
#      Date of Sale (dd/mm/yyyy)  \
# 624                 2018-05-29
# 849                 2014-08-20
# 1276                2017-11-09
# 1320                2016-04-13
# 1480                2015-09-22
# 1580                2010-03-12
# 2094                2015-12-14
# 2267                2015-10-06
# 2582                2019-02-04
# 2661                2013-10-14
# 2749                2015-06-02
# 2772                2015-12-22
# 2783                2013-11-12
# 2846                2017-01-06
# 2950                2016-11-01
# 2972                2017-07-31
# 3635                2017-03-13
# 3863                2021-02-26
# 3907                2016-01-03
# 4131                2017-10-10
# 4143                2019-04-02
# 4188                2021-06-17
# 4284                2020-06-17
# 4708                2018-06-19
# 5378                2018-06-07
# 5487                2013-12-20
# 5542                2012-06-01
# 6003                2013-12-20
# 7644                2011-10-10
# 8321                2013-12-17
# 9200                2020-10-11
#
#                                                 Address Postal Code  \
# 624                    617 HOWTH ROAD, RAHENY, DUBLIN 5    Dublin 5
# 849                           Glensharrold, Carrickerry         NaN
# 1276        226 CASTLE CURRAGH HEATH, DUBLIN 15, DUBLIN   Dublin 15
# 1320                        RAEMORE, KIELDUFF, CO KERRY         NaN
# 1480  20 MILLWHARF APARTMENTS, MERCHANTS QUAY, DROGHEDA         NaN
# 1580                              MAIN STREET, KILTEALY         NaN
# 2094         19 Aranleigh Mount, Rathfarnham, Dublin 14   Dublin 14
# 2267        APT 35 BUCKINGHAM VILLAGE, DUBLIN 1, DUBLIN    Dublin 1
# 2582               74 SPRING LANE RD, BALLYVOLANE, CORK         NaN
# 2661                          Friarsquarter, Ballinrobe         NaN
# 2749                  221 Cratloewood, Old Cratloe Road         NaN
# 2772              34 Tir an Choir, Vicorschorland, TUAM         NaN
# 2783                           COILBEE, LISTOWEL, KERRY         NaN
# 2846            5 THE CLOSET APTS, ROSEMARY ST, ROSCREA         NaN
# 2950             31 SHIP STREET, DROGHEDA, COUNTY LOUTH         NaN
# 2972                    4 DUBLIN RD UPPER, TUAM, GALWAY         NaN
# 3635                  MULLAGHBOY, TULLYHUNCO, KILTRASNA         NaN
# 3863                   ST JOHNS, MAGHERACLOGHER, BUNBEG         NaN
# 3907                       LAVALLY, BALLINTOGHER, SLIGO         NaN
# 4131                  APARTMENT 1, THE SQUARE, SWINFORD         NaN
# 4143                      MEENBANE, BALLYBOFEY, DONEGAL         NaN
# 4188                    BALLYBANNON, MILFORD, CO CARLOW         NaN
# 4284                  RHUE, KILMORE, CARRICK ON SHANNON         NaN
# 4708                     NEW STREET, LITTLETON, THURLES         NaN
# 5378                     MOUNTIRWIN, GURTEEN, BALLYMOTE         NaN
# 5487  64 Rosanule, Phoenix Park Racecourse, Castleknock   Dublin 15
# 5542                           Garra, Ballyglunin, Tuam         NaN
# 6003  13 Phoenix Park Way, Phoenix Park Racecourse, ...   Dublin 15
# 7644                               Rathvilla, Edenderry         NaN
# 8321                       SHRAIGH, BUNNAHOWEN, BALLINA         NaN
# 9200                   8 ORANHILL AVE, ORANMORE, GALWAY         NaN
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 624      Dublin   10000.00                    No            No
# 849    Limerick    8000.00                    No            No
# 1276     Dublin    8697.91                    No            No
# 1320      Kerry   10000.00                    No            No
# 1480      Louth    9039.78                    No            No
# 1580    Wexford   10000.00                    No            No
# 2094     Dublin    5500.00                    No            No
# 2267     Dublin   10000.00                    No            No
# 2582       Cork    7300.00                    No            No
# 2661       Mayo    6348.00                    No            No
# 2749   Limerick    7500.00                    No           Yes
# 2772     Galway    6608.00                    No           Yes
# 2783      Kerry   10000.00                    No            No
# 2846  Tipperary    7500.00                    No            No
# 2950      Louth    7250.00                    No            No
# 2972     Galway   10000.00                   Yes            No
# 3635      Cavan   10000.00                    No            No
# 3863    Donegal    9000.00                   Yes            No
# 3907      Sligo   10000.00                    No            No
# 4131       Mayo   10000.00                    No            No
# 4143    Donegal   10000.00                    No            No
# 4188     Carlow   10000.00                    No            No
# 4284  Roscommon   10000.00                    No            No
# 4708  Tipperary    6000.00                   Yes            No
# 5378      Sligo   10000.00                    No            No
# 5487     Dublin    8000.00                    No           Yes
# 5542     Galway    7500.00                   Yes            No
# 6003     Dublin    8000.00                    No           Yes
# 7644     Offaly   10000.00                    No            No
# 8321       Mayo    5500.00                   Yes            No
# 9200     Galway    7770.00                    No            No
#
#                     Description of Property  \
# 624   Second-Hand Dwelling house /Apartment
# 849   Second-Hand Dwelling house /Apartment
# 1276  Second-Hand Dwelling house /Apartment
# 1320  Second-Hand Dwelling house /Apartment
# 1480  Second-Hand Dwelling house /Apartment
# 1580  Second-Hand Dwelling house /Apartment
# 2094  Second-Hand Dwelling house /Apartment
# 2267  Second-Hand Dwelling house /Apartment
# 2582  Second-Hand Dwelling house /Apartment
# 2661  Second-Hand Dwelling house /Apartment
# 2749          New Dwelling house /Apartment
# 2772          New Dwelling house /Apartment
# 2783  Second-Hand Dwelling house /Apartment
# 2846  Second-Hand Dwelling house /Apartment
# 2950  Second-Hand Dwelling house /Apartment
# 2972  Second-Hand Dwelling house /Apartment
# 3635  Second-Hand Dwelling house /Apartment
# 3863  Second-Hand Dwelling house /Apartment
# 3907  Second-Hand Dwelling house /Apartment
# 4131  Second-Hand Dwelling house /Apartment
# 4143  Second-Hand Dwelling house /Apartment
# 4188  Second-Hand Dwelling house /Apartment
# 4284  Second-Hand Dwelling house /Apartment
# 4708  Second-Hand Dwelling house /Apartment
# 5378  Second-Hand Dwelling house /Apartment
# 5487          New Dwelling house /Apartment
# 5542  Second-Hand Dwelling house /Apartment
# 6003          New Dwelling house /Apartment
# 7644  Second-Hand Dwelling house /Apartment
# 8321  Second-Hand Dwelling house /Apartment
# 9200  Second-Hand Dwelling house /Apartment
#
#                               Property Size Description  Year  Month
# 624                                                 NaN  2018      5
# 849                                                 NaN  2014      8
# 1276                                                NaN  2017     11
# 1320                                                NaN  2016      4
# 1480                                                NaN  2015      9
# 1580                                                NaN  2010      3
# 2094                                                NaN  2015     12
# 2267                                                NaN  2015     10
# 2582                                                NaN  2019      2
# 2661                                                NaN  2013     10
# 2749                             less than 38 sq metres  2015      6
# 2772  greater than or equal to 38 sq metres and less...  2015     12
# 2783                                                NaN  2013     11
# 2846                                                NaN  2017      1
# 2950                                                NaN  2016     11
# 2972                                                NaN  2017      7
# 3635                                                NaN  2017      3
# 3863                                                NaN  2021      2
# 3907                                                NaN  2016      1
# 4131                                                NaN  2017     10
# 4143                                                NaN  2019      4
# 4188                                                NaN  2021      6
# 4284                                                NaN  2020      6
# 4708                                                NaN  2018      6
# 5378                                                NaN  2018      6
# 5487  greater than or equal to 38 sq metres and less...  2013     12
# 5542                                                NaN  2012      6
# 6003  greater than or equal to 38 sq metres and less...  2013     12
# 7644                                                NaN  2011     10
# 8321                                                NaN  2013     12
# 9200                                                NaN  2020     10

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
# Out:
# array([[<AxesSubplot:title={'center':'Price (€)'}>]], dtype=object)

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#         Price (€)
# 4518  17151248.00
# 7913  16308370.05
# 7698   9515419.00
# 915    7600000.00
# 6404   7405286.34
# 3167   6720000.00
# 3999   6680000.00
# 5961   6200000.00
# 9789   6000000.00
# 2645   5250000.00

# %% [markdown]
# The sale of property worth €17,151,248 and €16308370.05
# has been dropped. As these is a large blocks of apartments. Thus, it does not makes sense to compare it to other sing dwellings.

# %%
df[((df['Price (€)'] == 17151248.00))].index
# Out:
# Int64Index([], dtype='int64')

# %%
df = df.drop(index=7913)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-fc16f04412b6> in <module>
# ----> 1 df = df.drop(index=7913)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[7913] not found in axis'

# %%
df = df.drop(index=4518)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-6a736f2f81c8> in <module>
# ----> 1 df = df.drop(index=4518)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[4518] not found in axis'

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#        Price (€)
# 7698  9515419.00
# 915   7600000.00
# 6404  7405286.34
# 3167  6720000.00
# 3999  6680000.00
# 5961  6200000.00
# 9789  6000000.00
# 2645  5250000.00
# 4438  5127753.00
# 2542  5000000.00

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
# Out:
# array([[<AxesSubplot:title={'center':'Price (€)'}>]], dtype=object)

# %% [markdown]
# #### Summary of data quality plan

# %% [markdown]
# | Variable Name | Data Quality Issue | Handling Stratergy |
# | :- | :- | :- |
# | Price (€) | Outliers | Remove outliers |
# | Postal Code | Missing data |Do nothing|
# | Description of Property | Descriptions were in Irish | Irish descriptions were tranlated so there were only two unique values for consistency |
# | Propert Size Description | Missing data | feature was dropped as data was vague and the majority was missing |
# | VAT exclusive | Provides varying info | Do nothing |

# %%
df[numeric_columns].describe().T
# Out:
#              count           mean            std     min       25%       50%  \
# Price (€)  10000.0  260260.702676  390170.322939  5500.0  120000.0  200000.0
#
#                  75%         max
# Price (€)  308370.08  17151248.0

# %%
df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                 1860     22
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description   1029      4
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                        Dublin 15
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                            freq
# Address                       2
# Postal Code                 232
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description   723

# %% [markdown]
# ### Applying solutions to new csv file with the issues addressed:

# %%
df.to_csv('cleanedCSV_after_data_quality_plan-ppr-17350796.csv', index=False)

# %% [markdown]
# ## Part 3: Exploring the relationships between feature pairs:

# %% [markdown]
# We want to be able to say something about the price data.
# The features that I will look at for pairwise interaction:
#
# - County
# - Year
# - Month
# - Month/Year
# - Description of property
#
# The reasons for these choices, are these factors could all give insight and to provide markers into house prices.

# %%
df.plot.scatter(x = 'Price (€)', y = 'Month')
# Out:
# <AxesSubplot:xlabel='Price (€)', ylabel='Month'>

# %% [markdown]
# Need to address the differences in the tax.
