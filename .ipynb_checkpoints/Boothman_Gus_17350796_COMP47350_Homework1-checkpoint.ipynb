# %% [markdown]
# <h1><center>From the finacial crash to the crippling housing crisis: What is the future of Ireland's housing crisis?
# </center></h1>

# %% [markdown]
#
# <h1><center>17350796
# </center></h1>

# %% [markdown]
# <h1><center>Introduction</center></h1>

# %% [markdown]
# Here I give an overview of the notebook. The data examined is from the residential property price register. It includes the date of sale, price and address of residential propeperties purchesed in the Republic of Ireland since the 1st of January 2010.
# The aim of this assignment is to build a data analytics solution for the prediction of residential property price in Ireland.
#
# This type of analysis is particularly pertinent as house prices in recent years has seen massive increases. Irish house prices have increased by 5% only in the last year. It is a crisis situation and thus, prediction tools are becoming more and more important. Qualitiy predicition tools will be crucial in determing how damaging this situation could become.
#
# This notebook begins with a data quality report. The CSV is read in and the data is put in Pandas data frame to be analysed. All features are analysed for errors and the data frame is checked for logical integrity as a whole. With this intial clean up and with the errors flagged, this update dataframe is saved to a new CSV file. A table of descriptive statistics  for continous and categorical features are also displayed in this section. Histograms, box plots, and bar plots are made and interpreted. The findings both discussed in this notebook and also in a seperate PDF file labelled as the Data quality report pdf file. A detailed description of my understanding of the data is included in this report.
#
#
# The second part of this notebook involves the data quality plan. Where there are potential problems with a feature or row of data, the problem and solutions to the problem are discussed. The solutions are then implenmented on the data frame. The data frame with the solutions applied is then saved to a new CSV file. A seperate PDF file titled data quality plan is also supplied seperate to this notebook.
#
#
# The third part is where the relationships between features are explored. Only features I deemed promising in the prediction of the target feature price were included in this part. The necessary continous-continous plots and continous-categorical plots were made. A short paragragh is included in this section explaining the story so far in regards to evalutating the price data.
#
#
# The final section invovlves adding new features in order get a better understanding the the target data price. The choices I have made have all been justified with figures and plots. As well as the findings being discussed. These new features are then added to a new CSV file with a clear name.
#
#
#
# Finally, a conclusion is found at the end of the notebook whereby I sum up my thoughts of the process as a whole and briefly give an overivew of my findings.

# %% [markdown]
# <h1><center>Part 1: Preparing the data from CSV</center></h1>

# %%
import pandas as pd

from pandas.plotting import table
# import dataframe_image as dfi

import numpy as np
from numpy import array

import matplotlib.pyplot as plt

# %matplotlib inline

from matplotlib.backends.backend_pdf import PdfPages


from scipy import stats
#for cat plots
import seaborn as sns

# %% [markdown]
# - Throughout the notebook the main dataframe will be assigned as 'df' with subsequent dataframes being assigned appropriate variable names.

# %%
df = pd.read_csv('ppr-17350796.csv', keep_default_na=True, sep=',\s+', delimiter=',', skipinitialspace=True)

# %% [markdown]
# ## First 5 rows

# %%
df.head(5)
# Out:
#   Date of Sale (dd/mm/yyyy)                               Address Postal Code  \
# 0                06/05/2016    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8
# 1                22/12/2014  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8
# 2                22/05/2020    17 MERRION PARK, BLACKROCK, DUBLIN         NaN
# 3                27/11/2014      KNOCKROE, RATHMOYLE, CO.KILKENNY         NaN
# 4                22/11/2018    15 SHANNON PARK, LIFFORD RD, ENNIS         NaN
#
#      County    Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin  €630,000.00                    No            No
# 1    Dublin  €281,000.00                    No            No
# 2    Dublin  €560,000.00                    No            No
# 3  Kilkenny   €46,000.00                    No            No
# 4     Clare  €204,000.00                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
# 2  Second-Hand Dwelling house /Apartment                       NaN
# 3  Second-Hand Dwelling house /Apartment                       NaN
# 4  Second-Hand Dwelling house /Apartment                       NaN

# %% [markdown]
# ## Last 5 rows

# %% [markdown]
# Displaying the last 5 rows

# %%
df.tail(5)
# Out:
#      Date of Sale (dd/mm/yyyy)                                    Address  \
# 9995                15/12/2017           KNOCKASARTNETT, KILLARNEY, KERRY
# 9996                18/12/2012    17 the court, cypress downs, templeogue
# 9997                14/12/2016  THE LOG CABIN, FORGE COTTAGE, CULLENSTOWN
# 9998                19/06/2017               CARRIG RD, PARKMORE, ROSCREA
# 9999                02/11/2017         26 KILSHANE RD, FINGLAS, DUBLIN 11
#
#      Postal Code     County    Price (€) Not Full Market Price VAT Exclusive  \
# 9995         NaN      Kerry  €200,000.00                    No            No
# 9996         NaN     Dublin  €605,000.00                    No            No
# 9997         NaN    Wexford   €46,666.67                    No            No
# 9998         NaN  Tipperary  €176,000.00                    No            No
# 9999   Dublin 11     Dublin   €86,738.06                   Yes            No
#
#                     Description of Property Property Size Description
# 9995  Second-Hand Dwelling house /Apartment                       NaN
# 9996  Second-Hand Dwelling house /Apartment                       NaN
# 9997  Second-Hand Dwelling house /Apartment                       NaN
# 9998  Second-Hand Dwelling house /Apartment                       NaN
# 9999  Second-Hand Dwelling house /Apartment                       NaN

# %% [markdown]
# #### Shape of data frame

# %% [markdown]
# Display number of rows and columns- 10000 = Rows, 9 = columns

# %%
# number of rows and columns
df.shape
# Out:
# (10000, 9)

# %% [markdown]
# The data is currently all read as type object. The data needs to be change to the appropriate data type for it to be accurately analysed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date of Sale (dd/mm/yyyy)  10000 non-null  object
#  1   Address                    10000 non-null  object
#  2   Postal Code                1860 non-null   object
#  3   County                     10000 non-null  object
#  4   Price (€)                  10000 non-null  object
#  5   Not Full Market Price      10000 non-null  object
#  6   VAT Exclusive              10000 non-null  object
#  7   Description of Property    10000 non-null  object
#  8   Property Size Description  1029 non-null   object
# dtypes: object(9)
# memory usage: 703.2+ KB

# %% [markdown]
# #### Looking at the column names for errrors

# %%
df.columns
# Out:
# Index(['Date of Sale (dd/mm/yyyy)', 'Address', 'Postal Code', 'County',
#        'Price (€)', 'Not Full Market Price', 'VAT Exclusive',
#        'Description of Property', 'Property Size Description'],
#       dtype='object')

# %% [markdown]
# ### Editing price data in oder to change its type

# %%
# Converting price to float, you need to remove all symbols from strings for the command to work. 



df['Price (€)'] = df['Price (€)'].str.replace(',', '')


df['Price (€)'] = df['Price (€)'].str.replace('€', '')

df['Price (€)'] = df['Price (€)'].astype(float)

df[['Price (€)']]
# Out:
#       Price (€)
# 0     630000.00
# 1     281000.00
# 2     560000.00
# 3      46000.00
# 4     204000.00
# ...         ...
# 9995  200000.00
# 9996  605000.00
# 9997   46666.67
# 9998  176000.00
# 9999   86738.06
#
# [10000 rows x 1 columns]

# %% [markdown]
# These object features have been changed to categorical as they each describe unique values

# %% [markdown]
# ### Changing data types

# %% [markdown]
# - The only continous data type is price
# - Date has been changed to datetime
# - The rest are deemed to be categroical features as they are set number of unique descriptions.

# %%
# There are a set number of unique counties
df['County'] = df['County'].astype('category')

# There are a set number of unique descriptions

df['Description of Property'] = df['Description of Property'].astype('category')

df['Address'] = df['Address'].astype('category')


# Postal code has a set number of unique categories
df['Postal Code'] = df['Postal Code'].astype('category')

# There are a set number of property size descriptions
df['Property Size Description'] = df['Property Size Description'].astype('category')

# this is just yes or no data there for categorical 
df['VAT Exclusive'] = df['VAT Exclusive'].astype('category')

# this is just yes or no data so it is cateogrical 
df['Not Full Market Price'] = df['Not Full Market Price'].astype('category')






df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)      object
# Address                      category
# Postal Code                  category
# County                       category
# Price (€)                     float64
# Not Full Market Price        category
# VAT Exclusive                category
# Description of Property      category
# Property Size Description    category
# dtype: object

# %%
# converting dates to date data type
df['Date of Sale (dd/mm/yyyy)'] = pd.to_datetime(df['Date of Sale (dd/mm/yyyy)'])

df.dtypes
# Out:
# Date of Sale (dd/mm/yyyy)    datetime64[ns]
# Address                            category
# Postal Code                        category
# County                             category
# Price (€)                           float64
# Not Full Market Price              category
# VAT Exclusive                      category
# Description of Property            category
# Property Size Description          category
# dtype: object

# %%
df.head(4)
# Out:
#   Date of Sale (dd/mm/yyyy)                               Address Postal Code  \
# 0                2016-06-05    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8
# 1                2014-12-22  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8
# 2                2020-05-22    17 MERRION PARK, BLACKROCK, DUBLIN         NaN
# 3                2014-11-27      KNOCKROE, RATHMOYLE, CO.KILKENNY         NaN
#
#      County  Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin   630000.0                    No            No
# 1    Dublin   281000.0                    No            No
# 2    Dublin   560000.0                    No            No
# 3  Kilkenny    46000.0                    No            No
#
#                  Description of Property Property Size Description
# 0  Second-Hand Dwelling house /Apartment                       NaN
# 1  Second-Hand Dwelling house /Apartment                       NaN
# 2  Second-Hand Dwelling house /Apartment                       NaN
# 3  Second-Hand Dwelling house /Apartment                       NaN

# %% [markdown]
# ### Renaming Date of Sale (dd/mm/yyyy)	to Date of Sale (yyyy/mm/dd)

# %% [markdown]
# - This is was necessary as the chaning of type caused the year and day to swap.

# %%
df.rename(columns={"Date of Sale (dd/mm/yyyy)":"Date of Sale (yyyy/mm/dd)"}, inplace=True)

# %% [markdown]
# ### Splitting Year and Month into their own category

# %% [markdown]
# - Year and Month have been split early in the analysis in order to see trends that go from month to month and year to year more easily
# - It will also be easier to asses errors with regards to date this way.

# %%
df['Month'] = pd.DatetimeIndex(df['Date of Sale (yyyy/mm/dd)']).month
df['Year'] = pd.DatetimeIndex(df['Date of Sale (yyyy/mm/dd)']).year


df.head(10)
# Out:
#   Date of Sale (yyyy/mm/dd)                                        Address  \
# 0                2016-06-05             21 CURZON ST, PORTOBELLO, DUBLIN 8
# 1                2014-12-22           44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8
# 2                2020-05-22             17 MERRION PARK, BLACKROCK, DUBLIN
# 3                2014-11-27               KNOCKROE, RATHMOYLE, CO.KILKENNY
# 4                2018-11-22             15 SHANNON PARK, LIFFORD RD, ENNIS
# 5                2016-01-31  27 MOUNT DRUMMOND SQ, HAROLDS CROSS, DUBLIN 6
# 6                2021-11-30         10 HOLLOW WAY, OAKVIEW VILLAGE, TRALEE
# 7                2016-02-05                            Ballygibbon, Nenagh
# 8                2018-12-03              RANDLESTOWN, BALLYCOGLEY, WEXFORD
# 9                2015-11-17               3 RIVER STREET, CLARA, CO OFFALY
#
#   Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin 8     Dublin   630000.0                    No            No
# 1    Dublin 8     Dublin   281000.0                    No            No
# 2         NaN     Dublin   560000.0                    No            No
# 3         NaN   Kilkenny    46000.0                    No            No
# 4         NaN      Clare   204000.0                    No            No
# 5    Dublin 6     Dublin   375000.0                    No            No
# 6         NaN      Kerry   182000.0                    No            No
# 7         NaN  Tipperary   264317.0                    No           Yes
# 8         NaN    Wexford    70000.0                    No            No
# 9         NaN     Offaly    34500.0                    No            No
#
#                  Description of Property   Property Size Description  Month  \
# 0  Second-Hand Dwelling house /Apartment                         NaN      6
# 1  Second-Hand Dwelling house /Apartment                         NaN     12
# 2  Second-Hand Dwelling house /Apartment                         NaN      5
# 3  Second-Hand Dwelling house /Apartment                         NaN     11
# 4  Second-Hand Dwelling house /Apartment                         NaN     11
# 5  Second-Hand Dwelling house /Apartment                         NaN      1
# 6  Second-Hand Dwelling house /Apartment                         NaN     11
# 7          New Dwelling house /Apartment  greater than 125 sq metres      2
# 8  Second-Hand Dwelling house /Apartment                         NaN     12
# 9  Second-Hand Dwelling house /Apartment                         NaN     11
#
#    Year
# 0  2016
# 1  2014
# 2  2020
# 3  2014
# 4  2018
# 5  2016
# 6  2021
# 7  2016
# 8  2018
# 9  2015

# %% [markdown]
# ### Checking integrity of Year and Month sales:

# %% [markdown]
# - There are no dates greater than the year 2022 or less than 2010 which is consistent to the orginal description of the CSV file.

# %%
df.loc[(df['Year'] > 2022)]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %%
df.loc[(df['Year'] < 2010)]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %% [markdown]
# #### Dates in the future:

# %% [markdown]
# - We can see there is sales in the future below. I am not sure how this is possible.
# - My hypothesis is that it was a data entry mistake. i.e the day was entered as the month and the month was entered as the day.
# - Thus, I believe the following houses were actually sold in January of this year.
# - This is corrected later in the notebook

# %%
df.loc[(df['Year'] == 2022) & 
                         (df['Month']> 0)]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 1032                2022-04-01
# 2742                2022-07-01
# 3042                2022-04-01
# 3900                2022-07-01
# 4358                2022-12-01
# 5494                2022-12-01
# 5540                2022-05-01
# 6237                2022-06-01
# 6567                2022-12-01
# 8340                2022-07-01
#
#                                                 Address Postal Code  \
# 1032                 5 STRAFFAN GATE, STRAFFAN, KILDARE         NaN
# 2742   78 HILL OF DOWN, SPENCER DOCK, MAYOR ST DUBLIN 1    Dublin 1
# 3042          4 CNOC BEAG, LIS CARA, CARRICK ON SHANNON         NaN
# 3900              36 THE CAMMOCK, MOUNT BROWN, DUBLIN 8    Dublin 8
# 4358  74 DAKOTA COURT, ROYAL CANAL BANK, PHIBSBOROUG...    Dublin 7
# 5494                    RUSHLAKE, WOODLAWN, BALLINASLOE         NaN
# 5540                        BIRCHILL, DROMBANE, THURLES         NaN
# 6237               48 CROMCASTLE AVE, COOLOCK, DUBLIN 5    Dublin 5
# 6567                           5 Cul na Claishe, Tralee         NaN
# 8340                           TISSASSON, KINSALE, CORK         NaN
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 1032    Kildare   186974.0                    No            No
# 2742     Dublin   382000.0                    No            No
# 3042    Leitrim   161000.0                   Yes            No
# 3900     Dublin   231500.0                    No            No
# 4358     Dublin   278000.0                    No            No
# 5494     Galway   216500.0                    No            No
# 5540  Tipperary   160000.0                    No            No
# 6237     Dublin   290000.0                   Yes            No
# 6567      Kerry    30000.0                    No           Yes
# 8340       Cork   260000.0                    No            No
#
#                     Description of Property Property Size Description  Month  \
# 1032  Second-Hand Dwelling house /Apartment                       NaN      4
# 2742  Second-Hand Dwelling house /Apartment                       NaN      7
# 3042  Second-Hand Dwelling house /Apartment                       NaN      4
# 3900  Second-Hand Dwelling house /Apartment                       NaN      7
# 4358  Second-Hand Dwelling house /Apartment                       NaN     12
# 5494  Second-Hand Dwelling house /Apartment                       NaN     12
# 5540  Second-Hand Dwelling house /Apartment                       NaN      5
# 6237  Second-Hand Dwelling house /Apartment                       NaN      6
# 6567          New Dwelling house /Apartment                       NaN     12
# 8340  Second-Hand Dwelling house /Apartment                       NaN      7
#
#       Year
# 1032  2022
# 2742  2022
# 3042  2022
# 3900  2022
# 4358  2022
# 5494  2022
# 5540  2022
# 6237  2022
# 6567  2022
# 8340  2022

# %%
df.loc[(df['Year'] == 2022) & 
                         (df['Month']> 0)]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 1032                2022-04-01
# 2742                2022-07-01
# 3042                2022-04-01
# 3900                2022-07-01
# 4358                2022-12-01
# 5494                2022-12-01
# 5540                2022-05-01
# 6237                2022-06-01
# 6567                2022-12-01
# 8340                2022-07-01
#
#                                                 Address Postal Code  \
# 1032                 5 STRAFFAN GATE, STRAFFAN, KILDARE         NaN
# 2742   78 HILL OF DOWN, SPENCER DOCK, MAYOR ST DUBLIN 1    Dublin 1
# 3042          4 CNOC BEAG, LIS CARA, CARRICK ON SHANNON         NaN
# 3900              36 THE CAMMOCK, MOUNT BROWN, DUBLIN 8    Dublin 8
# 4358  74 DAKOTA COURT, ROYAL CANAL BANK, PHIBSBOROUG...    Dublin 7
# 5494                    RUSHLAKE, WOODLAWN, BALLINASLOE         NaN
# 5540                        BIRCHILL, DROMBANE, THURLES         NaN
# 6237               48 CROMCASTLE AVE, COOLOCK, DUBLIN 5    Dublin 5
# 6567                           5 Cul na Claishe, Tralee         NaN
# 8340                           TISSASSON, KINSALE, CORK         NaN
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 1032    Kildare   186974.0                    No            No
# 2742     Dublin   382000.0                    No            No
# 3042    Leitrim   161000.0                   Yes            No
# 3900     Dublin   231500.0                    No            No
# 4358     Dublin   278000.0                    No            No
# 5494     Galway   216500.0                    No            No
# 5540  Tipperary   160000.0                    No            No
# 6237     Dublin   290000.0                   Yes            No
# 6567      Kerry    30000.0                    No           Yes
# 8340       Cork   260000.0                    No            No
#
#                     Description of Property Property Size Description  Month  \
# 1032  Second-Hand Dwelling house /Apartment                       NaN      4
# 2742  Second-Hand Dwelling house /Apartment                       NaN      7
# 3042  Second-Hand Dwelling house /Apartment                       NaN      4
# 3900  Second-Hand Dwelling house /Apartment                       NaN      7
# 4358  Second-Hand Dwelling house /Apartment                       NaN     12
# 5494  Second-Hand Dwelling house /Apartment                       NaN     12
# 5540  Second-Hand Dwelling house /Apartment                       NaN      5
# 6237  Second-Hand Dwelling house /Apartment                       NaN      6
# 6567          New Dwelling house /Apartment                       NaN     12
# 8340  Second-Hand Dwelling house /Apartment                       NaN      7
#
#       Year
# 1032  2022
# 2742  2022
# 3042  2022
# 3900  2022
# 4358  2022
# 5494  2022
# 5540  2022
# 6237  2022
# 6567  2022
# 8340  2022

# %% [markdown]
# - No dates less than or equal to 2009, which makes sense

# %%
df.loc[(df['Year'] <= 2009)]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %% [markdown]
# ####  Checking logical integrity of months:

# %% [markdown]
# - As we can see there are no months less than 1 or greater than 12 which is correct.

# %%
df.loc[(df['Month'] < 1) | 
                         (df['Month']> 12)]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %% [markdown]
# - There should be no reason to check if number of days is correct for each date as the datetime data type should throw an error if there is one.
#
# - It is of course possible that a day or a month was entered incorrectly, but there is no meaning full way of correcting this other evualating how they appear in the dataframe which we have done.

# %%
df.dtypes
# Out:
# Date of Sale (yyyy/mm/dd)    datetime64[ns]
# Address                            category
# Postal Code                        category
# County                             category
# Price (€)                           float64
# Not Full Market Price              category
# VAT Exclusive                      category
# Description of Property            category
# Property Size Description          category
# Month                                 int64
# Year                                  int64
# dtype: object

# %% [markdown]
# ### Looking for duplicate rows and columns

# %% [markdown]
# - From first inspection of non unique values, all values seem plausible.

# %%
df.nunique()
# Out:
# Date of Sale (yyyy/mm/dd)    2759
# Address                      9980
# Postal Code                    22
# County                         26
# Price (€)                    2285
# Not Full Market Price           2
# VAT Exclusive                   2
# Description of Property         3
# Property Size Description       4
# Month                          12
# Year                           13
# dtype: int64

# %% [markdown]
# ### Checking Null values

# %% [markdown]
# - As you can see both Postal Code and Property Size Description have large amounts of null values. All other features have no null values, this is a postive sign.

# %%
df.isnull().sum()
# Out:
# Date of Sale (yyyy/mm/dd)       0
# Address                         0
# Postal Code                  8140
# County                          0
# Price (€)                       0
# Not Full Market Price           0
# VAT Exclusive                   0
# Description of Property         0
# Property Size Description    8971
# Month                           0
# Year                            0
# dtype: int64

# %% [markdown]
# ## Postal Codes Review

# %% [markdown]
# The county Dublin appears 3193 times, this is the highest proportion.

# %%
df.loc[df['County'].isin(['Dublin'])]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 0                   2016-06-05
# 1                   2014-12-22
# 2                   2020-05-22
# 5                   2016-01-31
# 10                  2015-06-15
# ...                        ...
# 9975                2013-04-11
# 9988                2020-10-03
# 9993                2019-05-12
# 9996                2012-12-18
# 9999                2017-02-11
#
#                                                Address Postal Code  County  \
# 0                   21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8  Dublin
# 1                 44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8  Dublin
# 2                   17 MERRION PARK, BLACKROCK, DUBLIN         NaN  Dublin
# 5        27 MOUNT DRUMMOND SQ, HAROLDS CROSS, DUBLIN 6    Dublin 6  Dublin
# 10    Apt 350 Block 8B, Tallaght Cross West, Dublin 24   Dublin 24  Dublin
# ...                                                ...         ...     ...
# 9975        29 Carndonagh Drive, Donaghmede, Dublin 13   Dublin 13  Dublin
# 9988        44 GERALDSTOWN WOODS, SANTRY AVE, DUBLIN 9    Dublin 9  Dublin
# 9993            6 Edenbrook Green, Edenbrook, Citywest         NaN  Dublin
# 9996           17 the court, cypress downs, templeogue         NaN  Dublin
# 9999                26 KILSHANE RD, FINGLAS, DUBLIN 11   Dublin 11  Dublin
#
#       Price (€) Not Full Market Price VAT Exclusive  \
# 0     630000.00                    No            No
# 1     281000.00                    No            No
# 2     560000.00                    No            No
# 5     375000.00                    No            No
# 10     99433.75                    No           Yes
# ...         ...                   ...           ...
# 9975  190000.00                    No            No
# 9988  170000.00                    No            No
# 9993  348017.61                    No           Yes
# 9996  605000.00                    No            No
# 9999   86738.06                   Yes            No
#
#                     Description of Property  \
# 0     Second-Hand Dwelling house /Apartment
# 1     Second-Hand Dwelling house /Apartment
# 2     Second-Hand Dwelling house /Apartment
# 5     Second-Hand Dwelling house /Apartment
# 10            New Dwelling house /Apartment
# ...                                     ...
# 9975  Second-Hand Dwelling house /Apartment
# 9988  Second-Hand Dwelling house /Apartment
# 9993          New Dwelling house /Apartment
# 9996  Second-Hand Dwelling house /Apartment
# 9999  Second-Hand Dwelling house /Apartment
#
#                               Property Size Description  Month  Year
# 0                                                   NaN      6  2016
# 1                                                   NaN     12  2014
# 2                                                   NaN      5  2020
# 5                                                   NaN      1  2016
# 10    greater than or equal to 38 sq metres and less...      6  2015
# ...                                                 ...    ...   ...
# 9975                                                NaN      4  2013
# 9988                                                NaN     10  2020
# 9993                                                NaN      5  2019
# 9996                                                NaN     12  2012
# 9999                                                NaN      2  2017
#
# [3193 rows x 11 columns]

# %%
df["Postal Code"].describe().T
# Out:
# count          1860
# unique           22
# top       Dublin 15
# freq            232
# Name: Postal Code, dtype: object

# %% [markdown]
# Only 58% percent have a set post code in Dublin, while this is low. I have opted to keep the data as it still could provide relevent statisical inferences to the area of Dublin.

# %% [markdown]
# ### Assigning all categorical features to a variable

# %%
category_columns = df.select_dtypes(['category']).columns
df[category_columns].head()
# Out:
#                                 Address Postal Code    County  \
# 0    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8    Dublin
# 1  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8    Dublin
# 2    17 MERRION PARK, BLACKROCK, DUBLIN         NaN    Dublin
# 3      KNOCKROE, RATHMOYLE, CO.KILKENNY         NaN  Kilkenny
# 4    15 SHANNON PARK, LIFFORD RD, ENNIS         NaN     Clare
#
#   Not Full Market Price VAT Exclusive                Description of Property  \
# 0                    No            No  Second-Hand Dwelling house /Apartment
# 1                    No            No  Second-Hand Dwelling house /Apartment
# 2                    No            No  Second-Hand Dwelling house /Apartment
# 3                    No            No  Second-Hand Dwelling house /Apartment
# 4                    No            No  Second-Hand Dwelling house /Apartment
#
#   Property Size Description
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %% [markdown]
# ### Changing Postal Code and Propery Description NaN values to 'None' as these features contain the null values.

# %% [markdown]
# - As both features are categorical there NaN values can be safely change to 'None'. There will be no mathematical opertations preformed on these features where keeping the NaN value would be useful.
# - This logic is discussed here: https://stackoverflow.com/questions/17534106/what-is-the-difference-between-nan-and-none

# %%
df['Postal Code']= df['Postal Code'].astype('object')
df['Postal Code']= df['Postal Code'].fillna('None')


df['Property Size Description']= df['Property Size Description'].astype('object')
df['Property Size Description']= df['Property Size Description'].fillna('None')

# %%
df['Postal Code']= df['Postal Code'].astype('category')


df['Property Size Description']= df['Property Size Description'].astype('category')

# %%
df.tail(5)
# Out:
#      Date of Sale (yyyy/mm/dd)                                    Address  \
# 9995                2017-12-15           KNOCKASARTNETT, KILLARNEY, KERRY
# 9996                2012-12-18    17 the court, cypress downs, templeogue
# 9997                2016-12-14  THE LOG CABIN, FORGE COTTAGE, CULLENSTOWN
# 9998                2017-06-19               CARRIG RD, PARKMORE, ROSCREA
# 9999                2017-02-11         26 KILSHANE RD, FINGLAS, DUBLIN 11
#
#      Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 9995        None      Kerry  200000.00                    No            No
# 9996        None     Dublin  605000.00                    No            No
# 9997        None    Wexford   46666.67                    No            No
# 9998        None  Tipperary  176000.00                    No            No
# 9999   Dublin 11     Dublin   86738.06                   Yes            No
#
#                     Description of Property Property Size Description  Month  \
# 9995  Second-Hand Dwelling house /Apartment                      None     12
# 9996  Second-Hand Dwelling house /Apartment                      None     12
# 9997  Second-Hand Dwelling house /Apartment                      None     12
# 9998  Second-Hand Dwelling house /Apartment                      None      6
# 9999  Second-Hand Dwelling house /Apartment                      None      2
#
#       Year
# 9995  2017
# 9996  2012
# 9997  2016
# 9998  2017
# 9999  2017

# %% [markdown]
# ### Looking at all the unique categories and their values:

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(dropna=False))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
#
# Postal Code
# None         8140
# Dublin 15     232
# Dublin 18     143
# Dublin 9      119
# Dublin 8      115
# Dublin 24     114
# Dublin 4      109
# Dublin 12     104
# Dublin 16      96
# Dublin 11      93
# Dublin 7       88
# Dublin 13      85
# Dublin 14      84
# Dublin 3       82
# Dublin 5       78
# Dublin 1       77
# Dublin 6       66
# Dublin 22      54
# Dublin 2       34
# Dublin 20      25
# Dublin 17      24
# Dublin 10      20
# Dublin 6w      18
# Name: Postal Code, dtype: int64
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8363
# New Dwelling house /Apartment            1636
# Teach/Árasán Cónaithe Atháimhe              1
# Name: Description of Property, dtype: int64
#
# Property Size Description
# None                                                                 8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64

# %% [markdown]
# ### Not Full  Market Price analysis

# %% [markdown]
# - As you can see from above., there are 9552 'No' rows and 448 'Yes' rows. This means over 95% of the houses sold for full market price.
# - There is a small amount that did not sell for full market price. From research, this can be due to a number of reasons. For example, the dwelling may have been purchased at a reduced price under the Affordable Homes Scheme or only a fraction of the dwelling was sold.
# - I will wait untill later in the data analysis procedure before making a decision on whether to retain this information or not.
# - Reference https://www.propertypriceregister.ie/Website/npsra/pprweb.nsf/page/ppr-price-en

# %% [markdown]
# ## Description of Property Iregularity

# %% [markdown]
# - 'Description of Property' shows 3 unique properties. "Teach/Árasán Cónaithe Atháimhe" is the Irish translation of "Second-Hand Dwelling house /Apartment".
# - While it is important that Irish people practice their native language for the purpose of data analytics it makes sense to change this to the english category for consistency.

# %%
# getting index of where the illogical data is 
df.index[df['Description of Property'] == 'Teach/Árasán Cónaithe Atháimhe'].tolist()
# Out:
# [5686]

# %%
# dropping and replacing with english translation
df['Description of Property'] = df['Description of Property'].str.replace('Teach/Árasán Cónaithe Atháimhe','Second-Hand Dwelling house /Apartment')

# %%
df['Description of Property'].value_counts(dropna=False)
# Out:
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Name: Description of Property, dtype: int64

# %%
df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                10000     23
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description  10000      5
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                             None
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description                                               None
#
#                            freq
# Address                       2
# Postal Code                8140
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description  8971

# %% [markdown]
# ### Looking at Price data in more detail:

# %%
df.sort_values(by=['Price (€)']).head(20)
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 2094       2015-12-14 00:00:00
# 2661       2013-10-14 00:00:00
# 2772       2015-12-22 00:00:00
# 2950       2016-11-01 00:00:00
# 2582       2019-02-04 00:00:00
# 2749       2015-06-02 00:00:00
# 2846       2017-01-06 00:00:00
# 9200       2020-10-11 00:00:00
# 6003       2013-12-20 00:00:00
# 5487       2013-12-20 00:00:00
# 849        2014-08-20 00:00:00
# 1276       2017-11-09 00:00:00
# 1480       2015-09-22 00:00:00
# 7644       2011-10-10 00:00:00
# 2267       2015-10-06 00:00:00
# 4284       2020-06-17 00:00:00
# 5378       2018-06-07 00:00:00
# 4143       2019-04-02 00:00:00
# 4131       2017-10-10 00:00:00
# 1580       2010-03-12 00:00:00
#
#                                                 Address Postal Code  \
# 2094         19 Aranleigh Mount, Rathfarnham, Dublin 14   Dublin 14
# 2661                          Friarsquarter, Ballinrobe        None
# 2772              34 Tir an Choir, Vicorschorland, TUAM        None
# 2950             31 SHIP STREET, DROGHEDA, COUNTY LOUTH        None
# 2582               74 SPRING LANE RD, BALLYVOLANE, CORK        None
# 2749                  221 Cratloewood, Old Cratloe Road        None
# 2846            5 THE CLOSET APTS, ROSEMARY ST, ROSCREA        None
# 9200                   8 ORANHILL AVE, ORANMORE, GALWAY        None
# 6003  13 Phoenix Park Way, Phoenix Park Racecourse, ...   Dublin 15
# 5487  64 Rosanule, Phoenix Park Racecourse, Castleknock   Dublin 15
# 849                           Glensharrold, Carrickerry        None
# 1276        226 CASTLE CURRAGH HEATH, DUBLIN 15, DUBLIN   Dublin 15
# 1480  20 MILLWHARF APARTMENTS, MERCHANTS QUAY, DROGHEDA        None
# 7644                               Rathvilla, Edenderry        None
# 2267        APT 35 BUCKINGHAM VILLAGE, DUBLIN 1, DUBLIN    Dublin 1
# 4284                  RHUE, KILMORE, CARRICK ON SHANNON        None
# 5378                     MOUNTIRWIN, GURTEEN, BALLYMOTE        None
# 4143                      MEENBANE, BALLYBOFEY, DONEGAL        None
# 4131                  APARTMENT 1, THE SQUARE, SWINFORD        None
# 1580                              MAIN STREET, KILTEALY        None
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 2094     Dublin    5500.00                    No            No
# 2661       Mayo    6348.00                    No            No
# 2772     Galway    6608.00                    No           Yes
# 2950      Louth    7250.00                    No            No
# 2582       Cork    7300.00                    No            No
# 2749   Limerick    7500.00                    No           Yes
# 2846  Tipperary    7500.00                    No            No
# 9200     Galway    7770.00                    No            No
# 6003     Dublin    8000.00                    No           Yes
# 5487     Dublin    8000.00                    No           Yes
# 849    Limerick    8000.00                    No            No
# 1276     Dublin    8697.91                    No            No
# 1480      Louth    9039.78                    No            No
# 7644     Offaly   10000.00                    No            No
# 2267     Dublin   10000.00                    No            No
# 4284  Roscommon   10000.00                    No            No
# 5378      Sligo   10000.00                    No            No
# 4143    Donegal   10000.00                    No            No
# 4131       Mayo   10000.00                    No            No
# 1580    Wexford   10000.00                    No            No
#
#                     Description of Property  \
# 2094  Second-Hand Dwelling house /Apartment
# 2661  Second-Hand Dwelling house /Apartment
# 2772          New Dwelling house /Apartment
# 2950  Second-Hand Dwelling house /Apartment
# 2582  Second-Hand Dwelling house /Apartment
# 2749          New Dwelling house /Apartment
# 2846  Second-Hand Dwelling house /Apartment
# 9200  Second-Hand Dwelling house /Apartment
# 6003          New Dwelling house /Apartment
# 5487          New Dwelling house /Apartment
# 849   Second-Hand Dwelling house /Apartment
# 1276  Second-Hand Dwelling house /Apartment
# 1480  Second-Hand Dwelling house /Apartment
# 7644  Second-Hand Dwelling house /Apartment
# 2267  Second-Hand Dwelling house /Apartment
# 4284  Second-Hand Dwelling house /Apartment
# 5378  Second-Hand Dwelling house /Apartment
# 4143  Second-Hand Dwelling house /Apartment
# 4131  Second-Hand Dwelling house /Apartment
# 1580  Second-Hand Dwelling house /Apartment
#
#                               Property Size Description  Month  Year  \
# 2094                                               None     12  2015
# 2661                                               None     10  2013
# 2772  greater than or equal to 38 sq metres and less...     12  2015
# 2950                                               None     11  2016
# 2582                                               None      2  2019
# 2749                             less than 38 sq metres      6  2015
# 2846                                               None      1  2017
# 9200                                               None     10  2020
# 6003  greater than or equal to 38 sq metres and less...     12  2013
# 5487  greater than or equal to 38 sq metres and less...     12  2013
# 849                                                None      8  2014
# 1276                                               None     11  2017
# 1480                                               None      9  2015
# 7644                                               None     10  2011
# 2267                                               None     10  2015
# 4284                                               None      6  2020
# 5378                                               None      6  2018
# 4143                                               None      4  2019
# 4131                                               None     10  2017
# 1580                                               None      3  2010
#
#        percent  Season   Province GDP (USD-Billion)  \
# 2094  0.031368  Winter   Leinster            291.46
# 2661  0.386100  Autumn  Connaught            238.21
# 2772  0.199203  Winter  Connaught            291.46
# 2950  0.347222  Autumn   Leinster            298.73
# 2582  0.091075  Winter    Munster            399.12
# 2749  0.287356  Summer    Munster            291.46
# 2846  0.353357  Winter    Munster             334.6
# 9200  0.199203  Autumn  Connaught            425.89
# 6003  0.031368  Winter   Leinster            238.21
# 5487  0.031368  Winter   Leinster            238.21
# 849   0.287356  Summer    Munster            258.63
# 1276  0.031368  Autumn   Leinster             334.6
# 1480  0.347222  Autumn   Leinster            291.46
# 7644  0.840336  Autumn   Leinster            238.66
# 2267  0.031368  Autumn   Leinster            291.46
# 4284  0.699301  Summer  Connaught            425.89
# 5378  0.675676  Summer  Connaught            384.85
# 4143  0.364964  Spring     Ulster            399.12
# 4131  0.386100  Autumn  Connaught             334.6
# 1580  0.275482  Spring   Leinster            221.66
#
#      Total Number of Loans Approved
# 2094                          32236
# 2661                          19258
# 2772                          32236
# 2950                          35037
# 2582                         Unkown
# 2749                          32236
# 2846                         Unkown
# 9200                         Unkown
# 6003                          19258
# 5487                          19258
# 849                           31897
# 1276                         Unkown
# 1480                          32236
# 7644                          12834
# 2267                          32236
# 4284                         Unkown
# 5378                         Unkown
# 4143                         Unkown
# 4131                         Unkown
# 1580                          20021

# %% [markdown]
# ### Interpretation

# %% [markdown]
# - Again, this highlights the range of data in the price column. These outliers will have to be looked at in more detail. As some of them appear to large blocks of apartments grouped together
# - What is interesting is that a lot of the lowest prices are in Dublin which would go against popular belief. Of course, majority of the most expensive properties are also in Dublin

# %%
df.sort_values(by=['Price (€)'], ascending=False).head(20)
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 915        2017-07-17 00:00:00
# 3167       2021-02-24 00:00:00
# 5961       2019-12-18 00:00:00
# 9789       2014-10-06 00:00:00
# 2645       2016-12-15 00:00:00
# 4438       2021-07-27 00:00:00
# 2542       2015-02-10 00:00:00
# 787        2018-02-15 00:00:00
# 8462       2021-08-12 00:00:00
# 242        2020-06-29 00:00:00
# 8610       2021-11-26 00:00:00
# 2776       2016-12-14 00:00:00
# 2311       2021-04-08 00:00:00
# 2973       2018-02-11 00:00:00
# 6928       2021-04-13 00:00:00
# 9857       2019-03-25 00:00:00
# 4757       2016-06-14 00:00:00
# 9335       2011-08-26 00:00:00
# 7449       2018-09-25 00:00:00
# 4178       2018-09-13 00:00:00
#
#                                                 Address Postal Code   County  \
# 915                 THE HERMITAGE, CROSS AVE, BLACKROCK        None   Dublin
# 3167             1 THE HALL, YEW TREE SQ, PROSPEROUS RD        None  Kildare
# 5961  18-21 23-27 41 42 44-51, WHATELY PLACE, UPPER ...        None   Dublin
# 9789             73 AILESBURY RD, BALLSBRIDGE, DUBLIN 4    Dublin 4   Dublin
# 2645                             4 ELGIN ROAD, DUBLIN 4    Dublin 4   Dublin
# 4438           Block 29 St Helen's II, Adamstown, Lucan        None   Dublin
# 2542            CARNALEA, THORMANBY RD, BAILY DUBLIN 13   Dublin 13   Dublin
# 787           ARD NA GLAISE, STILLORGAN PARK, BLACKROCK        None   Dublin
# 8462            10-28 Pairc na Dara, Coolcotts, Wexford        None  Wexford
# 242                  23 ELGIN RD, BALLSBRIDGE, DUBLIN 4    Dublin 4   Dublin
# 8610               56 EGLINTON RD, DONNYBROOK, DUBLIN 4    Dublin 4   Dublin
# 2776             'SANCTA MARIA', BRIGHTON ROAD, FOXROCK        None   Dublin
# 2311                6 CLYDE LANE, BALLSBRIDGE, DUBLIN 4    Dublin 4   Dublin
# 2973              UNIT 1, 107 HADDINGTON ROAD, DUBLIN 4    Dublin 4   Dublin
# 6928               CONVENT OF MERCY, BEAUMONT, DUBLIN 9    Dublin 9   Dublin
# 9857          65 MOUNT PROSPECT AVE, CLONTARF, DUBLIN 3    Dublin 3   Dublin
# 4757                         2C ARRAN ST EAST, DUBLIN 7    Dublin 7   Dublin
# 9335      Carraigbrack House, Carraickbrack Road, Howth        None   Dublin
# 7449                  59 PARK AVE, SANDYMOUNT, DUBLIN 4    Dublin 4   Dublin
# 4178                  10 ORWELL PARK, RATHGAR, DUBLIN 6    Dublin 6   Dublin
#
#        Price (€) Not Full Market Price VAT Exclusive  \
# 915   7600000.00                    No            No
# 3167  6720000.00                    No            No
# 5961  6200000.00                    No            No
# 9789  6000000.00                    No            No
# 2645  5250000.00                    No            No
# 4438  5127753.00                    No           Yes
# 2542  5000000.00                    No            No
# 787   4138200.00                    No            No
# 8462  3691629.96                    No           Yes
# 242   3350000.00                    No            No
# 8610  3300000.00                    No            No
# 2776  3150000.00                    No            No
# 2311  3050000.00                    No            No
# 2973  2950000.00                    No            No
# 6928  2700100.00                    No            No
# 9857  2675000.00                    No            No
# 4757  2562500.00                    No            No
# 9335  2480000.00                    No            No
# 7449  2375000.00                    No            No
# 4178  2350000.00                    No            No
#
#                     Description of Property Property Size Description  Month  \
# 915   Second-Hand Dwelling house /Apartment                      None      7
# 3167  Second-Hand Dwelling house /Apartment                      None      2
# 5961  Second-Hand Dwelling house /Apartment                      None     12
# 9789  Second-Hand Dwelling house /Apartment                      None     10
# 2645  Second-Hand Dwelling house /Apartment                      None     12
# 4438          New Dwelling house /Apartment                      None      7
# 2542  Second-Hand Dwelling house /Apartment                      None      2
# 787   Second-Hand Dwelling house /Apartment                      None      2
# 8462          New Dwelling house /Apartment                      None      8
# 242   Second-Hand Dwelling house /Apartment                      None      6
# 8610  Second-Hand Dwelling house /Apartment                      None     11
# 2776  Second-Hand Dwelling house /Apartment                      None     12
# 2311  Second-Hand Dwelling house /Apartment                      None      4
# 2973  Second-Hand Dwelling house /Apartment                      None      2
# 6928  Second-Hand Dwelling house /Apartment                      None      4
# 9857  Second-Hand Dwelling house /Apartment                      None      3
# 4757  Second-Hand Dwelling house /Apartment                      None      6
# 9335  Second-Hand Dwelling house /Apartment                      None      8
# 7449  Second-Hand Dwelling house /Apartment                      None      9
# 4178  Second-Hand Dwelling house /Apartment                      None      9
#
#       Year   percent  Season  Province GDP (USD-Billion)  \
# 915   2017  0.031368  Summer  Leinster             334.6
# 3167  2021  0.207039  Winter  Leinster             440.0
# 5961  2019  0.031368  Winter  Leinster            399.12
# 9789  2014  0.031368  Autumn  Leinster            258.63
# 2645  2016  0.031368  Winter  Leinster            298.73
# 4438  2021  0.031368  Summer  Leinster             440.0
# 2542  2015  0.031368  Winter  Leinster            291.46
# 787   2018  0.031368  Winter  Leinster            384.85
# 8462  2021  0.275482  Summer  Leinster             440.0
# 242   2020  0.031368  Summer  Leinster            425.89
# 8610  2021  0.031368  Autumn  Leinster             440.0
# 2776  2016  0.031368  Winter  Leinster            298.73
# 2311  2021  0.031368  Spring  Leinster             440.0
# 2973  2018  0.031368  Winter  Leinster            384.85
# 6928  2021  0.031368  Spring  Leinster             440.0
# 9857  2019  0.031368  Spring  Leinster            399.12
# 4757  2016  0.031368  Summer  Leinster            298.73
# 9335  2011  0.031368  Summer  Leinster            238.66
# 7449  2018  0.031368  Autumn  Leinster            384.85
# 4178  2018  0.031368  Autumn  Leinster            384.85
#
#      Total Number of Loans Approved
# 915                          Unkown
# 3167                         Unkown
# 5961                         Unkown
# 9789                          31897
# 2645                          35037
# 4438                         Unkown
# 2542                          32236
# 787                          Unkown
# 8462                         Unkown
# 242                          Unkown
# 8610                         Unkown
# 2776                          35037
# 2311                         Unkown
# 2973                         Unkown
# 6928                         Unkown
# 9857                         Unkown
# 4757                          35037
# 9335                          12834
# 7449                         Unkown
# 4178                         Unkown

# %% [markdown]
# # Describing Numeric Types

# %% [markdown]
# - As you can see the only numeric type is the price data.

# %%
numeric_columns = df.select_dtypes(['float64','int']).columns
numeric_columns
# Out:
# Index(['Price (€)'], dtype='object')

# %%
df.describe(datetime_is_numeric=True).T
# Out:
#                              count                        mean  \
# Date of Sale (yyyy/mm/dd)    10000  2017-01-19 02:06:08.640000
# Price (€)                  10000.0               260260.702676
# Month                      10000.0                      6.8947
# Year                       10000.0                   2016.5192
#
#                                            min                  25%  \
# Date of Sale (yyyy/mm/dd)  2010-01-02 00:00:00  2014-11-07 00:00:00
# Price (€)                               5500.0             120000.0
# Month                                      1.0                  4.0
# Year                                    2010.0               2014.0
#
#                                            50%                  75%  \
# Date of Sale (yyyy/mm/dd)  2017-06-02 12:00:00  2019-08-04 00:00:00
# Price (€)                             200000.0            308370.08
# Month                                      7.0                 10.0
# Year                                    2017.0               2019.0
#
#                                            max            std
# Date of Sale (yyyy/mm/dd)  2022-12-01 00:00:00            NaN
# Price (€)                           17151248.0  390170.322939
# Month                                     12.0       3.477186
# Year                                    2022.0       3.108729

# %% [markdown]
# #### Further summary stats for numeric data Price (€)
# From look at the price data, the standard deviation is very large, with a large range of values. Range = 17145748

# %%
df[numeric_columns].describe().T
# Out:
#              count           mean            std     min       25%       50%  \
# Price (€)  10000.0  260260.702676  390170.322939  5500.0  120000.0  200000.0
#
#                  75%         max
# Price (€)  308370.08  17151248.0

# %% [markdown]
# #### Median value of price as is not included in the above describe table

# %%
df['Price (€)'].median()
# Out:
# 200000.0

# %%
numeric_columns_card = df[numeric_columns].nunique()
# store the values in a dataframe
df_numeric_card = pd.DataFrame(numeric_columns_card, columns=['card'])
df_numeric_card
# Out:
#            card
# Price (€)  2285

# %% [markdown]
# #### Looking at Address feature:

# %%
df['Address'].describe()
# Out:
# count                                                 10000
# unique                                                 9980
# top       APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# freq                                                      2
# Name: Address, dtype: object

# %% [markdown]
# #### Looking at Category features in more detail

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(dropna=False))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
#
# Postal Code
# None         8140
# Dublin 15     232
# Dublin 18     143
# Dublin 9      119
# Dublin 8      115
# Dublin 24     114
# Dublin 4      109
# Dublin 12     104
# Dublin 16      96
# Dublin 11      93
# Dublin 7       88
# Dublin 13      85
# Dublin 14      84
# Dublin 3       82
# Dublin 5       78
# Dublin 1       77
# Dublin 6       66
# Dublin 22      54
# Dublin 2       34
# Dublin 20      25
# Dublin 17      24
# Dublin 10      20
# Dublin 6w      18
# Name: Postal Code, dtype: int64
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Name: Description of Property, dtype: int64
#
# Property Size Description
# None                                                                 8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64

# %% [markdown]
# ### Breakdown of values as a percentage:

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts(normalize=True, dropna=True))
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    0.0002
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       0.0002
# GURETTI, HOWTH SUMMIT, NEW RD                            0.0002
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      0.0002
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        0.0002
#                                                           ...
# 29 Crockaun Way, Brownstown, Curragh                     0.0001
# 29 DROIMNEACH, BWEENG, CORK                              0.0001
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    0.0001
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          0.0001
# unit 3 Parkside Glen, parkside, malahide road            0.0001
# Name: Address, Length: 9980, dtype: float64
#
# Postal Code
# None         0.8140
# Dublin 15    0.0232
# Dublin 18    0.0143
# Dublin 9     0.0119
# Dublin 8     0.0115
# Dublin 24    0.0114
# Dublin 4     0.0109
# Dublin 12    0.0104
# Dublin 16    0.0096
# Dublin 11    0.0093
# Dublin 7     0.0088
# Dublin 13    0.0085
# Dublin 14    0.0084
# Dublin 3     0.0082
# Dublin 5     0.0078
# Dublin 1     0.0077
# Dublin 6     0.0066
# Dublin 22    0.0054
# Dublin 2     0.0034
# Dublin 20    0.0025
# Dublin 17    0.0024
# Dublin 10    0.0020
# Dublin 6w    0.0018
# Name: Postal Code, dtype: float64
#
# County
# Dublin       0.3193
# Cork         0.1099
# Galway       0.0502
# Kildare      0.0483
# Meath        0.0399
# Wexford      0.0363
# Limerick     0.0348
# Wicklow      0.0317
# Louth        0.0288
# Kerry        0.0285
# Tipperary    0.0283
# Donegal      0.0274
# Mayo         0.0259
# Waterford    0.0245
# Clare        0.0240
# Westmeath    0.0174
# Laois        0.0163
# Cavan        0.0153
# Sligo        0.0148
# Roscommon    0.0143
# Kilkenny     0.0133
# Carlow       0.0124
# Offaly       0.0119
# Leitrim      0.0099
# Longford     0.0090
# Monaghan     0.0076
# Name: County, dtype: float64
#
# Not Full Market Price
# No     0.9552
# Yes    0.0448
# Name: Not Full Market Price, dtype: float64
#
# VAT Exclusive
# No     0.8399
# Yes    0.1601
# Name: VAT Exclusive, dtype: float64
#
# Description of Property
# Second-Hand Dwelling house /Apartment    0.8364
# New Dwelling house /Apartment            0.1636
# Name: Description of Property, dtype: float64
#
# Property Size Description
# None                                                                 0.8971
# greater than or equal to 38 sq metres and less than 125 sq metres    0.0723
# greater than 125 sq metres                                           0.0135
# greater than or equal to 125 sq metres                               0.0094
# less than 38 sq metres                                               0.0077
# Name: Property Size Description, dtype: float64

# %% [markdown]
# ### Looking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
dfT = df.T
print("Number of duplicate (excluding first) columns in the table is: ", dfT.duplicated().sum())
print("Number of duplicate (including first) columns in the table is: ",  dfT[dfT.duplicated(keep=False)].shape[0])
# Out:
# Number of duplicate (excluding first) columns in the table is:  0
# Number of duplicate (including first) columns in the table is:  0

# %% [markdown]
# ### Saving intial updated data frame to a new CSV file with changes implemented above:

# %%
df.to_csv('updated-ppr-17350796.csv', index=False)

# %% [markdown]
# ### Preparing a tale with descriptive statistics for categorical data and continous data:

# %% [markdown]
# ### Describing continous data

# %% [markdown]
# Price:

# %%
df[numeric_columns].describe().T
# Out:
#              count           mean            std     min       25%       50%  \
# Price (€)  10000.0  260260.702676  390170.322939  5500.0  120000.0  200000.0
#
#                  75%         max
# Price (€)  308370.08  17151248.0

# %% [markdown]
# Date of Sale:

# %%
df['Date of Sale (yyyy/mm/dd)'].describe().T
# Out:
# <ipython-input-47-7343f1ab4cd9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['Date of Sale (yyyy/mm/dd)'].describe().T
# count                   10000
# unique                   2759
# top       2013-12-20 00:00:00
# freq                       32
# first     2010-01-02 00:00:00
# last      2022-12-01 00:00:00
# Name: Date of Sale (yyyy/mm/dd), dtype: object

# %% [markdown]
# ### Describing categorical data

# %%
df[category_columns].describe().T
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                10000     23
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description  10000      5
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                             None
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description                                               None
#
#                            freq
# Address                       2
# Postal Code                8140
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description  8971

# %%
df_category_mode = pd.DataFrame(index = df[category_columns].describe().T.index, columns=['mode', 'freq_mode','%mode', '2ndmode', 'freq_2ndmode','%2ndmode'])
df_category_mode
# Out:
#                           mode freq_mode %mode 2ndmode freq_2ndmode %2ndmode
# Address                    NaN       NaN   NaN     NaN          NaN      NaN
# Postal Code                NaN       NaN   NaN     NaN          NaN      NaN
# County                     NaN       NaN   NaN     NaN          NaN      NaN
# Not Full Market Price      NaN       NaN   NaN     NaN          NaN      NaN
# VAT Exclusive              NaN       NaN   NaN     NaN          NaN      NaN
# Description of Property    NaN       NaN   NaN     NaN          NaN      NaN
# Property Size Description  NaN       NaN   NaN     NaN          NaN      NaN

# %%
for column in category_columns:
    print("\n" + column)
    print(df[column].value_counts())
    print(df[column].value_counts().keys())
    
    df_category_mode.loc[column]['mode'] = df[column].value_counts().keys()[0]
    df_category_mode.loc[column]['freq_mode'] = df[column].value_counts()[df_category_mode.loc[column]['mode']]
    df_category_mode.loc[column]['%mode'] = df[column].value_counts(normalize=True)[df_category_mode.loc[column]['mode']]
 

    if df[column].value_counts().size > 1:
        df_category_mode.loc[column]['2ndmode'] = df[column].value_counts().keys()[1]
        df_category_mode.loc[column]['freq_2ndmode'] = df[column].value_counts()[df_category_mode.loc[column]['2ndmode']]
        df_category_mode.loc[column]['%2ndmode'] = df[column].value_counts(normalize=True)[df_category_mode.loc[column]['2ndmode']]
    else: df_category_mode.loc[column] = '-'
# Out:
# Address
# APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE    2
# 8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY       2
# GURETTI, HOWTH SUMMIT, NEW RD                            2
# 3 BARTRA ROCK, HARBOUR ROAD, DALKEY                      2
# BALLYHAUNIS RD, CLAREMORRIS, MAYO                        2
#                                                         ..
# 29 Crockaun Way, Brownstown, Curragh                     1
# 29 DROIMNEACH, BWEENG, CORK                              1
# 29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7                    1
# 29 DUBLIN ST, DUNDALK, CO LOUTH                          1
# unit 3 Parkside Glen, parkside, malahide road            1
# Name: Address, Length: 9980, dtype: int64
# CategoricalIndex(['APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND VILLAGE',
#                   '8A COACHMAN APARTMENTS, DOMINICK STREET, CO GALWAY',
#                   'GURETTI, HOWTH SUMMIT, NEW RD',
#                   '3 BARTRA ROCK, HARBOUR ROAD, DALKEY',
#                   'BALLYHAUNIS RD, CLAREMORRIS, MAYO',
#                   'RUSHLAKE, WOODLAWN, BALLINASLOE',
#                   'Glackmore, Aught Road, Muff',
#                   '16 BENBULBIN RD, DRIMNAGH, DUBLIN 12',
#                   '67 MALAHIDE MARINA VILLAGE, MALAHIDE, DUBLIN',
#                   'HILLQUARTER, COOSAN, ATHLONE',
#                   ...
#                   '29 COIS LOCHA, SALEEN, BALLINROBE RD',
#                   '29 Carlinn Avenue, Mullaharlin Road, Dundalk',
#                   '29 Carndonagh Drive, Donaghmede, Dublin 13',
#                   '29 Castlebrook Green, Castlebrook Manor, Castletroy',
#                   '29 Citywest Village Avenue, Citywest Village, Citywest',
#                   '29 Crockaun Way, Brownstown, Curragh',
#                   '29 DROIMNEACH, BWEENG, CORK',
#                   '29 DRUMCLIFF RD, CABRA WEST, DUBLIN 7',
#                   '29 DUBLIN ST, DUNDALK, CO LOUTH',
#                   'unit 3 Parkside Glen, parkside, malahide road'],
#                  categories=[''Ardan', Aghowle, Ashford', ''Eala', Castlejane, Glanmire', ''Ermland', Johnstown Road, Enfield', ''Ewell', 18 Mount Anville Road, Dundrum', ''Knocknagow', Blackrock Road', ''SANCTA MARIA', BRIGHTON ROAD, FOXROCK', ''SHARON', NORTH CIRCULAR ROAD', '04 MOYGLARE RIDGE, MARIAVILLA, MAYNOOTH', ...], ordered=False, dtype='category', length=9980)
#
# Postal Code
# None         8140
# Dublin 15     232
# Dublin 18     143
# Dublin 9      119
# Dublin 8      115
# Dublin 24     114
# Dublin 4      109
# Dublin 12     104
# Dublin 16      96
# Dublin 11      93
# Dublin 7       88
# Dublin 13      85
# Dublin 14      84
# Dublin 3       82
# Dublin 5       78
# Dublin 1       77
# Dublin 6       66
# Dublin 22      54
# Dublin 2       34
# Dublin 20      25
# Dublin 17      24
# Dublin 10      20
# Dublin 6w      18
# Name: Postal Code, dtype: int64
# CategoricalIndex(['None', 'Dublin 15', 'Dublin 18', 'Dublin 9', 'Dublin 8',
#                   'Dublin 24', 'Dublin 4', 'Dublin 12', 'Dublin 16',
#                   'Dublin 11', 'Dublin 7', 'Dublin 13', 'Dublin 14',
#                   'Dublin 3', 'Dublin 5', 'Dublin 1', 'Dublin 6', 'Dublin 22',
#                   'Dublin 2', 'Dublin 20', 'Dublin 17', 'Dublin 10',
#                   'Dublin 6w'],
#                  categories=['Dublin 1', 'Dublin 10', 'Dublin 11', 'Dublin 12', 'Dublin 13', 'Dublin 14', 'Dublin 15', 'Dublin 16', ...], ordered=False, dtype='category')
#
# County
# Dublin       3193
# Cork         1099
# Galway        502
# Kildare       483
# Meath         399
# Wexford       363
# Limerick      348
# Wicklow       317
# Louth         288
# Kerry         285
# Tipperary     283
# Donegal       274
# Mayo          259
# Waterford     245
# Clare         240
# Westmeath     174
# Laois         163
# Cavan         153
# Sligo         148
# Roscommon     143
# Kilkenny      133
# Carlow        124
# Offaly        119
# Leitrim        99
# Longford       90
# Monaghan       76
# Name: County, dtype: int64
# CategoricalIndex(['Dublin', 'Cork', 'Galway', 'Kildare', 'Meath', 'Wexford',
#                   'Limerick', 'Wicklow', 'Louth', 'Kerry', 'Tipperary',
#                   'Donegal', 'Mayo', 'Waterford', 'Clare', 'Westmeath',
#                   'Laois', 'Cavan', 'Sligo', 'Roscommon', 'Kilkenny', 'Carlow',
#                   'Offaly', 'Leitrim', 'Longford', 'Monaghan'],
#                  categories=['Carlow', 'Cavan', 'Clare', 'Cork', 'Donegal', 'Dublin', 'Galway', 'Kerry', ...], ordered=False, dtype='category')
#
# Not Full Market Price
# No     9552
# Yes     448
# Name: Not Full Market Price, dtype: int64
# CategoricalIndex(['No', 'Yes'], categories=['No', 'Yes'], ordered=False, dtype='category')
#
# VAT Exclusive
# No     8399
# Yes    1601
# Name: VAT Exclusive, dtype: int64
# CategoricalIndex(['No', 'Yes'], categories=['No', 'Yes'], ordered=False, dtype='category')
#
# Description of Property
# Second-Hand Dwelling house /Apartment    8364
# New Dwelling house /Apartment            1636
# Name: Description of Property, dtype: int64
# Index(['Second-Hand Dwelling house /Apartment', 'New Dwelling house /Apartment'], dtype='object')
#
# Property Size Description
# None                                                                 8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64
# CategoricalIndex(['None',
#                   'greater than or equal to 38 sq metres and less than 125 sq metres',
#                   'greater than 125 sq metres',
#                   'greater than or equal to 125 sq metres',
#                   'less than 38 sq metres'],
#                  categories=['None', 'greater than 125 sq metres', 'greater than or equal to 125 sq metres', 'greater than or equal to 38 sq metres and less than 125 sq metres', 'less than 38 sq metres'], ordered=False, dtype='category')

# %%
df_category_mode
# Out:
#                                                                         mode  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                             None
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description                                               None
#
#                           freq_mode   %mode  \
# Address                           2  0.0002
# Postal Code                    8140   0.814
# County                         3193  0.3193
# Not Full Market Price          9552  0.9552
# VAT Exclusive                  8399  0.8399
# Description of Property        8364  0.8364
# Property Size Description      8971  0.8971
#
#                                                                      2ndmode  \
# Address                    8A COACHMAN APARTMENTS, DOMINICK STREET, CO GA...
# Postal Code                                                        Dublin 15
# County                                                                  Cork
# Not Full Market Price                                                    Yes
# VAT Exclusive                                                            Yes
# Description of Property                        New Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                           freq_2ndmode %2ndmode
# Address                              2   0.0002
# Postal Code                        232   0.0232
# County                            1099   0.1099
# Not Full Market Price              448   0.0448
# VAT Exclusive                     1601   0.1601
# Description of Property           1636   0.1636
# Property Size Description          723   0.0723

# %% [markdown]
# #### No missing data:

# %%
# Prepare %missing column
category_columns_perc_missing  = 100 * (df[category_columns].isnull().sum()/df.shape[0])
#category_columns_perc_missing

# Store the values in a dataframe
df_category_perc_missing = pd.DataFrame(category_columns_perc_missing, columns=['%missing'])
df_category_perc_missing
# Out:
#                            %missing
# Address                         0.0
# Postal Code                     0.0
# County                          0.0
# Not Full Market Price           0.0
# VAT Exclusive                   0.0
# Description of Property         0.0
# Property Size Description       0.0

# %% [markdown]
# ### Final table of categorical data:

# %%
# Put the columns together to prepare the final table 
df_category_columns_data_quality_report_table = pd.concat([df[category_columns].describe().T, df_category_mode, df_category_perc_missing], axis=1)

df_category_columns_data_quality_report_table
# Out:
#                            count unique  \
# Address                    10000   9980
# Postal Code                10000     23
# County                     10000     26
# Not Full Market Price      10000      2
# VAT Exclusive              10000      2
# Description of Property    10000      2
# Property Size Description  10000      5
#
#                                                                          top  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                             None
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description                                               None
#
#                            freq  \
# Address                       2
# Postal Code                8140
# County                     3193
# Not Full Market Price      9552
# VAT Exclusive              8399
# Description of Property    8364
# Property Size Description  8971
#
#                                                                         mode  \
# Address                    APT 64 THOMOND VILLAGE, BALLYGRENNAN, THOMOND ...
# Postal Code                                                             None
# County                                                                Dublin
# Not Full Market Price                                                     No
# VAT Exclusive                                                             No
# Description of Property                Second-Hand Dwelling house /Apartment
# Property Size Description                                               None
#
#                           freq_mode   %mode  \
# Address                           2  0.0002
# Postal Code                    8140   0.814
# County                         3193  0.3193
# Not Full Market Price          9552  0.9552
# VAT Exclusive                  8399  0.8399
# Description of Property        8364  0.8364
# Property Size Description      8971  0.8971
#
#                                                                      2ndmode  \
# Address                    8A COACHMAN APARTMENTS, DOMINICK STREET, CO GA...
# Postal Code                                                        Dublin 15
# County                                                                  Cork
# Not Full Market Price                                                    Yes
# VAT Exclusive                                                            Yes
# Description of Property                        New Dwelling house /Apartment
# Property Size Description  greater than or equal to 38 sq metres and less...
#
#                           freq_2ndmode %2ndmode  %missing
# Address                              2   0.0002       0.0
# Postal Code                        232   0.0232       0.0
# County                            1099   0.1099       0.0
# Not Full Market Price              448   0.0448       0.0
# VAT Exclusive                     1601   0.1601       0.0
# Description of Property           1636   0.1636       0.0
# Property Size Description          723   0.0723       0.0

# %% [markdown]
# # Visualisation- Data Quality Report

# %% [markdown]
# ### Price feature

# %% [markdown]
# - As you see from the looking at the histogram of price that due to the large range of values, it is heavily right skewed

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
plt.savefig('Homework1-DataQualityReport-NumericFeatures-histograms_all_1-1.pdf')
plt.savefig('Price_orginal_histo.png')

# %% [markdown]
# ### Box Plot of Price

# %% [markdown]
# -  The outliers are further highlighted from looking at the box plot you can see there is a significant number of outliers

# %%
df[numeric_columns].plot(kind='box', subplots=True, figsize=(30,30), layout=(3,3), sharex=False, sharey=False)
plt.savefig('HomeWork-DataQualityReport-NumericFeatures-boxplots_all_1-1.pdf')

# %% [markdown]
# ### Clamping Data price for Data visualising purposes:

# %%
upper = df['Price (€)'].quantile(0.99)
lower = df['Price (€)'].quantile(0.01)

Adjusted_price = np.where(df['Price (€)']>= upper,
                         upper, 
                         np.where(df['Price (€)']<= lower,
                                 lower,
                                 df['Price (€)']))


Adjusted_price_dataframe =pd.DataFrame(Adjusted_price, columns=['Adjusted Price'])

# %% [markdown]
# ### Interpretation of Clamping the data:

# %% [markdown]
# - This allows us to visualise the bulk of the data as it gets rid of some of the outliers.
# - We can see that most price reside around the 100,000 mark to the 500,000 mark.

# %%
Adjusted_price_dataframe.hist(column='Adjusted Price', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
plt.savefig('clampedPrice.png')

# %% [markdown]
# ### Date of Sale feature

# %%
df_sample_grouped = df.groupby(['Date of Sale (yyyy/mm/dd)']).size()
df_sample_grouped
# Out:
# Date of Sale (yyyy/mm/dd)
# 2010-01-02    2
# 2010-01-03    2
# 2010-01-04    1
# 2010-01-05    1
# 2010-01-06    3
#              ..
# 2022-04-01    2
# 2022-05-01    1
# 2022-06-01    1
# 2022-07-01    3
# 2022-12-01    3
# Length: 2759, dtype: int64

# %%
df['Date of Sale (yyyy/mm/dd)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Month'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Charts for All Catergotical Features

# %%
df['Postal Code'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Postal Code")
plt.savefig('postalCode_bar.png')

plt.show()

df['County'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Counties")
plt.savefig('counties_bar.png')

plt.show()


df['Not Full Market Price'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Not Full Market Price")
plt.savefig('NotFullMarketPrice_bar.png')

plt.show()

df['VAT Exclusive'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of VAT Exclusive")
plt.savefig('VAT_exclusiveBar.png')

plt.show()


df['Property Size Description'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Property Size Description")
plt.savefig('Property_Size_DescriptionBar.png')

plt.show()



df['Year'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Years")

plt.savefig('Years_Bar.png')

plt.show()





df['Month'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
plt.title("Count of Months")

plt.savefig('Months_bar.png')

plt.show()

# %% [markdown]
# ### Interpretion of all bar charts of categorical features:

# %% [markdown]
# - Postal Code
#     - As you can see the count for none is the highest.
#     - The area of Dublin 15 is the highest with Dublin 20 being the lowest
# - County
#     - This visualises the majority that Dublin has.
#     - It gives you good idea how low Monaghan is in comparison
# - Not Full Market Price
#     - This further depicts how the overwhelming majority of the house sales were full market price
# - VAT exclusive
#     - Again, this depicts that the overwhelming majority of house sales were not VAT exclusive
# - Propery Size Description
#     - As you can see the majority of house sales do not have a property description
#     - Of the properties that do have descriptions, most are greater than or equal to 38 square metres and less than 125sq
# - Year
#     - The year 2018 has the most sales
#     - 2022 has the least as the year is not complete
#     - In general, they follow a gradual increasing trend as the years go by
# - Month
#     - December seems to have the most house sales, with February having the least
#     - Possibly due to people wanting to get deals done before the new year.
#     - They tend to follow a slight trend of the months later in the year having more sales than the months earlier in the year

# %% [markdown]
# <h1><center>Part 2: data quality plan for the cleaned CSV file</center></h1>

# %% [markdown]
# ### List of data quality issues and proposed solutions

# %% [markdown]
# - Date of Sale (dd/mm/yyyy): This data was converted to datetime. The months and the years have been extracted as separate features in order for it to be easier to compare them to other features. Also, there was dates that indicated they were sold in the future. They will be adjusted as it appears they have entered incorrectly.
#
# - Postal Code:Large proportion missing. Opted to keep as could provide further geographical information about Dublin
#
# - Price: Large variance in data makes it difficult for interpretation. There is potential to remove outliers
#
# - Description of Property: Irish descriptions were translated so there were only two unique values for consistency.
#
# - Property Size Description: This feature has a large amount of missing data.
#
# - Vat Exclusive: Less than 17% of the sales do not include the VAT in the sale price. I have chosen not to seperate this data and keep it as one.
#
# - Not Full Market Price: There is a small amount of sales that were not full market price. I have decided to drop those sales as there are not a true relection of market price.

# %% [markdown]
# ### Addressing 'Not Full Market Price':

# %% [markdown]
# - As mentioned I have chose to drop those that are not full market price. This a very small number of sales. There is a large number of reasons why a house would not be full market price such as fractional sales or government schemes. As these are not true representations of the market they are being dropped.

# %%
df = df[df['Not Full Market Price'] == 'No']

# %% [markdown]
# Confirming they have been removed:

# %%
df.loc[(df['Not Full Market Price'] == 'Yes')]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year, percent, Season, Province, GDP (USD-Billion), Total Number of Loans Approved]
# Index: []

# %% [markdown]
# ### Addressing 'Date of Sale (yyyy/mm/dd)' feature irregularity:

# %% [markdown]
# - As mentioned there are dates of sales in the future
# - It appear as though the month was entered as the day. Thus, all these sales were actually completed in January 2022 and not later this year. In an effort to avoid deleting data, I have decided to swap the days and months to their correct posistion in order to maintain logical integrity.

# %%
df.loc[(df['Year'] == 2022) & 
                         (df['Month']> 0)]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 1032                2022-04-01
# 2742                2022-07-01
# 3042                2022-04-01
# 3900                2022-07-01
# 4358                2022-12-01
# 5494                2022-12-01
# 5540                2022-05-01
# 6237                2022-06-01
# 6567                2022-12-01
# 8340                2022-07-01
#
#                                                 Address Postal Code  \
# 1032                 5 STRAFFAN GATE, STRAFFAN, KILDARE        None
# 2742   78 HILL OF DOWN, SPENCER DOCK, MAYOR ST DUBLIN 1    Dublin 1
# 3042          4 CNOC BEAG, LIS CARA, CARRICK ON SHANNON        None
# 3900              36 THE CAMMOCK, MOUNT BROWN, DUBLIN 8    Dublin 8
# 4358  74 DAKOTA COURT, ROYAL CANAL BANK, PHIBSBOROUG...    Dublin 7
# 5494                    RUSHLAKE, WOODLAWN, BALLINASLOE        None
# 5540                        BIRCHILL, DROMBANE, THURLES        None
# 6237               48 CROMCASTLE AVE, COOLOCK, DUBLIN 5    Dublin 5
# 6567                           5 Cul na Claishe, Tralee        None
# 8340                           TISSASSON, KINSALE, CORK        None
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 1032    Kildare   186974.0                    No            No
# 2742     Dublin   382000.0                    No            No
# 3042    Leitrim   161000.0                   Yes            No
# 3900     Dublin   231500.0                    No            No
# 4358     Dublin   278000.0                    No            No
# 5494     Galway   216500.0                    No            No
# 5540  Tipperary   160000.0                    No            No
# 6237     Dublin   290000.0                   Yes            No
# 6567      Kerry    30000.0                    No           Yes
# 8340       Cork   260000.0                    No            No
#
#                     Description of Property Property Size Description  Month  \
# 1032  Second-Hand Dwelling house /Apartment                      None      4
# 2742  Second-Hand Dwelling house /Apartment                      None      7
# 3042  Second-Hand Dwelling house /Apartment                      None      4
# 3900  Second-Hand Dwelling house /Apartment                      None      7
# 4358  Second-Hand Dwelling house /Apartment                      None     12
# 5494  Second-Hand Dwelling house /Apartment                      None     12
# 5540  Second-Hand Dwelling house /Apartment                      None      5
# 6237  Second-Hand Dwelling house /Apartment                      None      6
# 6567          New Dwelling house /Apartment                      None     12
# 8340  Second-Hand Dwelling house /Apartment                      None      7
#
#       Year
# 1032  2022
# 2742  2022
# 3042  2022
# 3900  2022
# 4358  2022
# 5494  2022
# 5540  2022
# 6237  2022
# 6567  2022
# 8340  2022

# %% [markdown]
# #### Correcting the data:

# %%
df.loc[1032,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-04',1]

df.loc[2742,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-07',1]

df.loc[3042,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-04',1]

df.loc[3900,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-07',1]

df.loc[4358,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-12',1]

df.loc[5494,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-12',1]

df.loc[5540,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-05',1]

df.loc[6237,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-06',1]

df.loc[6567,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-12',1]

df.loc[8340,['Date of Sale (yyyy/mm/dd)','Month']] = ['2022-01-07',1]

# %% [markdown]
# #### Corrected data:

# %%
df.loc[(df['Year'] == 2022) & 
                         (df['Month']> 0)]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 1032                2022-01-04
# 2742                2022-01-07
# 3042                2022-01-04
# 3900                2022-01-07
# 4358                2022-01-12
# 5494                2022-01-12
# 5540                2022-01-05
# 6237                2022-01-06
# 6567                2022-01-12
# 8340                2022-01-07
#
#                                                 Address Postal Code  \
# 1032                 5 STRAFFAN GATE, STRAFFAN, KILDARE        None
# 2742   78 HILL OF DOWN, SPENCER DOCK, MAYOR ST DUBLIN 1    Dublin 1
# 3042          4 CNOC BEAG, LIS CARA, CARRICK ON SHANNON        None
# 3900              36 THE CAMMOCK, MOUNT BROWN, DUBLIN 8    Dublin 8
# 4358  74 DAKOTA COURT, ROYAL CANAL BANK, PHIBSBOROUG...    Dublin 7
# 5494                    RUSHLAKE, WOODLAWN, BALLINASLOE        None
# 5540                        BIRCHILL, DROMBANE, THURLES        None
# 6237               48 CROMCASTLE AVE, COOLOCK, DUBLIN 5    Dublin 5
# 6567                           5 Cul na Claishe, Tralee        None
# 8340                           TISSASSON, KINSALE, CORK        None
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 1032    Kildare   186974.0                    No            No
# 2742     Dublin   382000.0                    No            No
# 3042    Leitrim   161000.0                   Yes            No
# 3900     Dublin   231500.0                    No            No
# 4358     Dublin   278000.0                    No            No
# 5494     Galway   216500.0                    No            No
# 5540  Tipperary   160000.0                    No            No
# 6237     Dublin   290000.0                   Yes            No
# 6567      Kerry    30000.0                    No           Yes
# 8340       Cork   260000.0                    No            No
#
#                     Description of Property Property Size Description  Month  \
# 1032  Second-Hand Dwelling house /Apartment                      None      1
# 2742  Second-Hand Dwelling house /Apartment                      None      1
# 3042  Second-Hand Dwelling house /Apartment                      None      1
# 3900  Second-Hand Dwelling house /Apartment                      None      1
# 4358  Second-Hand Dwelling house /Apartment                      None      1
# 5494  Second-Hand Dwelling house /Apartment                      None      1
# 5540  Second-Hand Dwelling house /Apartment                      None      1
# 6237  Second-Hand Dwelling house /Apartment                      None      1
# 6567          New Dwelling house /Apartment                      None      1
# 8340  Second-Hand Dwelling house /Apartment                      None      1
#
#       Year
# 1032  2022
# 2742  2022
# 3042  2022
# 3900  2022
# 4358  2022
# 5494  2022
# 5540  2022
# 6237  2022
# 6567  2022
# 8340  2022

# %% [markdown]
# ### Addressing 'Property Size Desciption' feature:

# %% [markdown]
# - From the below figures it is shown that 90% of this data is missing. However, as is shown 62% of New Dwelling house/Apartments have a Property Size Description attrtibuted to them. Thus, it may be valuable information to help look at the target feature Price later on.
# - It is important to not needlessly throw out data in case in could be useful in the future as we attempt to predict house prices.

# %%
df["Property Size Description"].describe().T
# Out:
# count     10000
# unique        5
# top        None
# freq       8971
# Name: Property Size Description, dtype: object

# %%
df['Property Size Description'].unique()
# Out:
# ['None', 'greater than 125 sq metres', 'greater than or equal to 38 sq metres and les..., 'greater than or equal to 125 sq metres', 'less than 38 sq metres']
# Categories (5, object): ['None', 'greater than 125 sq metres', 'greater than or equal to 38 sq metres and les..., 'greater than or equal to 125 sq metres', 'less than 38 sq metres']

# %%
df['Property Size Description'].value_counts()
# Out:
# None                                                                 8971
# greater than or equal to 38 sq metres and less than 125 sq metres     723
# greater than 125 sq metres                                            135
# greater than or equal to 125 sq metres                                 94
# less than 38 sq metres                                                 77
# Name: Property Size Description, dtype: int64

# %%
df['Property Size Description'].isnull().sum()
# Out:
# 0

# %%
df.groupby('Description of Property')['Property Size Description'].count()
# Out:
# Description of Property
# New Dwelling house /Apartment            1636
# Second-Hand Dwelling house /Apartment    8364
# Name: Property Size Description, dtype: int64

# %%
df.loc[(df['Description of Property'] == 'New Dwelling house /Apartment') & 
                         (df['Property Size Description'].isna())]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %%
df.groupby('Description of Property').count()
# Out:
#                                        Date of Sale (yyyy/mm/dd)  Address  \
# Description of Property
# New Dwelling house /Apartment                               1636     1636
# Second-Hand Dwelling house /Apartment                       8364     8364
#
#                                        Postal Code  County  Price (€)  \
# Description of Property
# New Dwelling house /Apartment                 1636    1636       1636
# Second-Hand Dwelling house /Apartment         8364    8364       8364
#
#                                        Not Full Market Price  VAT Exclusive  \
# Description of Property
# New Dwelling house /Apartment                           1636           1636
# Second-Hand Dwelling house /Apartment                   8364           8364
#
#                                        Property Size Description  Month  Year
# Description of Property
# New Dwelling house /Apartment                               1636   1636  1636
# Second-Hand Dwelling house /Apartment                       8364   8364  8364

# %% [markdown]
# ### Addressing the 'VAT exclusive' data

# %%
df.loc[df['Description of Property'] == 'New Dwelling house /Apartment']
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 7          2016-02-05 00:00:00
# 10         2015-06-15 00:00:00
# 15         2021-03-06 00:00:00
# 20         2017-07-04 00:00:00
# 24         2010-07-09 00:00:00
# ...                        ...
# 9967       2018-03-08 00:00:00
# 9979       2010-03-11 00:00:00
# 9983       2021-06-30 00:00:00
# 9991       2018-11-19 00:00:00
# 9993       2019-05-12 00:00:00
#
#                                                Address Postal Code     County  \
# 7                                  Ballygibbon, Nenagh        None  Tipperary
# 10    Apt 350 Block 8B, Tallaght Cross West, Dublin 24   Dublin 24     Dublin
# 15              4 INISHFALLEN, ROOKERY ROAD, KILLARNEY        None      Kerry
# 20                                 Knockanna, Tinahely        None    Wicklow
# 24    30 Broadfield Drive, Broadfield Manor, Rathcoole        None     Dublin
# ...                                                ...         ...        ...
# 9967                    152 BEECHDALE, DUNBOYNE, MEATH        None      Meath
# 9979                        3 Holywell Grove, Kilcoole        None    Wicklow
# 9983                                Knockmore, Drinagh        None       Cork
# 9991                14 Roseberry Hill, Quinagh, CARLOW        None     Carlow
# 9993            6 Edenbrook Green, Edenbrook, Citywest        None     Dublin
#
#       Price (€) Not Full Market Price VAT Exclusive  \
# 7     264317.00                    No           Yes
# 10     99433.75                    No           Yes
# 15    340000.00                    No           Yes
# 20    105000.00                    No           Yes
# 24    281938.00                    No           Yes
# ...         ...                   ...           ...
# 9967  330000.00                    No           Yes
# 9979  233480.17                    No           Yes
# 9983  233000.00                    No           Yes
# 9991  173173.00                    No           Yes
# 9993  348017.61                    No           Yes
#
#             Description of Property  \
# 7     New Dwelling house /Apartment
# 10    New Dwelling house /Apartment
# 15    New Dwelling house /Apartment
# 20    New Dwelling house /Apartment
# 24    New Dwelling house /Apartment
# ...                             ...
# 9967  New Dwelling house /Apartment
# 9979  New Dwelling house /Apartment
# 9983  New Dwelling house /Apartment
# 9991  New Dwelling house /Apartment
# 9993  New Dwelling house /Apartment
#
#                               Property Size Description  Month  Year
# 7                            greater than 125 sq metres      2  2016
# 10    greater than or equal to 38 sq metres and less...      6  2015
# 15                                                 None      3  2021
# 20               greater than or equal to 125 sq metres      7  2017
# 24    greater than or equal to 38 sq metres and less...      7  2010
# ...                                                 ...    ...   ...
# 9967  greater than or equal to 38 sq metres and less...      3  2018
# 9979  greater than or equal to 38 sq metres and less...      3  2010
# 9983                                               None      6  2021
# 9991  greater than or equal to 38 sq metres and less...     11  2018
# 9993                                               None      5  2019
#
# [1636 rows x 11 columns]

# %%
print("number of 'Yes VAT exclusives: '",(df['VAT Exclusive'] == 'Yes').sum())
print("number of New Dwelling house/Apartment '",(df['Description of Property'] == 'New Dwelling house /Apartment').sum())
# Out:
# number of 'Yes VAT exclusives: ' 1601
# number of New Dwelling house/Apartment ' 1636

# %%
df.loc[(df['Description of Property'] == 'New Dwelling house /Apartment') & (df['VAT Exclusive'] == 'No')]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 199        2017-08-05 00:00:00
# 479        2016-08-23 00:00:00
# 738        2014-08-09 00:00:00
# 822        2016-12-23 00:00:00
# 1004       2011-06-10 00:00:00
# 1382       2012-08-22 00:00:00
# 1389       2013-04-07 00:00:00
# 1704       2010-01-27 00:00:00
# 2458       2018-11-14 00:00:00
# 2744       2015-06-11 00:00:00
# 3540       2013-06-28 00:00:00
# 4121       2012-04-01 00:00:00
# 4653       2010-07-29 00:00:00
# 5459       2012-10-12 00:00:00
# 5949       2016-07-29 00:00:00
# 5956       2017-01-08 00:00:00
# 6064       2017-07-13 00:00:00
# 6099       2015-07-31 00:00:00
# 6145       2015-02-27 00:00:00
# 6206       2019-11-01 00:00:00
# 6807       2014-05-12 00:00:00
# 6991       2019-10-24 00:00:00
# 7138       2016-06-16 00:00:00
# 7300       2017-08-05 00:00:00
# 7912       2015-02-04 00:00:00
# 8292       2010-01-03 00:00:00
# 8557       2018-11-01 00:00:00
# 8731       2010-12-11 00:00:00
# 8749       2018-11-12 00:00:00
# 9263       2018-09-02 00:00:00
# 9367       2015-09-06 00:00:00
# 9777       2013-09-27 00:00:00
# 9811       2018-01-06 00:00:00
# 9855       2021-02-11 00:00:00
# 9966       2021-09-30 00:00:00
#
#                                                 Address Postal Code  \
# 199                  Unit 271 Roseberry Hill, Newbridge        None
# 479                           33 Shannon Quays, Rooskey        None
# 738                     Woodbine Heights, Spanish Point        None
# 822   4 The Parade, Riverchapel Wood, Riverchapel  C...        None
# 1004            57 Glen Tain, Carnamuggagh, Letterkenny        None
# 1382  8 Cois Abhann, Excise Street/Lyster Street, At...        None
# 1389                               Far Finisklin, Sligo        None
# 1704                           no 8 emmet place, nenagh        None
# 2458             2 THE GRAINSTORE, BAGENALSTOWN, CARLOW        None
# 2744                    50 Abhainn glas, Edgeworthstown        None
# 3540                  48 Gleann Bhan, Ballybane, Galway        None
# 4121                         10 Lissoran, Ballinspittle        None
# 4653                             105 Lios Ard, Tulla Rd        None
# 5459                                  WOODVIEW, DOUGLAS        None
# 5949  8 Retirement Village, Windmill  Churchtown, Ma...        None
# 5956    APARTMENT 2, GALWAY BAY SEA VIEW APTS, SALTHILL        None
# 6064              55 Carraig Ean, edenderry, Co. Offaly        None
# 6099                  1 The Terrace, Robswall, Malahide        None
# 6145                    Apartment 16 Seascape, Clontarf        None
# 6206                     LAVAGH, BALLYHEELAN, KILNALECK        None
# 6807    4 Castlemurray Apt, St John's Point, Dunkineely        None
# 6991                             Station Road, Glenties        None
# 7138          Cottage and Garden, Glanbane, Trughanacmy        None
# 7300                 Unit 270 Roseberry Hill, Newbridge        None
# 7912          160 Brightwater, Konocknagore, Crosshaven        None
# 8292                    168 The Quadrants, Ballincollig        None
# 8557                       12 Seagull Park, Clogherhead        None
# 8731                               Balllycummin, Easkey        None
# 8749                   52 FIONNUISCE, DOUGHISKA, GALWAY        None
# 9263  6 St. Edmunds Green, St. Edmunds, St. Lomans Road   Dublin 20
# 9367                     Apt 12 Millrace Drive, Saggart        None
# 9777                   BON-HOMIE, BOHERBOY, CAHIRCIVEEN        None
# 9811       76 MARLINSTOWN PARK, MULLINGAR, CO WESTMEATH        None
# 9855                7 BEECHWOOD AVENUE, RAPHOE, LIFFORD        None
# 9966       Apartment 14, First Floor - Block B, Belvoir        None
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 199     Kildare  235000.00                    No            No
# 479     Leitrim  132159.00                    No            No
# 738       Clare   48242.00                    No            No
# 822     Wexford  130000.00                    No            No
# 1004    Donegal   90000.00                   Yes            No
# 1382  Westmeath  125000.00                    No            No
# 1389      Sligo   48000.00                   Yes            No
# 1704  Tipperary  140000.00                    No            No
# 2458     Carlow  107825.00                    No            No
# 2744   Longford   35000.00                    No            No
# 3540     Galway   57750.00                    No            No
# 4121       Cork   99000.00                   Yes            No
# 4653      Clare  170500.00                    No            No
# 5459       Cork  210000.00                    No            No
# 5949       Cork   89000.00                    No            No
# 5956     Galway   86242.00                    No            No
# 6064     Offaly   20000.00                    No            No
# 6099     Dublin  475000.00                    No            No
# 6145     Dublin  619500.00                    No            No
# 6206      Cavan  370000.00                    No            No
# 6807    Donegal  114276.42                    No            No
# 6991    Donegal   97500.00                    No            No
# 7138      Kerry   80000.00                    No            No
# 7300    Kildare  235000.00                    No            No
# 7912       Cork  250000.00                    No            No
# 8292       Cork  170000.00                    No            No
# 8557      Louth   70000.00                    No            No
# 8731      Sligo  172000.00                   Yes            No
# 8749     Galway   88350.00                    No            No
# 9263     Dublin  415000.00                    No            No
# 9367     Dublin  205000.00                    No            No
# 9777      Kerry   80648.00                    No            No
# 9811  Westmeath  210800.00                    No            No
# 9855    Donegal   60690.00                   Yes            No
# 9966     Dublin  476678.00                    No            No
#
#             Description of Property  \
# 199   New Dwelling house /Apartment
# 479   New Dwelling house /Apartment
# 738   New Dwelling house /Apartment
# 822   New Dwelling house /Apartment
# 1004  New Dwelling house /Apartment
# 1382  New Dwelling house /Apartment
# 1389  New Dwelling house /Apartment
# 1704  New Dwelling house /Apartment
# 2458  New Dwelling house /Apartment
# 2744  New Dwelling house /Apartment
# 3540  New Dwelling house /Apartment
# 4121  New Dwelling house /Apartment
# 4653  New Dwelling house /Apartment
# 5459  New Dwelling house /Apartment
# 5949  New Dwelling house /Apartment
# 5956  New Dwelling house /Apartment
# 6064  New Dwelling house /Apartment
# 6099  New Dwelling house /Apartment
# 6145  New Dwelling house /Apartment
# 6206  New Dwelling house /Apartment
# 6807  New Dwelling house /Apartment
# 6991  New Dwelling house /Apartment
# 7138  New Dwelling house /Apartment
# 7300  New Dwelling house /Apartment
# 7912  New Dwelling house /Apartment
# 8292  New Dwelling house /Apartment
# 8557  New Dwelling house /Apartment
# 8731  New Dwelling house /Apartment
# 8749  New Dwelling house /Apartment
# 9263  New Dwelling house /Apartment
# 9367  New Dwelling house /Apartment
# 9777  New Dwelling house /Apartment
# 9811  New Dwelling house /Apartment
# 9855  New Dwelling house /Apartment
# 9966  New Dwelling house /Apartment
#
#                               Property Size Description  Month  Year
# 199   greater than or equal to 38 sq metres and less...      8  2017
# 479   greater than or equal to 38 sq metres and less...      8  2016
# 738   greater than or equal to 38 sq metres and less...      8  2014
# 822   greater than or equal to 38 sq metres and less...     12  2016
# 1004                             less than 38 sq metres      6  2011
# 1382  greater than or equal to 38 sq metres and less...      8  2012
# 1389  greater than or equal to 38 sq metres and less...      4  2013
# 1704  greater than or equal to 38 sq metres and less...      1  2010
# 2458  greater than or equal to 38 sq metres and less...     11  2018
# 2744  greater than or equal to 38 sq metres and less...      6  2015
# 3540                             less than 38 sq metres      6  2013
# 4121                             less than 38 sq metres      4  2012
# 4653  greater than or equal to 38 sq metres and less...      7  2010
# 5459                         greater than 125 sq metres     10  2012
# 5949  greater than or equal to 38 sq metres and less...      7  2016
# 5956  greater than or equal to 38 sq metres and less...      1  2017
# 6064                             less than 38 sq metres      7  2017
# 6099  greater than or equal to 38 sq metres and less...      7  2015
# 6145  greater than or equal to 38 sq metres and less...      2  2015
# 6206                                               None     11  2019
# 6807  greater than or equal to 38 sq metres and less...      5  2014
# 6991                                               None     10  2019
# 7138  greater than or equal to 38 sq metres and less...      6  2016
# 7300  greater than or equal to 38 sq metres and less...      8  2017
# 7912  greater than or equal to 38 sq metres and less...      2  2015
# 8292  greater than or equal to 38 sq metres and less...      1  2010
# 8557                             less than 38 sq metres     11  2018
# 8731                         greater than 125 sq metres     12  2010
# 8749                                               None     11  2018
# 9263  greater than or equal to 38 sq metres and less...      9  2018
# 9367  greater than or equal to 38 sq metres and less...      9  2015
# 9777  greater than or equal to 38 sq metres and less...      9  2013
# 9811  greater than or equal to 38 sq metres and less...      1  2018
# 9855                                               None      2  2021
# 9966                                               None      9  2021

# %% [markdown]
# - Only 35 "New Dwelling house/Apartment" are marked as 'No' for Vat Exclusive.
# - The other 1601 are marked as 'Yes'.
# - This is in line with the information for the revenue regarding VAT payments on new property.
# - New properties that meet certain conditions must pay VAT at a rate of 13.5%- https://www.revenue.ie/en/property/stamp-duty/consideration/vat-exclusive-consideration.aspx#:~:text=If%20you%20buy%20or%20lease,on%20the%20VAT%2Dexclusive%20amount.
# - This does not apply to second hand property which we can see in the data:

# %%
print("number of 'No' VAT exclusives: '",(df['VAT Exclusive'] == 'No').sum())
# Out:
# number of 'No' VAT exclusives: ' 8399

# %% [markdown]
# - For this there is no reason to extract or remove any of the Vat Exclusive data as there are differences only for a very small amount of data and the difference may only be 13.5%

# %% [markdown]
# ## Looking at the outliers of the price data

# %% [markdown]
# As you can see there is a large range of values for the target feature of price.

# %%
print(df['Price (€)'].mean(), "mean of price data")
print(df['Price (€)'].std(), "standard deviation of price data")
# Out:
# 260260.70267600025 mean of price data
# 390170.3229389402 standard deviation of price data

# %% [markdown]
# There are some sales that were very high in price. These are explored in more detail later:

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#         Price (€)
# 4518  17151248.00
# 7913  16308370.05
# 7698   9515419.00
# 915    7600000.00
# 6404   7405286.34
# 3167   6720000.00
# 3999   6680000.00
# 5961   6200000.00
# 9789   6000000.00
# 2645   5250000.00

# %% [markdown]
# #### Evaluating the lower end outliers:

# %% [markdown]
# - As you can see some values for sales are extremely low like €5500. Having looked into these sales these sales in more detail there are number of reasons for this.
# - For example, some are that low because they are ruins that were bought 9 years ago. Thus, It is difficult to determine if they were input mistakes or genunine mistakes.
# - Due to this uncertainty I have decided to keep these outliers.

# %%
df.sort_values(by='Price (€)', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#       Price (€)
# 2094     5500.0
# 8321     5500.0
# 4708     6000.0
# 2661     6348.0
# 2772     6608.0
# 2950     7250.0
# 2582     7300.0
# 2846     7500.0
# 5542     7500.0
# 2749     7500.0

# %%
df.loc[df['Price (€)'] <= 10000]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 624        2018-05-29 00:00:00
# 849        2014-08-20 00:00:00
# 1276       2017-11-09 00:00:00
# 1320       2016-04-13 00:00:00
# 1480       2015-09-22 00:00:00
# 1580       2010-03-12 00:00:00
# 2094       2015-12-14 00:00:00
# 2267       2015-10-06 00:00:00
# 2582       2019-02-04 00:00:00
# 2661       2013-10-14 00:00:00
# 2749       2015-06-02 00:00:00
# 2772       2015-12-22 00:00:00
# 2783       2013-11-12 00:00:00
# 2846       2017-01-06 00:00:00
# 2950       2016-11-01 00:00:00
# 2972       2017-07-31 00:00:00
# 3635       2017-03-13 00:00:00
# 3863       2021-02-26 00:00:00
# 3907       2016-01-03 00:00:00
# 4131       2017-10-10 00:00:00
# 4143       2019-04-02 00:00:00
# 4188       2021-06-17 00:00:00
# 4284       2020-06-17 00:00:00
# 4708       2018-06-19 00:00:00
# 5378       2018-06-07 00:00:00
# 5487       2013-12-20 00:00:00
# 5542       2012-06-01 00:00:00
# 6003       2013-12-20 00:00:00
# 7644       2011-10-10 00:00:00
# 8321       2013-12-17 00:00:00
# 9200       2020-10-11 00:00:00
#
#                                                 Address Postal Code  \
# 624                    617 HOWTH ROAD, RAHENY, DUBLIN 5    Dublin 5
# 849                           Glensharrold, Carrickerry        None
# 1276        226 CASTLE CURRAGH HEATH, DUBLIN 15, DUBLIN   Dublin 15
# 1320                        RAEMORE, KIELDUFF, CO KERRY        None
# 1480  20 MILLWHARF APARTMENTS, MERCHANTS QUAY, DROGHEDA        None
# 1580                              MAIN STREET, KILTEALY        None
# 2094         19 Aranleigh Mount, Rathfarnham, Dublin 14   Dublin 14
# 2267        APT 35 BUCKINGHAM VILLAGE, DUBLIN 1, DUBLIN    Dublin 1
# 2582               74 SPRING LANE RD, BALLYVOLANE, CORK        None
# 2661                          Friarsquarter, Ballinrobe        None
# 2749                  221 Cratloewood, Old Cratloe Road        None
# 2772              34 Tir an Choir, Vicorschorland, TUAM        None
# 2783                           COILBEE, LISTOWEL, KERRY        None
# 2846            5 THE CLOSET APTS, ROSEMARY ST, ROSCREA        None
# 2950             31 SHIP STREET, DROGHEDA, COUNTY LOUTH        None
# 2972                    4 DUBLIN RD UPPER, TUAM, GALWAY        None
# 3635                  MULLAGHBOY, TULLYHUNCO, KILTRASNA        None
# 3863                   ST JOHNS, MAGHERACLOGHER, BUNBEG        None
# 3907                       LAVALLY, BALLINTOGHER, SLIGO        None
# 4131                  APARTMENT 1, THE SQUARE, SWINFORD        None
# 4143                      MEENBANE, BALLYBOFEY, DONEGAL        None
# 4188                    BALLYBANNON, MILFORD, CO CARLOW        None
# 4284                  RHUE, KILMORE, CARRICK ON SHANNON        None
# 4708                     NEW STREET, LITTLETON, THURLES        None
# 5378                     MOUNTIRWIN, GURTEEN, BALLYMOTE        None
# 5487  64 Rosanule, Phoenix Park Racecourse, Castleknock   Dublin 15
# 5542                           Garra, Ballyglunin, Tuam        None
# 6003  13 Phoenix Park Way, Phoenix Park Racecourse, ...   Dublin 15
# 7644                               Rathvilla, Edenderry        None
# 8321                       SHRAIGH, BUNNAHOWEN, BALLINA        None
# 9200                   8 ORANHILL AVE, ORANMORE, GALWAY        None
#
#          County  Price (€) Not Full Market Price VAT Exclusive  \
# 624      Dublin   10000.00                    No            No
# 849    Limerick    8000.00                    No            No
# 1276     Dublin    8697.91                    No            No
# 1320      Kerry   10000.00                    No            No
# 1480      Louth    9039.78                    No            No
# 1580    Wexford   10000.00                    No            No
# 2094     Dublin    5500.00                    No            No
# 2267     Dublin   10000.00                    No            No
# 2582       Cork    7300.00                    No            No
# 2661       Mayo    6348.00                    No            No
# 2749   Limerick    7500.00                    No           Yes
# 2772     Galway    6608.00                    No           Yes
# 2783      Kerry   10000.00                    No            No
# 2846  Tipperary    7500.00                    No            No
# 2950      Louth    7250.00                    No            No
# 2972     Galway   10000.00                   Yes            No
# 3635      Cavan   10000.00                    No            No
# 3863    Donegal    9000.00                   Yes            No
# 3907      Sligo   10000.00                    No            No
# 4131       Mayo   10000.00                    No            No
# 4143    Donegal   10000.00                    No            No
# 4188     Carlow   10000.00                    No            No
# 4284  Roscommon   10000.00                    No            No
# 4708  Tipperary    6000.00                   Yes            No
# 5378      Sligo   10000.00                    No            No
# 5487     Dublin    8000.00                    No           Yes
# 5542     Galway    7500.00                   Yes            No
# 6003     Dublin    8000.00                    No           Yes
# 7644     Offaly   10000.00                    No            No
# 8321       Mayo    5500.00                   Yes            No
# 9200     Galway    7770.00                    No            No
#
#                     Description of Property  \
# 624   Second-Hand Dwelling house /Apartment
# 849   Second-Hand Dwelling house /Apartment
# 1276  Second-Hand Dwelling house /Apartment
# 1320  Second-Hand Dwelling house /Apartment
# 1480  Second-Hand Dwelling house /Apartment
# 1580  Second-Hand Dwelling house /Apartment
# 2094  Second-Hand Dwelling house /Apartment
# 2267  Second-Hand Dwelling house /Apartment
# 2582  Second-Hand Dwelling house /Apartment
# 2661  Second-Hand Dwelling house /Apartment
# 2749          New Dwelling house /Apartment
# 2772          New Dwelling house /Apartment
# 2783  Second-Hand Dwelling house /Apartment
# 2846  Second-Hand Dwelling house /Apartment
# 2950  Second-Hand Dwelling house /Apartment
# 2972  Second-Hand Dwelling house /Apartment
# 3635  Second-Hand Dwelling house /Apartment
# 3863  Second-Hand Dwelling house /Apartment
# 3907  Second-Hand Dwelling house /Apartment
# 4131  Second-Hand Dwelling house /Apartment
# 4143  Second-Hand Dwelling house /Apartment
# 4188  Second-Hand Dwelling house /Apartment
# 4284  Second-Hand Dwelling house /Apartment
# 4708  Second-Hand Dwelling house /Apartment
# 5378  Second-Hand Dwelling house /Apartment
# 5487          New Dwelling house /Apartment
# 5542  Second-Hand Dwelling house /Apartment
# 6003          New Dwelling house /Apartment
# 7644  Second-Hand Dwelling house /Apartment
# 8321  Second-Hand Dwelling house /Apartment
# 9200  Second-Hand Dwelling house /Apartment
#
#                               Property Size Description  Month  Year
# 624                                                None      5  2018
# 849                                                None      8  2014
# 1276                                               None     11  2017
# 1320                                               None      4  2016
# 1480                                               None      9  2015
# 1580                                               None      3  2010
# 2094                                               None     12  2015
# 2267                                               None     10  2015
# 2582                                               None      2  2019
# 2661                                               None     10  2013
# 2749                             less than 38 sq metres      6  2015
# 2772  greater than or equal to 38 sq metres and less...     12  2015
# 2783                                               None     11  2013
# 2846                                               None      1  2017
# 2950                                               None     11  2016
# 2972                                               None      7  2017
# 3635                                               None      3  2017
# 3863                                               None      2  2021
# 3907                                               None      1  2016
# 4131                                               None     10  2017
# 4143                                               None      4  2019
# 4188                                               None      6  2021
# 4284                                               None      6  2020
# 4708                                               None      6  2018
# 5378                                               None      6  2018
# 5487  greater than or equal to 38 sq metres and less...     12  2013
# 5542                                               None      6  2012
# 6003  greater than or equal to 38 sq metres and less...     12  2013
# 7644                                               None     10  2011
# 8321                                               None     12  2013
# 9200                                               None     10  2020

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
# Out:
# array([[<AxesSubplot:title={'center':'Price (€)'}>]], dtype=object)

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#         Price (€)
# 4518  17151248.00
# 7913  16308370.05
# 7698   9515419.00
# 915    7600000.00
# 6404   7405286.34
# 3167   6720000.00
# 3999   6680000.00
# 5961   6200000.00
# 9789   6000000.00
# 2645   5250000.00

# %% [markdown]
# ### Dropping apartment blocks and multiple housing units:

# %% [markdown]
# - The sale of property such as those worth €17,151,248 and €16308370.05 have been dropped.
# - As these is a large blocks of apartments. Thus, it does not makes sense to compare it to other sing dwellings which is our overall aim.

# %% [markdown]
# ### Looking for addresses that are selling as multiple 'units':

# %%
df[df['Address'].str.contains("Units")]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 561        2020-11-20 00:00:00
# 4459       2020-01-10 00:00:00
# 6404       2020-09-09 00:00:00
#
#                                                 Address Postal Code  County  \
# 561   Units 51-54 Sruthan Na Sailí, & Apts.1-18 Áras...        None   Kerry
# 4459                    Units 1-7  Croppy Boy, Fairhill        None    Cork
# 6404                  Units 1-24, Block C, Gandon Grove        None  Dublin
#
#        Price (€) Not Full Market Price VAT Exclusive  \
# 561   4096916.28                    No           Yes
# 4459  1788546.26                    No           Yes
# 6404  7405286.34                    No           Yes
#
#             Description of Property Property Size Description  Month  Year
# 561   New Dwelling house /Apartment                      None     11  2020
# 4459  New Dwelling house /Apartment                      None      1  2020
# 6404  New Dwelling house /Apartment                      None      9  2020

# %%
df[df['Address'].str.contains("units")]
# Out:
# Empty DataFrame
# Columns: [Date of Sale (yyyy/mm/dd), Address, Postal Code, County, Price (€), Not Full Market Price, VAT Exclusive, Description of Property, Property Size Description, Month, Year]
# Index: []

# %%
df[df['Address'].str.contains("unit")]
# Out:
#      Date of Sale (yyyy/mm/dd)  \
# 2292       2016-10-20 00:00:00
# 4624       2018-07-27 00:00:00
#
#                                                 Address Postal Code  County  \
# 2292  unit 11 Hampton Gardens Drive, Balbriggan, Cou...        None  Dublin
# 4624      unit 3 Parkside Glen, parkside, malahide road        None  Dublin
#
#       Price (€) Not Full Market Price VAT Exclusive  \
# 2292  180616.74                    No           Yes
# 4624  361233.00                    No           Yes
#
#             Description of Property  \
# 2292  New Dwelling house /Apartment
# 4624  New Dwelling house /Apartment
#
#                               Property Size Description  Month  Year
# 2292  greater than or equal to 38 sq metres and less...     10  2016
# 4624  greater than or equal to 38 sq metres and less...      7  2018

# %% [markdown]
# #### Dropping necessary indexes:

# %%
# All large blocks of apartments with no accurate way of braking up the dwellings and determining their individual prices

df = df.drop(index=7913)
df = df.drop(index=4518)
df = df.drop(index=7698)
df = df.drop(index=6404)
df = df.drop(index=3999)
df = df.drop(index=561)
df = df.drop(index=4459)

# %% [markdown]
# ####  With outliers removed:

# %%
df.sort_values(by='Price (€)', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')[['Price (€)']].head(10)
# Out:
#        Price (€)
# 915   7600000.00
# 3167  6720000.00
# 5961  6200000.00
# 9789  6000000.00
# 2645  5250000.00
# 4438  5127753.00
# 2542  5000000.00
# 787   4138200.00
# 8462  3691629.96
# 242   3350000.00

# %% [markdown]
# #### The histogram of price looks like this with the outliers removed which is now slightly better visually:

# %% [markdown]
# - There is is still a large spread of data. However, it has been tighten slightly.

# %%
df.hist(column='Price (€)', bins='auto', grid=False, figsize=(19,12), color='#86bf91', zorder=2, rwidth=.9)
# Out:
# array([[<AxesSubplot:title={'center':'Price (€)'}>]], dtype=object)

# %% [markdown]
# ## Final Summary of Data Quality Plan

# %% [markdown]
# | Variable Name | Data Quality Issue | Handling Stratergy |
# | :- | :- | :- |
# | Price (€) | Outliers | Remove high outliers, keep low outliers |
# | Postal Code | Missing data |Do nothing|
# | Description of Property | Descriptions were in Irish | Irish descriptions were tranlated so there were only two unique values for consistency |
# | Propert Size Description | Missing data | Do nothing |
# | VAT exclusive | Provides varying info, with potentially not much meaning | Do nothing |
# | Date of Sale| There are dates in the future | Edit future dates |
# | Not Full Market Price	| very small % dwellings are not full market price | Removed |

# %%
df[numeric_columns].describe().T
# Out:
#             count         mean            std     min       25%       50%  \
# Price (€)  9993.0  254144.0249  280108.039388  5500.0  120000.0  200000.0
#
#                 75%        max
# Price (€)  308370.0  7600000.0

# %%
df[category_columns].describe().T
# Out:
#                           count unique                                    top  \
# Address                    9993   9973               SUFFOLK ST, KELLS, MEATH
# Postal Code                9993     23                                   None
# County                     9993     26                                 Dublin
# Not Full Market Price      9993      2                                     No
# VAT Exclusive              9993      2                                     No
# Description of Property    9993      2  Second-Hand Dwelling house /Apartment
# Property Size Description  9993      5                                   None
#
#                            freq
# Address                       2
# Postal Code                8134
# County                     3188
# Not Full Market Price      9545
# VAT Exclusive              8397
# Description of Property    8362
# Property Size Description  8964

# %% [markdown]
# #### Applying solutions to new csv file with the issues addressed:

# %%
df.to_csv('cleanedCSV_after_data_quality_plan-ppr-17350796.csv', index=False)

# %% [markdown]
# <h1><center>Part 3: Exploring the relationships between feature pairs:</center></h1>

# %% [markdown]
# We want to be able to say something about the price data.
# The features that I will look at for pairwise interaction:
#
# - County
# - Date
#     - Year
#     - Month
# - Description of property
# - Postal Code
#
# The reasons for these choices, are these factors could all give insight and to provide markers into house prices. More detail on this is given throughout the section.

# %% [markdown]
# ### County and Price

# %% [markdown]
# -  The reason for this comparison as I want to see how prices change with counties. Location is often a key factor that dictates house prices. The counties of Ireland provide a clear boundary to assess different areas of the country.

# %% [markdown]
# ### Finding median and average Price Per County

# %%
#creating data frame of just price and county
df_Price_Per_county = df[['County', 'Price (€)']].copy()

df_Price_Per_county.head(5)
# Out:
#      County  Price (€)
# 0    Dublin   630000.0
# 1    Dublin   281000.0
# 2    Dublin   560000.0
# 3  Kilkenny    46000.0
# 4     Clare   204000.0

# %% [markdown]
# ### Full description:

# %%
df_Price_Per_county.groupby(['County']).describe()
# Out:
#           Price (€)                                                    \
#               count           mean            std       min       25%
# County
# Carlow        124.0  143656.524758   86606.590885  10000.00   80000.0
# Cavan         153.0  122956.608824   81710.531446  10000.00   62000.0
# Clare         240.0  172906.232208  175103.077687  16000.00   85000.0
# Cork         1098.0  219647.882213  155434.157456   7300.00  123917.0
# Donegal       274.0  118046.671861   71647.433521   9000.00   65000.0
# Dublin       3188.0  396231.655326  392734.840279   5500.00  220000.0
# Galway        502.0  200292.352390  163667.001964   6608.00  103131.0
# Kerry         284.0  165515.118873  102083.938114  10000.00   88750.0
# Kildare       483.0  283365.438302  333521.854346  34140.94  186487.0
# Kilkenny      133.0  185045.541429  130124.001864  35000.00  110000.0
# Laois         163.0  148705.788589   88317.719643  16000.00   85000.0
# Leitrim        99.0  103665.406162   84042.939933  15000.00   55000.0
# Limerick      348.0  167723.789138  102098.265175   7500.00   90000.0
# Longford       90.0  102993.677556  110390.585117  18320.00   50000.0
# Louth         288.0  177240.498958  140659.106720   7250.00   98750.0
# Mayo          259.0  128095.167722   97738.890287   5500.00   59000.0
# Meath         399.0  245427.156216  130016.056988  25000.00  171000.0
# Monaghan       76.0  153715.143816  117350.019675  20000.00   67799.0
# Offaly        119.0  141661.260672  117975.542116  10000.00   76000.0
# Roscommon     143.0  106894.540000   70019.562763  10000.00   52250.0
# Sligo         148.0  117806.779122   89699.571544  10000.00   60750.0
# Tipperary     283.0  130040.683816   84666.421252   6000.00   64000.0
# Waterford     245.0  157052.875633  107326.152720  25000.00   80000.0
# Westmeath     174.0  158190.980632  100160.117987  13333.00   90250.0
# Wexford       363.0  187763.779642  253636.561822  10000.00   97000.0
# Wicklow       317.0  313226.456088  196625.696136  30000.00  195000.0
#
#
#                 50%          75%         max
# County
# Carlow     136000.0  179750.0000   540000.00
# Cavan      102000.0  155000.0000   370000.00
# Clare      146500.0  217125.0000  2275000.00
# Cork       190000.0  275000.0000  1905000.00
# Donegal    104000.0  150000.0000   420000.00
# Dublin     312328.5  445000.0000  7600000.00
# Galway     175000.0  255000.0000  2026432.00
# Kerry      144215.0  225000.0000   643172.00
# Kildare    254800.0  317840.3100  6720000.00
# Kilkenny   165000.0  225000.0000  1150000.00
# Laois      138000.0  185875.0000   500000.00
# Leitrim     85000.0  129750.0000   670000.00
# Limerick   154500.0  228268.7500   640044.00
# Longford    82500.0  125000.0000   990806.50
# Louth      161000.0  222584.3375  1900000.00
# Mayo       110000.0  166000.0000   705000.00
# Meath      232000.0  305000.0000  1636123.00
# Monaghan   149000.0  180000.0000   850000.00
# Offaly     112450.0  172500.0000   800000.00
# Roscommon   90000.0  147500.0000   330000.00
# Sligo       95000.0  155000.0000   700000.00
# Tipperary  120000.0  173750.0000   665700.00
# Waterford  142000.0  200000.0000  1100000.00
# Westmeath  143250.0  195000.0000   600000.00
# Wexford    155000.0  220000.0000  3691629.96
# Wicklow    281939.0  383259.0000  1440000.00

# %% [markdown]
# Making new data frame with just group county and mean

# %%
mean_price_per_county= df_Price_Per_county.groupby(['County']).mean().reset_index()


mean_price_per_county.sort_values(by=['Price (€)'], inplace=True)
print(mean_price_per_county)
# Out:
#        County      Price (€)
# 13   Longford  102993.677556
# 11    Leitrim  103665.406162
# 19  Roscommon  106894.540000
# 20      Sligo  117806.779122
# 4     Donegal  118046.671861
# 1       Cavan  122956.608824
# 15       Mayo  128095.167722
# 21  Tipperary  130040.683816
# 18     Offaly  141661.260672
# 0      Carlow  143656.524758
# 10      Laois  148705.788589
# 17   Monaghan  153715.143816
# 22  Waterford  157052.875633
# 23  Westmeath  158190.980632
# 7       Kerry  165515.118873
# 12   Limerick  167723.789138
# 2       Clare  172906.232208
# 14      Louth  177240.498958
# 9    Kilkenny  185045.541429
# 24    Wexford  187763.779642
# 6      Galway  200292.352390
# 3        Cork  219647.882213
# 16      Meath  245427.156216
# 8     Kildare  283365.438302
# 25    Wicklow  313226.456088
# 5      Dublin  396231.655326

# %%
sns.catplot(x="County", y= "Price (€)", kind="bar",aspect=4,data=mean_price_per_county)

# %% [markdown]
# ### Both the median and the mean provide similar results

# %%
median_price_per_county = df_Price_Per_county.groupby(['County']).median().reset_index()

median_price_per_county.sort_values(by=['Price (€)'], inplace=True)
print(median_price_per_county)
# Out:
#        County  Price (€)
# 13   Longford    82500.0
# 11    Leitrim    85000.0
# 19  Roscommon    90000.0
# 20      Sligo    95000.0
# 1       Cavan   102000.0
# 4     Donegal   104000.0
# 15       Mayo   110000.0
# 18     Offaly   112450.0
# 21  Tipperary   120000.0
# 0      Carlow   136000.0
# 10      Laois   138000.0
# 22  Waterford   142000.0
# 23  Westmeath   143250.0
# 7       Kerry   144215.0
# 2       Clare   146500.0
# 17   Monaghan   149000.0
# 12   Limerick   154500.0
# 24    Wexford   155000.0
# 14      Louth   161000.0
# 9    Kilkenny   165000.0
# 6      Galway   175000.0
# 3        Cork   190000.0
# 16      Meath   232000.0
# 8     Kildare   254800.0
# 25    Wicklow   281939.0
# 5      Dublin   312328.5

# %%
sns.catplot(x="County", y= "Price (€)", kind="bar",aspect=4,data=median_price_per_county)

# %% [markdown]
# ### Interpretation

# %% [markdown]
# - As you can see Dublin has the highest amount with Longford, Roscommon and Leitrim being the lowest. The counties that border Dublin like Meath, Wicklow and Kildare all have very high median and mean values.
# - We can clearly see that the area of Dublin is the most sought after.

# %%
sns.catplot(x="County", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### County and Price Box plot

# %%
sns.catplot(x="County", y= "Price (€)", kind="box",aspect=4,data=df)

# %% [markdown]
# ### Year and Price

# %% [markdown]
# - Year and Price is another very important interaction as we are aiming to predict price which means we must look to the future. The year to year trends are very important for this.

# %% [markdown]
# ### Year and Price bar chart

# %% [markdown]
# - As you can see 2012 has the lowest with 2021 having the highest

# %%
sns.catplot(x="Year", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### Median and Average Price Per Year

# %%
df_Price_Per_year = df[['Year', 'Price (€)']].copy()

df_Price_Per_year.head(5)
# Out:
#    Year  Price (€)
# 0  2016   630000.0
# 1  2014   281000.0
# 2  2020   560000.0
# 3  2014    46000.0
# 4  2018   204000.0

# %% [markdown]
# ### Full description table of price grouped by Year:

# %%
df_Price_Per_year.groupby(['Year']).describe()
# Out:
#      Price (€)                                                               \
#          count           mean            std      min        25%        50%
# Year
# 2010     412.0  224643.019951  157192.930640  10000.0  136875.00  200000.00
# 2011     369.0  219054.456558  206419.722487  10000.0  110132.00  175000.00
# 2012     506.0  181532.374605  153257.033998   7500.0   90000.00  145374.50
# 2013     585.0  203643.650462  220379.267323   5500.0   80000.00  140000.00
# 2014     808.0  212177.482092  294579.769583   8000.0   80975.60  150000.00
# 2015    1003.0  223259.339182  263648.172099   5500.0   90000.00  164537.00
# 2016     937.0  238362.960918  270581.705049   7250.0  105000.00  185500.00
# 2017    1060.0  266338.501613  318113.095142   7500.0  127938.25  211226.50
# 2018    1172.0  265961.352850  257800.119201   6000.0  135000.00  217250.00
# 2019    1149.0  283149.717328  278349.470145   7300.0  156000.00  245000.00
# 2020     936.0  289165.761090  261154.926478   7770.0  154750.00  242470.48
# 2021    1046.0  329212.255373  386364.365416   9000.0  170000.00  260000.00
# 2022      10.0  219597.400000   94588.345423  30000.0  167493.50  224000.00
#
#
#             75%        max
# Year
# 2010  266640.00  1550000.0
# 2011  255000.00  2480000.0
# 2012  220000.00  1425000.0
# 2013  240000.00  2050000.0
# 2014  245000.00  6000000.0
# 2015  267500.00  5000000.0
# 2016  295000.00  5250000.0
# 2017  325000.00  7600000.0
# 2018  317000.00  4138200.0
# 2019  334091.00  6200000.0
# 2020  346111.25  3350000.0
# 2021  370000.00  6720000.0
# 2022  273500.00   382000.0

# %% [markdown]
# - Finding the mean of year and putting into its own data frame in order to visualise with graphs.

# %%
mean_price_per_year = df_Price_Per_year.groupby(['Year']).mean().reset_index()

mean_price_per_year
# Out:
#     Year      Price (€)
# 0   2010  224643.019951
# 1   2011  219054.456558
# 2   2012  181532.374605
# 3   2013  203643.650462
# 4   2014  212177.482092
# 5   2015  223259.339182
# 6   2016  238362.960918
# 7   2017  266338.501613
# 8   2018  265961.352850
# 9   2019  283149.717328
# 10  2020  289165.761090
# 11  2021  329212.255373
# 12  2022  219597.400000

# %%
scatter_plot_mean_price_year = mean_price_per_year.plot.scatter(x='Year',
                      y='Price (€)')

# %%
sns.catplot(x="Year", y= "Price (€)", kind="bar",aspect=4,data=mean_price_per_year)

# %%
median_price_per_year = df_Price_Per_year.groupby(['Year']).median().reset_index()

# %%
scatter_plot_median_price_year = median_price_per_year.plot.scatter(x='Year',
                      y='Price (€)')

# %%
sns.catplot(x="Year", y= "Price (€)", kind="bar",aspect=4,data=median_price_per_year)

# %% [markdown]
# #### Interpretation of above

# %% [markdown]
# - From looking at the scatter plots and bar charts for mean and median per year you can see certain trend of prices.
# - There has been a sharp increase in house prices from 2012/2013

# %% [markdown]
# ### Year and Price boxplot

# %% [markdown]
# As you can see there are a lot of outliers outliears throughout the 12 years:

# %%
sns.catplot(x="Year", y= "Price (€)", kind="box",aspect=4,data=df)

# %% [markdown]
# ### Month and Price bar plot

# %% [markdown]
# - As you can see for each month over the time price stays relatively consistent

# %%
sns.catplot(x="Month", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### Month and Price boxplot

# %%
sns.catplot(x="Month", y= "Price (€)", kind="box",aspect=4 ,data=df)

# %% [markdown]
# ### Decription of property and Price bar chart

# %% [markdown]
# - From the below analysis you can clearly see that new properties tend to be more expensive.

# %%
df_property_description = df[['Description of Property', 'Price (€)']].copy()

df_property_description.head(5)
# Out:
#                  Description of Property  Price (€)
# 0  Second-Hand Dwelling house /Apartment   630000.0
# 1  Second-Hand Dwelling house /Apartment   281000.0
# 2  Second-Hand Dwelling house /Apartment   560000.0
# 3  Second-Hand Dwelling house /Apartment    46000.0
# 4  Second-Hand Dwelling house /Apartment   204000.0

# %%
df_property_description.groupby(['Description of Property']).describe()
# Out:
#                                       Price (€)                                \
#                                           count           mean            std
# Description of Property
# New Dwelling house /Apartment            1631.0  280866.408749  240130.626692
# Second-Hand Dwelling house /Apartment    8362.0  248931.849816  286980.865311
#
#                                                                                \
#                                           min        25%       50%        75%
# Description of Property
# New Dwelling house /Apartment          6608.0  162998.00  250000.0  340704.84
# Second-Hand Dwelling house /Apartment  5500.0  112568.75  190000.0  300000.00
#
#
#                                              max
# Description of Property
# New Dwelling house /Apartment          5127753.0
# Second-Hand Dwelling house /Apartment  7600000.0

# %%
df_property_description.groupby(['Description of Property']).median()
# Out:
#                                        Price (€)
# Description of Property
# New Dwelling house /Apartment           250000.0
# Second-Hand Dwelling house /Apartment   190000.0

# %%
sns.catplot(x="Description of Property", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### Postal Code and Price bar chart

# %% [markdown]
# - While Postal Codes are not applicable to the marjority of the addresses in this data set. There do provide insight into the areas of Dublin which is the most represented county in Ireland.
# - The traditionally more 'affluent' areas of Dublin are represented with the highest amount of price like Dubline 4.

# %%
sns.catplot(x="Postal Code", y= "Price (€)", kind="bar",aspect=4,data=df)

# %%
df.groupby(['Postal Code']).describe()
# Out:
#             Price (€)                                                       \
#                 count           mean            std        min         25%
# Postal Code
# Dublin 1         76.0  299198.630000  241160.296752   10000.00  193000.000
# Dublin 10        20.0  210035.855000  140341.117977   48400.00  110454.825
# Dublin 11        93.0  223625.008495  112193.421056   28778.97  145564.000
# Dublin 12       104.0  296740.307885  131306.151132   72325.00  210000.000
# Dublin 13        85.0  405516.830824  537237.155007   74889.87  227000.000
# Dublin 14        84.0  531037.113690  284865.220662    5500.00  361250.000
# Dublin 15       232.0  288877.654267  165050.347195    8000.00  198022.500
# Dublin 16        96.0  465365.819062  193898.043227  140000.00  357500.000
# Dublin 17        24.0  213404.902500  107854.514940   73921.63  132787.000
# Dublin 18       143.0  485871.333566  344820.888732   39000.00  265000.000
# Dublin 2         34.0  446535.647059  351341.909714  140000.00  234000.000
# Dublin 20        25.0  273777.224800  148360.149525   67000.00  165000.000
# Dublin 22        54.0  238867.101296   95035.315465   21771.13  170000.000
# Dublin 24       114.0  254402.011842   91925.869671   35000.00  187000.000
# Dublin 3         82.0  452822.391463  334645.470284   52320.00  270088.500
# Dublin 4        109.0  828341.047798  925813.389294  142690.00  360000.000
# Dublin 5         78.0  359048.699231  144750.928779   10000.00  275250.000
# Dublin 6         66.0  709703.581212  460466.254370   90000.00  378750.000
# Dublin 6w        18.0  459598.545556  192907.856144  220000.00  344325.000
# Dublin 7         88.0  337756.520341  277278.661469   50000.00  209262.000
# Dublin 8        115.0  302620.357739  168103.197336   88611.92  206250.000
# Dublin 9        119.0  358800.386723  311268.102011   80000.00  218750.000
# None           8134.0  223014.892263  244523.166678    5500.00  105000.000
#
#                                                   Month            ...         \
#                    50%          75%         max   count      mean  ...    75%
# Postal Code                                                        ...
# Dublin 1     258500.00  340250.0000  1880000.00    76.0  6.552632  ...  10.00
# Dublin 10    192000.00  258250.0000   615000.00    20.0  7.050000  ...   9.00
# Dublin 11    215000.00  310000.0000   495000.00    93.0  7.365591  ...  11.00
# Dublin 12    275551.50  381250.0000   985000.00   104.0  6.673077  ...  10.00
# Dublin 13    315000.00  470000.0000  5000000.00    85.0  6.494118  ...   9.00
# Dublin 14    485000.00  649062.5000  1600000.00    84.0  6.892857  ...  10.00
# Dublin 15    265000.00  337637.5000  1575000.00   232.0  6.495690  ...  10.00
# Dublin 16    445000.00  539125.0000  1500000.00    96.0  6.281250  ...   9.00
# Dublin 17    189250.00  255250.0000   541850.00    24.0  6.416667  ...  10.25
# Dublin 18    375000.00  548458.1100  1960000.00   143.0  6.573427  ...  10.00
# Dublin 2     330000.00  500000.0000  1600000.00    34.0  6.852941  ...   9.00
# Dublin 20    275000.00  385000.0000   720000.00    25.0  5.560000  ...   9.00
# Dublin 22    220000.00  280000.0000   550000.00    54.0  6.740741  ...  10.00
# Dublin 24    250000.00  321585.9750   580000.00   114.0  6.982456  ...  10.00
# Dublin 3     384000.00  575750.0000  2675000.00    82.0  6.475610  ...   8.75
# Dublin 4     476515.00  855000.0000  6000000.00   109.0  6.605505  ...   9.00
# Dublin 5     346500.00  426584.8475   792951.54    78.0  7.756410  ...  10.00
# Dublin 6     612500.00  931250.0000  2350000.00    66.0  7.469697  ...  10.00
# Dublin 6w    445599.50  500809.7500   966250.00    18.0  6.444444  ...  10.00
# Dublin 7     305000.00  377375.0000  2562500.00    88.0  6.875000  ...  10.00
# Dublin 8     265000.00  343500.0000  1085000.00   115.0  7.026087  ...  10.00
# Dublin 9     310000.00  409845.5000  2700100.00   119.0  6.403361  ...   9.50
# None         178788.39  275000.0000  7600000.00  8134.0  6.923285  ...  10.00
#
#                      Year                                                  \
#               max   count         mean       std     min      25%     50%
# Postal Code
# Dublin 1     12.0    76.0  2017.052632  2.746609  2011.0  2015.00  2017.0
# Dublin 10    11.0    20.0  2017.150000  2.539685  2012.0  2015.75  2017.0
# Dublin 11    12.0    93.0  2017.086022  2.976925  2010.0  2015.00  2018.0
# Dublin 12    12.0   104.0  2016.769231  2.756214  2010.0  2015.00  2017.0
# Dublin 13    12.0    85.0  2016.682353  2.816667  2010.0  2014.00  2017.0
# Dublin 14    12.0    84.0  2016.416667  3.046659  2010.0  2014.00  2016.0
# Dublin 15    12.0   232.0  2016.840517  2.754846  2010.0  2015.00  2017.0
# Dublin 16    12.0    96.0  2017.208333  2.894338  2010.0  2015.00  2017.0
# Dublin 17    12.0    24.0  2016.375000  2.373999  2012.0  2015.00  2015.5
# Dublin 18    12.0   143.0  2016.636364  2.588015  2010.0  2015.00  2016.0
# Dublin 2     12.0    34.0  2016.411765  2.362814  2012.0  2014.25  2016.0
# Dublin 20    12.0    25.0  2017.000000  2.768875  2010.0  2015.00  2017.0
# Dublin 22    12.0    54.0  2017.351852  2.291555  2012.0  2016.00  2018.0
# Dublin 24    12.0   114.0  2017.000000  2.456705  2010.0  2015.00  2017.0
# Dublin 3     12.0    82.0  2016.939024  2.441147  2010.0  2015.00  2017.0
# Dublin 4     12.0   109.0  2017.119266  2.999150  2010.0  2015.00  2017.0
# Dublin 5     12.0    78.0  2017.525641  3.218148  2010.0  2016.00  2018.0
# Dublin 6     12.0    66.0  2016.151515  3.014031  2010.0  2014.00  2016.0
# Dublin 6w    12.0    18.0  2014.888889  4.296221  2010.0  2011.00  2013.0
# Dublin 7     12.0    88.0  2016.636364  3.141059  2010.0  2014.75  2017.0
# Dublin 8     12.0   115.0  2017.269565  2.760377  2010.0  2015.00  2018.0
# Dublin 9     12.0   119.0  2016.857143  2.844220  2010.0  2015.00  2017.0
# None         12.0  8134.0  2016.435702  3.165540  2010.0  2014.00  2017.0
#
#
#                  75%     max
# Postal Code
# Dublin 1     2019.25  2022.0
# Dublin 10    2019.00  2021.0
# Dublin 11    2019.00  2021.0
# Dublin 12    2019.00  2021.0
# Dublin 13    2019.00  2021.0
# Dublin 14    2019.00  2021.0
# Dublin 15    2019.00  2021.0
# Dublin 16    2020.00  2021.0
# Dublin 17    2018.00  2021.0
# Dublin 18    2019.00  2021.0
# Dublin 2     2018.00  2021.0
# Dublin 20    2019.00  2021.0
# Dublin 22    2019.00  2021.0
# Dublin 24    2019.00  2021.0
# Dublin 3     2019.00  2021.0
# Dublin 4     2020.00  2021.0
# Dublin 5     2020.00  2022.0
# Dublin 6     2018.00  2021.0
# Dublin 6w    2019.75  2021.0
# Dublin 7     2019.00  2022.0
# Dublin 8     2019.00  2022.0
# Dublin 9     2019.00  2021.0
# None         2019.00  2022.0
#
# [23 rows x 24 columns]

# %%
df.groupby(['Postal Code']).median()
# Out:
#              Price (€)  Month    Year
# Postal Code
# Dublin 1     258500.00    6.0  2017.0
# Dublin 10    192000.00    8.0  2017.0
# Dublin 11    215000.00    7.0  2018.0
# Dublin 12    275551.50    7.0  2017.0
# Dublin 13    315000.00    7.0  2017.0
# Dublin 14    485000.00    7.0  2016.0
# Dublin 15    265000.00    6.0  2017.0
# Dublin 16    445000.00    6.0  2017.0
# Dublin 17    189250.00    6.0  2015.5
# Dublin 18    375000.00    7.0  2016.0
# Dublin 2     330000.00    7.0  2016.0
# Dublin 20    275000.00    4.0  2017.0
# Dublin 22    220000.00    6.0  2018.0
# Dublin 24    250000.00    7.0  2017.0
# Dublin 3     384000.00    6.0  2017.0
# Dublin 4     476515.00    7.0  2017.0
# Dublin 5     346500.00    8.0  2018.0
# Dublin 6     612500.00    8.0  2016.0
# Dublin 6w    445599.50    7.5  2013.0
# Dublin 7     305000.00    7.0  2017.0
# Dublin 8     265000.00    7.0  2018.0
# Dublin 9     310000.00    6.0  2017.0
# None         178788.39    7.0  2017.0

# %%
df_Price_Per_postalcode = df[['Postal Code', 'Price (€)']].copy()

mean_price_per_postalcode= df_Price_Per_postalcode.groupby(['Postal Code']).mean().reset_index()

# %%
sns.catplot(x="Postal Code", y= "Price (€)", kind="bar",aspect=4,data=mean_price_per_postalcode)

# %%
median_price_per_postalcode= df_Price_Per_postalcode.groupby(['Postal Code']).median().reset_index()

sns.catplot(x="Postal Code", y= "Price (€)", kind="bar",aspect=4,data=median_price_per_postalcode)

# %% [markdown]
# - Interestinly Dublin 4 has the highest mean, yet Dublin 6 has the highed median.
# - We can see this when we look at the descriptive table above that the area of Dublin 4 has a very large range of values.
# - It is important to keep in mind that these postal codes do not tell the whole story as large parts of North County Dublin and South County Dublin are not included.

# %% [markdown]
# ### Postal Code and Price boxplot

# %% [markdown]
# - We can see that Dublin 4 has a significant number of outliers here, that is way it has such a high average price:

# %%
sns.catplot(x="Postal Code", y= "Price (€)", kind="box",aspect=4,data=df)

# %% [markdown]
# ### Categorical vs Categorical feature plots

# %% [markdown]
# #### Comparing Description of Property and County

# %% [markdown]
# - This shows the percentage of New Dwellings to Second Hand dwellings:

# %%
County = pd.unique(df["County"].ravel())

# add new column and set values to zero
df['percent'] = 0

#print header
print("County")
print("Index \t Count")

for i in County:
    
    count = df[df["County"] == i].count()['Description of Property']
    count_percentage = (1 / count) * 100
        
    # print out index vs count
    print(i, "\t", count)
    
    index_list = df[df['County'] == i].index.tolist()
    for ind in index_list:
        df.loc[ind, 'percent'] = count_percentage
        
group = df[['percent','County','Description of Property']].groupby(['County','Description of Property']).sum()

my_plot = group.unstack().plot(kind='bar', stacked=True, title="County vs Description of Property", figsize=(15,7), grid=True)


my_plot.legend(["New Dwellings", "Second Hand"])
    
# add gridlines
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)

my_plot.set_xlabel("Countys")
my_plot.set_ylabel("%")
my_plot.set_ylim([0,100])
# Out:
# County
# Index 	 Count
# Dublin 	 3188
# Kilkenny 	 133
# Clare 	 240
# Kerry 	 284
# Tipperary 	 283
# Wexford 	 363
# Offaly 	 119
# Longford 	 90
# Waterford 	 245
# Limerick 	 348
# Wicklow 	 317
# Meath 	 399
# Galway 	 502
# Donegal 	 274
# Kildare 	 483
# Roscommon 	 143
# Cavan 	 153
# Louth 	 288
# Cork 	 1098
# Mayo 	 259
# Westmeath 	 174
# Sligo 	 148
# Laois 	 163
# Carlow 	 124
# Monaghan 	 76
# Leitrim 	 99
# (0.0, 100.0)

# %% [markdown]
# ### Interpretation:

# %% [markdown]
# - We can see that the border counties of Kildare, Meath, and Wicklow see the greates amount of new dwellings.
# - This makes sense as people look to move closer to Dublin while avoiding the astronmical house prices within Dublin.

# %% [markdown]
#
# <h1><center>Part 4: Creating New Features by transforming existing data or adding in external data</center></h1>

# %% [markdown]
# - How the data frame looks currently:

# %%
df.head(3)
# Out:
#   Date of Sale (yyyy/mm/dd)                               Address Postal Code  \
# 0       2016-06-05 00:00:00    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8
# 1       2014-12-22 00:00:00  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8
# 2       2020-05-22 00:00:00    17 MERRION PARK, BLACKROCK, DUBLIN        None
#
#    County  Price (€) Not Full Market Price VAT Exclusive  \
# 0  Dublin   630000.0                    No            No
# 1  Dublin   281000.0                    No            No
# 2  Dublin   560000.0                    No            No
#
#                  Description of Property Property Size Description  Month  \
# 0  Second-Hand Dwelling house /Apartment                      None      6
# 1  Second-Hand Dwelling house /Apartment                      None     12
# 2  Second-Hand Dwelling house /Apartment                      None      5
#
#    Year   percent
# 0  2016  0.031368
# 1  2014  0.031368
# 2  2020  0.031368

# %% [markdown]
# - I have decided to add the following extra features:
#     - Year (added in previous section)
#     - Month (added in previous section)
#     - Seasons
#     - Provinces
#     - GDP of that year
#     -  Number of yearly house loans approved.

# %% [markdown]
# - I have attempted to avoid using loops to manipulate the data due to how expensive they can be with large data sets.
# - ref https://www.kdnuggets.com/2017/11/forget-for-loop-data-science-code-vectorization.html

# %% [markdown]
# ## Creating Seasons feature

# %% [markdown]
# Metrological Seasons:
# - Spring runs from March 1 to May 31.
# - Summer runs from June 1 to August 31.
# - Autumn runs from September 1 to November 30.
# - winter runs from December 1 to February 28.

# %%
df['Season'] = df.apply(
    lambda row: row.Month, axis=1)

df.loc[df.Month== 12, 'Season'] = 'Winter'
df.loc[df.Month== 1, 'Season'] = 'Winter'
df.loc[df.Month== 2, 'Season'] = 'Winter'
df.loc[df.Month== 3, 'Season'] = 'Spring'
df.loc[df.Month== 4, 'Season'] = 'Spring'
df.loc[df.Month== 5, 'Season'] = 'Spring'
df.loc[df.Month== 6, 'Season'] = 'Summer'
df.loc[df.Month== 7, 'Season'] = 'Summer'
df.loc[df.Month== 8, 'Season'] = 'Summer'
df.loc[df.Month== 9, 'Season'] = 'Autumn'
df.loc[df.Month== 10, 'Season'] = 'Autumn'
df.loc[df.Month== 11, 'Season'] = 'Autumn'

# %%
df.head(10)
# Out:
#   Date of Sale (yyyy/mm/dd)                                        Address  \
# 0       2016-06-05 00:00:00             21 CURZON ST, PORTOBELLO, DUBLIN 8
# 1       2014-12-22 00:00:00           44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8
# 2       2020-05-22 00:00:00             17 MERRION PARK, BLACKROCK, DUBLIN
# 3       2014-11-27 00:00:00               KNOCKROE, RATHMOYLE, CO.KILKENNY
# 4       2018-11-22 00:00:00             15 SHANNON PARK, LIFFORD RD, ENNIS
# 5       2016-01-31 00:00:00  27 MOUNT DRUMMOND SQ, HAROLDS CROSS, DUBLIN 6
# 6       2021-11-30 00:00:00         10 HOLLOW WAY, OAKVIEW VILLAGE, TRALEE
# 7       2016-02-05 00:00:00                            Ballygibbon, Nenagh
# 8       2018-12-03 00:00:00              RANDLESTOWN, BALLYCOGLEY, WEXFORD
# 9       2015-11-17 00:00:00               3 RIVER STREET, CLARA, CO OFFALY
#
#   Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin 8     Dublin   630000.0                    No            No
# 1    Dublin 8     Dublin   281000.0                    No            No
# 2        None     Dublin   560000.0                    No            No
# 3        None   Kilkenny    46000.0                    No            No
# 4        None      Clare   204000.0                    No            No
# 5    Dublin 6     Dublin   375000.0                    No            No
# 6        None      Kerry   182000.0                    No            No
# 7        None  Tipperary   264317.0                    No           Yes
# 8        None    Wexford    70000.0                    No            No
# 9        None     Offaly    34500.0                    No            No
#
#                  Description of Property   Property Size Description  Month  \
# 0  Second-Hand Dwelling house /Apartment                        None      6
# 1  Second-Hand Dwelling house /Apartment                        None     12
# 2  Second-Hand Dwelling house /Apartment                        None      5
# 3  Second-Hand Dwelling house /Apartment                        None     11
# 4  Second-Hand Dwelling house /Apartment                        None     11
# 5  Second-Hand Dwelling house /Apartment                        None      1
# 6  Second-Hand Dwelling house /Apartment                        None     11
# 7          New Dwelling house /Apartment  greater than 125 sq metres      2
# 8  Second-Hand Dwelling house /Apartment                        None     12
# 9  Second-Hand Dwelling house /Apartment                        None     11
#
#    Year   percent  Season
# 0  2016  0.031368  Summer
# 1  2014  0.031368  Winter
# 2  2020  0.031368  Spring
# 3  2014  0.751880  Autumn
# 4  2018  0.416667  Autumn
# 5  2016  0.031368  Winter
# 6  2021  0.352113  Autumn
# 7  2016  0.353357  Winter
# 8  2018  0.275482  Winter
# 9  2015  0.840336  Autumn

# %%
df['Season'] = df['Season'].astype('category')

df.dtypes
# Out:
# Date of Sale (yyyy/mm/dd)      object
# Address                      category
# Postal Code                  category
# County                       category
# Price (€)                     float64
# Not Full Market Price        category
# VAT Exclusive                category
# Description of Property        object
# Property Size Description    category
# Month                           int64
# Year                            int64
# percent                       float64
# Season                       category
# dtype: object

# %% [markdown]
# #### Analysis of Seasons:

# %%
df["Season"].describe()
# Out:
# count       9993
# unique         4
# top       Autumn
# freq        2675
# Name: Season, dtype: object

# %%
df.groupby(['Season']).describe()
# Out:
#        Price (€)                                                             \
#            count           mean            std      min       25%       50%
# Season
# Autumn    2675.0  254792.578763  251778.381990   6348.0  120000.0  205000.0
# Spring    2313.0  242608.173065  223679.755765  10000.0  117739.2  194000.0
# Summer    2492.0  263254.844635  299052.065829   6000.0  123500.0  207000.0
# Winter    2513.0  255036.735181  331168.560416   5500.0  116000.0  196875.0
#
#                               Month             ...    Year         percent  \
#              75%        max   count       mean  ...     75%     max   count
# Season                                          ...
# Autumn  315500.0  6000000.0  2675.0  10.033271  ...  2019.0  2021.0  2675.0
# Spring  300000.0  3050000.0  2313.0   4.041505  ...  2019.0  2021.0  2313.0
# Summer  315000.0  7600000.0  2492.0   7.015249  ...  2019.0  2021.0  2492.0
# Winter  300000.0  6720000.0  2513.0   6.036610  ...  2019.0  2022.0  2513.0
#
#
#             mean       std       min       25%       50%       75%       max
# Season
# Autumn  0.266525  0.261115  0.031368  0.031368  0.207039  0.364964  1.315789
# Spring  0.257161  0.254054  0.031368  0.031368  0.207039  0.353357  1.315789
# Summer  0.257020  0.249283  0.031368  0.031368  0.207039  0.353357  1.315789
# Winter  0.259346  0.260831  0.031368  0.031368  0.207039  0.353357  1.315789
#
# [4 rows x 32 columns]

# %%
sns.catplot(x="Season", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# #### Looking at value counts

# %%
df['Season'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation of Season features:

# %% [markdown]
# - It loooks as though there is no difference in price across the 5 seasons
# - It looks as though there is a difference in terms of the amount of sales per month. With autumn being the highest. This could be due to a number of reasons such as buyers being keen to move in time for Christmas and before the new year

# %% [markdown]
# ## Creating Province Feature

# %% [markdown]
# - A province is a territorial region
# - There have been four Provinces of Ireland: Connacht, Leinster, Munster, and Ulster
# - Each county falls into one the provinces.

# %%
df['Province'] = df.apply(
    lambda row: row.County, axis=1)

df.loc[df.County== 'Dublin', 'Province'] = 'Leinster'
df.loc[df.County== 'Carlow', 'Province'] = 'Leinster'
df.loc[df.County== 'Kildare', 'Province'] = 'Leinster'
df.loc[df.County== 'Kilkenny', 'Province'] = 'Leinster'
df.loc[df.County== 'Laois', 'Province'] = 'Leinster'
df.loc[df.County== 'Longford', 'Province'] = 'Leinster'
df.loc[df.County== 'Louth', 'Province'] = 'Leinster'
df.loc[df.County== 'Meath', 'Province'] = 'Leinster'
df.loc[df.County== 'Offaly', 'Province'] = 'Leinster'
df.loc[df.County== 'Westmeath', 'Province'] = 'Leinster'
df.loc[df.County== 'Wexford', 'Province'] = 'Leinster'
df.loc[df.County== 'Wicklow', 'Province'] = 'Leinster'
df.loc[df.County== 'Cork', 'Province'] = 'Munster'
df.loc[df.County== 'Clare', 'Province'] = 'Munster'
df.loc[df.County== 'Kerry', 'Province'] = 'Munster'
df.loc[df.County== 'Limerick', 'Province'] = 'Munster'
df.loc[df.County== 'Tipperary', 'Province'] = 'Munster'
df.loc[df.County== 'Waterford', 'Province'] = 'Munster'
df.loc[df.County== 'Galway', 'Province'] = 'Connaught'
df.loc[df.County== 'Leitrim', 'Province'] = 'Connaught'
df.loc[df.County== 'Mayo', 'Province'] = 'Connaught'
df.loc[df.County== 'Roscommon', 'Province'] = 'Connaught'
df.loc[df.County== 'Sligo', 'Province'] = 'Connaught'
df.loc[df.County== 'Donegal', 'Province'] = 'Ulster'
df.loc[df.County== 'Cavan', 'Province'] = 'Ulster'
df.loc[df.County== 'Monaghan', 'Province'] = 'Ulster'







df.tail(5)
# Out:
#      Date of Sale (yyyy/mm/dd)                                    Address  \
# 9995       2017-12-15 00:00:00           KNOCKASARTNETT, KILLARNEY, KERRY
# 9996       2012-12-18 00:00:00    17 the court, cypress downs, templeogue
# 9997       2016-12-14 00:00:00  THE LOG CABIN, FORGE COTTAGE, CULLENSTOWN
# 9998       2017-06-19 00:00:00               CARRIG RD, PARKMORE, ROSCREA
# 9999       2017-02-11 00:00:00         26 KILSHANE RD, FINGLAS, DUBLIN 11
#
#      Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 9995        None      Kerry  200000.00                    No            No
# 9996        None     Dublin  605000.00                    No            No
# 9997        None    Wexford   46666.67                    No            No
# 9998        None  Tipperary  176000.00                    No            No
# 9999   Dublin 11     Dublin   86738.06                   Yes            No
#
#                     Description of Property Property Size Description  Month  \
# 9995  Second-Hand Dwelling house /Apartment                      None     12
# 9996  Second-Hand Dwelling house /Apartment                      None     12
# 9997  Second-Hand Dwelling house /Apartment                      None     12
# 9998  Second-Hand Dwelling house /Apartment                      None      6
# 9999  Second-Hand Dwelling house /Apartment                      None      2
#
#       Year   percent  Season  Province
# 9995  2017  0.352113  Winter   Munster
# 9996  2012  0.031368  Winter  Leinster
# 9997  2016  0.275482  Winter  Leinster
# 9998  2017  0.353357  Summer   Munster
# 9999  2017  0.031368  Winter  Leinster

# %%
df['Province'] = df['Province'].astype('category')

df.dtypes
# Out:
# Date of Sale (yyyy/mm/dd)      object
# Address                      category
# Postal Code                  category
# County                       category
# Price (€)                     float64
# Not Full Market Price        category
# VAT Exclusive                category
# Description of Property        object
# Property Size Description    category
# Month                           int64
# Year                            int64
# percent                       float64
# Season                       category
# Province                     category
# dtype: object

# %% [markdown]
# #### Analysis of Provinces

# %%
df["Province"].describe().T
# Out:
# count         9993
# unique           4
# top       Leinster
# freq          5841
# Name: Province, dtype: object

# %%
df.groupby(['Province']).describe()
# Out:
#           Price (€)                                                            \
#               count           mean            std     min       25%       50%
# Province
# Connaught    1151.0  153525.288514  133408.000784  5500.0   70000.0  128000.0
# Leinster     5841.0  314464.924285  335936.103738  5500.0  161000.0  250000.0
# Munster      2498.0  185478.186882  138416.314081  6000.0   95000.0  160000.0
# Ulster        503.0  124929.423797   83804.317723  9000.0   65000.0  110000.0
#
#                                   Month            ...    Year          \
#                  75%        max   count      mean  ...     75%     max
# Province                                           ...
# Connaught  202643.17  2026432.0  1151.0  6.896612  ...  2019.0  2022.0
# Leinster   366666.66  7600000.0  5841.0  6.890772  ...  2019.0  2022.0
# Munster    240000.00  2275000.0  2498.0  6.873499  ...  2019.0  2022.0
# Ulster     160000.00   850000.0   503.0  6.922465  ...  2019.0  2021.0
#
#           percent                                                              \
#             count      mean       std       min       25%       50%       75%
# Province
# Connaught  1151.0  0.434405  0.263481  0.199203  0.199203  0.386100  0.675676
# Leinster   5841.0  0.205444  0.250337  0.031368  0.031368  0.031368  0.275482
# Munster    2498.0  0.240192  0.136841  0.091075  0.091075  0.287356  0.353357
# Ulster      503.0  0.596421  0.329518  0.364964  0.364964  0.364964  0.653595
#
#
#                 max
# Province
# Connaught  1.010101
# Leinster   1.111111
# Munster    0.416667
# Ulster     1.315789
#
# [4 rows x 32 columns]

# %% [markdown]
# - Leinster has the highest amount of prices compared to the other counties by a considerable distance.

# %%
df.groupby(['Province']).median()
# Out:
#            Price (€)  Month  Year   percent
# Province
# Connaught   128000.0      7  2017  0.386100
# Leinster    250000.0      7  2017  0.031368
# Munster     160000.0      7  2017  0.287356
# Ulster      110000.0      7  2017  0.364964

# %%
sns.catplot(x="Province", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# - Leinster has the most sales due to it area size, population and containing the capital city Dublin. As shown below:

# %%
df['Province'].value_counts(dropna=False).plot(kind='bar', figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Creating Gross Domestic Product (GDP) Feature

# %% [markdown]
# - GDP is the total monetary value of all the finished goods and services produced within a country’s borders in a specific time period. In other words, the total value created by an econnomy.
# - GDP is usuaslly calculated on a yearly basis.
# - The data is obtained from the official world bank https://tradingeconomics.com/ireland/gdp
# - The reason for adding this feature is that GDP has been seen to be the main driver in real estate prices from other parts of the world. This is due to the idea that income has to be accumulated to buy a home in order to purchase a property. Thus, income can be directly derived from GDP. Growth trends of both cycles typically line up with each other.
# - reference: https://www.asiagreen.com/en/news-insights/the-link-between-gdp-growth-and-the-real-estate-market

# %%
df['GDP (USD-Billion)'] = df.apply(
    lambda row: row.Year, axis=1)

df.loc[df.Year== 2010, 'GDP (USD-Billion)'] = 221.66
df.loc[df.Year== 2011, 'GDP (USD-Billion)'] = 238.66
df.loc[df.Year== 2012, 'GDP (USD-Billion)'] = 225.51
df.loc[df.Year== 2013, 'GDP (USD-Billion)'] = 238.21
df.loc[df.Year== 2014, 'GDP (USD-Billion)'] = 258.63
df.loc[df.Year== 2015, 'GDP (USD-Billion)'] = 291.46
df.loc[df.Year== 2016, 'GDP (USD-Billion)'] = 298.73
df.loc[df.Year== 2017, 'GDP (USD-Billion)'] = 334.60
df.loc[df.Year== 2018, 'GDP (USD-Billion)'] = 384.85
df.loc[df.Year== 2019, 'GDP (USD-Billion)'] = 399.12
df.loc[df.Year== 2020, 'GDP (USD-Billion)'] = 425.89
df.loc[df.Year== 2021, 'GDP (USD-Billion)'] = 440
df.loc[df.Year== 2022, 'GDP (USD-Billion)'] = 'Unknown'



df.tail(5)
# Out:
#      Date of Sale (yyyy/mm/dd)                                    Address  \
# 9995       2017-12-15 00:00:00           KNOCKASARTNETT, KILLARNEY, KERRY
# 9996       2012-12-18 00:00:00    17 the court, cypress downs, templeogue
# 9997       2016-12-14 00:00:00  THE LOG CABIN, FORGE COTTAGE, CULLENSTOWN
# 9998       2017-06-19 00:00:00               CARRIG RD, PARKMORE, ROSCREA
# 9999       2017-02-11 00:00:00         26 KILSHANE RD, FINGLAS, DUBLIN 11
#
#      Postal Code     County  Price (€) Not Full Market Price VAT Exclusive  \
# 9995        None      Kerry  200000.00                    No            No
# 9996        None     Dublin  605000.00                    No            No
# 9997        None    Wexford   46666.67                    No            No
# 9998        None  Tipperary  176000.00                    No            No
# 9999   Dublin 11     Dublin   86738.06                   Yes            No
#
#                     Description of Property Property Size Description  Month  \
# 9995  Second-Hand Dwelling house /Apartment                      None     12
# 9996  Second-Hand Dwelling house /Apartment                      None     12
# 9997  Second-Hand Dwelling house /Apartment                      None     12
# 9998  Second-Hand Dwelling house /Apartment                      None      6
# 9999  Second-Hand Dwelling house /Apartment                      None      2
#
#       Year   percent  Season  Province GDP (USD-Billion)
# 9995  2017  0.352113  Winter   Munster             334.6
# 9996  2012  0.031368  Winter  Leinster            225.51
# 9997  2016  0.275482  Winter  Leinster            298.73
# 9998  2017  0.353357  Summer   Munster             334.6
# 9999  2017  0.031368  Winter  Leinster             334.6

# %%
df['GDP (USD-Billion)'] = df['GDP (USD-Billion)'].astype('category')

df.dtypes
# Out:
# Date of Sale (yyyy/mm/dd)      object
# Address                      category
# Postal Code                  category
# County                       category
# Price (€)                     float64
# Not Full Market Price        category
# VAT Exclusive                category
# Description of Property        object
# Property Size Description    category
# Month                           int64
# Year                            int64
# percent                       float64
# Season                       category
# Province                     category
# GDP (USD-Billion)            category
# dtype: object

# %% [markdown]
# #### Analysis of GDP (USD-Billion)

# %%
df["GDP (USD-Billion)"].describe()
# Out:
# count     9993.00
# unique      13.00
# top        384.85
# freq      1172.00
# Name: GDP (USD-Billion), dtype: float64

# %%
df_GDP = df[['GDP (USD-Billion)', 'Price (€)']].copy()

# %%
df_GDP.groupby(['GDP (USD-Billion)']).describe()
# Out:
#                   Price (€)                                                    \
#                       count           mean            std      min        25%
# GDP (USD-Billion)
# 221.66                412.0  224643.019951  157192.930640  10000.0  136875.00
# 225.51                506.0  181532.374605  153257.033998   7500.0   90000.00
# 238.21                585.0  203643.650462  220379.267323   5500.0   80000.00
# 238.66                369.0  219054.456558  206419.722487  10000.0  110132.00
# 258.63                808.0  212177.482092  294579.769583   8000.0   80975.60
# 291.46               1003.0  223259.339182  263648.172099   5500.0   90000.00
# 298.73                937.0  238362.960918  270581.705049   7250.0  105000.00
# 334.6                1060.0  266338.501613  318113.095142   7500.0  127938.25
# 384.85               1172.0  265961.352850  257800.119201   6000.0  135000.00
# 399.12               1149.0  283149.717328  278349.470145   7300.0  156000.00
# 425.89                936.0  289165.761090  261154.926478   7770.0  154750.00
# 440.0                1046.0  329212.255373  386364.365416   9000.0  170000.00
# Unknown                10.0  219597.400000   94588.345423  30000.0  167493.50
#
#
#                          50%        75%        max
# GDP (USD-Billion)
# 221.66             200000.00  266640.00  1550000.0
# 225.51             145374.50  220000.00  1425000.0
# 238.21             140000.00  240000.00  2050000.0
# 238.66             175000.00  255000.00  2480000.0
# 258.63             150000.00  245000.00  6000000.0
# 291.46             164537.00  267500.00  5000000.0
# 298.73             185500.00  295000.00  5250000.0
# 334.6              211226.50  325000.00  7600000.0
# 384.85             217250.00  317000.00  4138200.0
# 399.12             245000.00  334091.00  6200000.0
# 425.89             242470.48  346111.25  3350000.0
# 440.0              260000.00  370000.00  6720000.0
# Unknown            224000.00  273500.00   382000.0

# %%
sns.catplot(x="GDP (USD-Billion)", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### Interpretation of GDP:

# %% [markdown]
# - The GDP of the country seems to be indicative of the price. As GDP grows so does house prices. As mentioned, this could be due to factors like people's wage's increasing and driving up prices.

# %% [markdown]
# ## Creating 'Number of Loans approved per year' feature:

# %% [markdown]
# - This data was obtained form the Central Statistics Office.
# - It indicates the number of loans that were approved in a calender year.
# - I decided to sum New property and Second hand property per year to obtain a bigger picture.
# - Unfortunatetly, data was only avaiable to year 2016.

# %%
df1 = pd.read_csv('House_loan_data.csv', keep_default_na=True, sep=',\s+', delimiter=',', skipinitialspace=True)
df1.head(5)
# Out:
#                         Statistic  Year House Type New or Second hand    UNIT  \
# 0  Number of House Loans Approved  1970                    New houses  Number
# 1  Number of House Loans Approved  1970            Second-hand houses  Number
# 2  Number of House Loans Approved  1971                    New houses  Number
# 3  Number of House Loans Approved  1971            Second-hand houses  Number
# 4  Number of House Loans Approved  1972                    New houses  Number
#
#      VALUE
# 0   7884.0
# 1   4587.0
# 2  10626.0
# 3   4692.0
# 4  13389.0

# %% [markdown]
# #### Dropping Unecessary Data

# %%
df1.drop(df1.index[94:377],0,inplace=True)

# %%
df1.drop(df1.index[0:80],0,inplace=True)

# %%
df1.head(40)
# Out:
#                          Statistic  Year House Type New or Second hand  \
# 80  Number of House Loans Approved  2010                    New houses
# 81  Number of House Loans Approved  2010            Second-hand houses
# 82  Number of House Loans Approved  2011                    New houses
# 83  Number of House Loans Approved  2011            Second-hand houses
# 84  Number of House Loans Approved  2012                    New houses
# 85  Number of House Loans Approved  2012            Second-hand houses
# 86  Number of House Loans Approved  2013                    New houses
# 87  Number of House Loans Approved  2013            Second-hand houses
# 88  Number of House Loans Approved  2014                    New houses
# 89  Number of House Loans Approved  2014            Second-hand houses
# 90  Number of House Loans Approved  2015                    New houses
# 91  Number of House Loans Approved  2015            Second-hand houses
# 92  Number of House Loans Approved  2016                    New houses
# 93  Number of House Loans Approved  2016            Second-hand houses
#
#       UNIT    VALUE
# 80  Number   6991.0
# 81  Number  13030.0
# 82  Number   2960.0
# 83  Number   9874.0
# 84  Number   3457.0
# 85  Number  14312.0
# 86  Number   2974.0
# 87  Number  16284.0
# 88  Number   4461.0
# 89  Number  27436.0
# 90  Number   4685.0
# 91  Number  27551.0
# 92  Number   6450.0
# 93  Number  28587.0

# %% [markdown]
# #### Creating the new feature

# %%
df2 = df1['VALUE']


print("Total 2010 = ", df2.iloc[0:2].sum())
print("Total 2011 = ", df2.iloc[2:4].sum())
print("Total 2012 = ", df2.iloc[4:6].sum())
print("Total 2013 = ", df2.iloc[6:8].sum())
print("Total 2014 = ", df2.iloc[8:10].sum())
print("Total 2015 = ", df2.iloc[10:12].sum())
print("Total 2016 = ", df2.iloc[12:14].sum())
# Out:
# Total 2010 =  20021.0
# Total 2011 =  12834.0
# Total 2012 =  17769.0
# Total 2013 =  19258.0
# Total 2014 =  31897.0
# Total 2015 =  32236.0
# Total 2016 =  35037.0

# %%
df['Total Number of Loans Approved'] = df.apply(
    lambda row: row.Year, axis=1)

df.loc[df.Year== 2010, 'Total Number of Loans Approved'] = 20021
df.loc[df.Year== 2011, 'Total Number of Loans Approved'] = 12834
df.loc[df.Year== 2012, 'Total Number of Loans Approved'] = 17769
df.loc[df.Year== 2013, 'Total Number of Loans Approved'] = 19258
df.loc[df.Year== 2014, 'Total Number of Loans Approved'] = 31897
df.loc[df.Year== 2015, 'Total Number of Loans Approved'] = 32236
df.loc[df.Year== 2016, 'Total Number of Loans Approved'] = 35037
df.loc[df.Year== 2017, 'Total Number of Loans Approved'] = 'Unkown'
df.loc[df.Year== 2018, 'Total Number of Loans Approved'] = 'Unkown'
df.loc[df.Year== 2019, 'Total Number of Loans Approved'] = 'Unkown'
df.loc[df.Year== 2020, 'Total Number of Loans Approved'] = 'Unkown'
df.loc[df.Year== 2021, 'Total Number of Loans Approved'] = 'Unkown'
df.loc[df.Year== 2022, 'Total Number of Loans Approved'] = 'Unkown'



df['Total Number of Loans Approved'] = df['Total Number of Loans Approved'].astype('category')

df.dtypes
# Out:
# Date of Sale (yyyy/mm/dd)           object
# Address                           category
# Postal Code                       category
# County                            category
# Price (€)                          float64
# Not Full Market Price             category
# VAT Exclusive                     category
# Description of Property             object
# Property Size Description         category
# Month                                int64
# Year                                 int64
# percent                            float64
# Season                            category
# Province                          category
# GDP (USD-Billion)                 category
# Total Number of Loans Approved    category
# dtype: object

# %%
df.head(5)
# Out:
#   Date of Sale (yyyy/mm/dd)                               Address Postal Code  \
# 0       2016-06-05 00:00:00    21 CURZON ST, PORTOBELLO, DUBLIN 8    Dublin 8
# 1       2014-12-22 00:00:00  44 ROTHE ABBEY, KILMAINHAM, DUBLIN 8    Dublin 8
# 2       2020-05-22 00:00:00    17 MERRION PARK, BLACKROCK, DUBLIN        None
# 3       2014-11-27 00:00:00      KNOCKROE, RATHMOYLE, CO.KILKENNY        None
# 4       2018-11-22 00:00:00    15 SHANNON PARK, LIFFORD RD, ENNIS        None
#
#      County  Price (€) Not Full Market Price VAT Exclusive  \
# 0    Dublin   630000.0                    No            No
# 1    Dublin   281000.0                    No            No
# 2    Dublin   560000.0                    No            No
# 3  Kilkenny    46000.0                    No            No
# 4     Clare   204000.0                    No            No
#
#                  Description of Property Property Size Description  Month  \
# 0  Second-Hand Dwelling house /Apartment                      None      6
# 1  Second-Hand Dwelling house /Apartment                      None     12
# 2  Second-Hand Dwelling house /Apartment                      None      5
# 3  Second-Hand Dwelling house /Apartment                      None     11
# 4  Second-Hand Dwelling house /Apartment                      None     11
#
#    Year   percent  Season  Province GDP (USD-Billion)  \
# 0  2016  0.031368  Summer  Leinster            298.73
# 1  2014  0.031368  Winter  Leinster            258.63
# 2  2020  0.031368  Spring  Leinster            425.89
# 3  2014  0.751880  Autumn  Leinster            258.63
# 4  2018  0.416667  Autumn   Munster            384.85
#
#   Total Number of Loans Approved
# 0                          35037
# 1                          31897
# 2                         Unkown
# 3                          31897
# 4                         Unkown

# %% [markdown]
# #### Analysis of "Total Number of Loans Approved"

# %%
df["Total Number of Loans Approved"].describe()
# Out:
# count       9993
# unique         8
# top       Unkown
# freq        5373
# Name: Total Number of Loans Approved, dtype: object

# %%
df.groupby(['Total Number of Loans Approved']).describe()
# Out:
#                                Price (€)                                \
#                                    count           mean            std
# Total Number of Loans Approved
# 12834                              369.0  219054.456558  206419.722487
# 17769                              506.0  181532.374605  153257.033998
# 19258                              585.0  203643.650462  220379.267323
# 20021                              412.0  224643.019951  157192.930640
# 31897                              808.0  212177.482092  294579.769583
# 32236                             1003.0  223259.339182  263648.172099
# 35037                              937.0  238362.960918  270581.705049
# Unkown                            5373.0  285980.958117  304067.130971
#
#                                                                        \
#                                     min       25%       50%       75%
# Total Number of Loans Approved
# 12834                           10000.0  110132.0  175000.0  255000.0
# 17769                            7500.0   90000.0  145374.5  220000.0
# 19258                            5500.0   80000.0  140000.0  240000.0
# 20021                           10000.0  136875.0  200000.0  266640.0
# 31897                            8000.0   80975.6  150000.0  245000.0
# 32236                            5500.0   90000.0  164537.0  267500.0
# 35037                            7250.0  105000.0  185500.0  295000.0
# Unkown                           6000.0  147000.0  235000.0  340000.0
#
#                                             Month            ...    Year  \
#                                       max   count      mean  ...     75%
# Total Number of Loans Approved                               ...
# 12834                           2480000.0   369.0  6.986450  ...  2011.0
# 17769                           1425000.0   506.0  7.266798  ...  2012.0
# 19258                           2050000.0   585.0  7.203419  ...  2013.0
# 20021                           1550000.0   412.0  6.398058  ...  2010.0
# 31897                           6000000.0   808.0  7.226485  ...  2014.0
# 32236                           5000000.0  1003.0  6.662014  ...  2015.0
# 35037                           5250000.0   937.0  6.781217  ...  2016.0
# Unkown                          7600000.0  5373.0  6.860041  ...  2020.0
#
#                                        percent                                \
#                                    max   count      mean       std       min
# Total Number of Loans Approved
# 12834                           2011.0   369.0  0.272924  0.279257  0.031368
# 17769                           2012.0   506.0  0.250802  0.247080  0.031368
# 19258                           2013.0   585.0  0.249566  0.251867  0.031368
# 20021                           2010.0   412.0  0.270157  0.260980  0.031368
# 31897                           2014.0   808.0  0.260504  0.258218  0.031368
# 32236                           2015.0  1003.0  0.267170  0.277529  0.031368
# 35037                           2016.0   937.0  0.259524  0.261318  0.031368
# Unkown                          2022.0  5373.0  0.259343  0.250709  0.031368
#
#
#                                      25%       50%       75%       max
# Total Number of Loans Approved
# 12834                           0.031368  0.207039  0.364964  1.315789
# 17769                           0.031368  0.207039  0.364964  1.315789
# 19258                           0.031368  0.199203  0.352113  1.315789
# 20021                           0.031368  0.207039  0.370248  1.315789
# 31897                           0.031368  0.207039  0.353357  1.315789
# 32236                           0.031368  0.199203  0.375532  1.315789
# 35037                           0.031368  0.199203  0.353357  1.315789
# Unkown                          0.031368  0.207039  0.353357  1.315789
#
# [8 rows x 32 columns]

# %%
sns.catplot(x="Total Number of Loans Approved", y= "Price (€)", kind="bar",aspect=4,data=df)

# %% [markdown]
# ### Interpretation of Total Number of Loans Approved:

# %% [markdown]
# -

# %% [markdown]
# #### Describing all categorical features again:

# %%
category_columns = df.select_dtypes(['category']).columns

df[category_columns].describe().T
# Out:
#                                  count unique                       top  \
# Address                           9993   9973  SUFFOLK ST, KELLS, MEATH
# Postal Code                       9993     23                      None
# County                            9993     26                    Dublin
# Not Full Market Price             9993      2                        No
# VAT Exclusive                     9993      2                        No
# Property Size Description         9993      5                      None
# Season                            9993      4                    Autumn
# Province                          9993      4                  Leinster
# GDP (USD-Billion)               9993.0   13.0                    384.85
# Total Number of Loans Approved    9993      8                    Unkown
#
#                                   freq
# Address                              2
# Postal Code                       8134
# County                            3188
# Not Full Market Price             9545
# VAT Exclusive                     8397
# Property Size Description         8964
# Season                            2675
# Province                          5841
# GDP (USD-Billion)               1172.0
# Total Number of Loans Approved    5373

# %%
df[numeric_columns].describe().T
# Out:
#             count         mean            std     min       25%       50%  \
# Price (€)  9993.0  254144.0249  280108.039388  5500.0  120000.0  200000.0
#
#                 75%        max
# Price (€)  308370.0  7600000.0

# %% [markdown]
# ### Final CSV file

# %%
df.to_csv('final-file-additonal-features-17350796.csv', index=False)

# %% [markdown]
# <h1><center>Conclusion</center></h1>

# %% [markdown]
# This was a challenging data set to examine. Mainly, due to the fact that this data was entered by human so there is a great chance of error throughout. However, with the power of modules like Pandas and Numpy it was possible to evaluate the data and clean the data, and finally visualize it and make inferences.
#
# As mentioned, price prediction of house prices is particularly pertinent due to the current state of the housing crisis. This analysis has given me a deeper understanding of the metrics at play when it comes to pricing of property. From my analysis you can see how features like, county, post code, number of loans approved, time of yeat, and GDP  interact with price data.
#
# As discussed in the data quality report, the first step saw an intial understanding of the data and an intial clean. My intial impression was that the data was relatively clean with most features having very few missing values. Features Postal Code and Property Description had the most missing data. These features were retained in the case that in the future they could be helpul in predicting price. There some other issues like translations of features, dates showing in the future, and outliers in price. Both features 'Not Full Market Prce' and 'VAT exclusive' showed very low percentages giving the price data very good consistency throughout.
#
# The data quality, plan saw some of the major outliers being removed due to the fact that they were not considered single dwellings for sale. The dates in the future were transformed to their actual dates. The main premise of this section was to retain as much data as appropriately possible. As this will give us more power when it comes to predicting price.
#
#
#
# Exploring the relationships between features is where we see the potential in our features for price prediction. Dublin and the counties bordering Dublin are clearly the most sought out after areas with the biggest rate sales turnover in Ireland. The border counties to Dublin are also seeing the most amount of new dwellings being sold. The Dublin also has the largest spread of data in the country.  This could be due to a number of reasons like employment opportunities, amenities, transport connections and population levels in general. While it is important to keep in mind that a large parts of the postal codes are missing, we can still see that the area of Dublin 4 has the highest average house, yet Dublin 6 has the highest median house price. This shows the large spread of data that the Dublin 4 area has. As the years increase both the number of properties increase, the amount they go for also increases as we measured the year and the median.
#
#
# A number of new features were added in the hope of providing more information in our aim of predicting house prices. Besides the breaking up of Month and Year into features, season, provinces, GDP per year, and number of total loans approved per year were added. As mentioned during the new features section of the report the feature season did not show any major differences during evalutation. Provinces showed Leinster's dominance with house prices and numbers of sales. As Ireland has recovered from the financial crash, our GDP has grown each year as has our house prices. This could be due to a number of reasons like wages increasing. The number of loans approved in a given year also seems to be indicative of house prices.
#
#
# As the title of the notebook suggests, it seems as though both the number of sales and the sales price has rapidly increased as Ireland has recovered from the finacial crash in 2008. It will be interesting to see how the Covid-19 pandemic impacts the property market. Particualy, with the potential for more people to work with home. For example, there may not be as much demand for cities as there was in the past.
#
#
# The main issues with this data set is the lack of details of the actual houses. As mentioned, the property size description is missing most of the data. Features like number of bed rooms or size of garden would be useful data in predicting price. More unique data as I have mentioned in the data quality report would be very beneficial.
#
#
#
# Finally, this has been a challenging assignment. However, it has given a much better understanding of data understanding and preparation by working with a real-world data set. I look forward to beginning to learn about modelling and machine learning.
#
#
#
#
# <p><center>Also...Ireland, build more houses!!
# </center></p>
